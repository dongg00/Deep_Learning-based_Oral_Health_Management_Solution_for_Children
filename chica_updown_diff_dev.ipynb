# %%
import os, glob, json, math, random
import numpy as np
from collections import defaultdict

# ★ 사용자 설정
PROJECT_TAG   = "v2"   # 추출할 때 사용한 project_tag
BASE_DIR      = os.getcwd()         # 노트북 위치 기준 (원하면 바꿔도 됨)
DATA_ROOT     = os.path.join(BASE_DIR, PROJECT_TAG, f"data_{PROJECT_TAG}")

# 라벨(폴더명과 동일)
KOREAN_LABELS = [
    '왼쪽-협측','중앙-협측','오른쪽-협측',
    '왼쪽-구개측','중앙-구개측','오른쪽-구개측',
    '왼쪽-설측','중앙-설측','오른쪽-설측',
    '오른쪽-위-씹는면','왼쪽-위-씹는면','왼쪽-아래-씹는면','오른쪽-아래-씹는면'
]
label_to_idx = {lab:i for i,lab in enumerate(KOREAN_LABELS)}

# ★ 윈도우/필터 기본값 (15fps 기준)
SEQ_LEN            = 45   # 3초 창 (추천)
STRIDE             = 15   # 1초 간격 (66% overlap, 안정적)
MIN_ACTIVE_RATIO   = 0.20 # 창 내에서 '손이 검출된 프레임' 비율 하한 (0.0~1.0)
ACTIVE_EPS         = 1e-7 # 손 좌표 all-zero 판정 임계

# 재현성
SEED = 42
random.seed(SEED); np.random.seed(SEED)

# %%
manifest = []
for lab in KOREAN_LABELS:
    lab_dir = os.path.join(DATA_ROOT, lab)
    if not os.path.isdir(lab_dir): 
        continue
    for person in sorted(os.listdir(lab_dir)):
        pdir = os.path.join(lab_dir, person)
        if not os.path.isdir(pdir): 
            continue
        for npy in glob.glob(os.path.join(pdir, "*.npy")):
            arr = np.load(npy)
            T, F = (arr.shape[0], arr.shape[1]) if arr.ndim==2 else (0,0)
            manifest.append({
                "label": lab,
                "y": label_to_idx[lab],
                "person": person,
                "path": npy,
                "T": T,
                "F": F
            })

len(manifest), manifest[:2]
# Out:
# (656,
#  [{'label': '왼쪽-협측',
#    'y': 0,
#    'person': 'P01',
#    'path': 'd:\\Final_Team3\\v2\\data_v2\\왼쪽-협측\\P01\\1755673634.npy',
#    'T': 150,
#    'F': 48},
#   {'label': '왼쪽-협측',
#    'y': 0,
#    'person': 'P01',
#    'path': 'd:\\Final_Team3\\v2\\data_v2\\왼쪽-협측\\P01\\1755674027.npy',
#    'T': 150,
#    'F': 48}])

# %%
from statistics import mean

feat_dims = sorted(set(m["F"] for m in manifest))
lens      = [m["T"] for m in manifest]
print("Feature dims found:", feat_dims)
print(f"Clips: {len(lens)}, mean T: {mean(lens):.1f}, min T: {min(lens)}, max T: {max(lens)}")

assert len(feat_dims)==1, "여러 차원의 npy가 섞여있어요. 추출 스크립트 버전을 통일하세요."
FEAT_DIM = feat_dims[0]
print("FEAT_DIM =", FEAT_DIM)
# Out:
# Feature dims found: [48]
# Clips: 656, mean T: 150.0, min T: 138, max T: 150
# FEAT_DIM = 48

# %%
def frame_active_mask(win, hand_dims=42, eps=ACTIVE_EPS):
    """
    win: (L, F)  # 스케일링 '전' 윈도
    반환: (L, 1)  # 0/1 마스크
    """
    e = np.abs(win[:, :hand_dims]).sum(axis=1)   # 손 좌표 에너지
    return (e > eps).astype(np.float32)[:, None]


def sliding_windows(arr, seq_len=SEQ_LEN, stride=STRIDE, pad_mode="left"):
    """
    arr: (T, F)
    반환: [(seq_len, F), ...]
    """
    T, F = arr.shape
    if T == 0:
        return []
    if T < seq_len:
        pad = np.zeros((seq_len - T, F), dtype=arr.dtype)
        if pad_mode == "left":
            return [np.vstack([pad, arr])]
        else:
            return [np.vstack([arr, pad])]
    out = []
    for s in range(0, T - seq_len + 1, stride):
        out.append(arr[s:s+seq_len])
    # 끝이 애매하면 마지막 창 하나 더 (중복 방지)
    if (T - seq_len) % stride != 0:
        out.append(arr[-seq_len:])
    return out

def active_ratio_of_window(win, hand_dims=42, eps=ACTIVE_EPS):
    """
    win: (seq_len, F)
    손 좌표(앞 hand_dims)를 frame별로 검사하여
    non-zero 프레임 비율을 반환.
    """
    H = hand_dims
    hand = win[:, :H]              # (L, 42)
    # 프레임별 norm (21점×2를 묶어서 한 프레임 에너지로)
    fr = hand.reshape(win.shape[0], -1)
    nz = (np.abs(fr).sum(axis=1) > eps)  # 각 프레임에 손 검출 여부
    return nz.mean()

# %%
X, M, y, meta = [], [], [], []

kept = 0
dropped_short = 0
dropped_inactive = 0

for m in manifest:
    arr = np.load(m["path"])
    wins = sliding_windows(arr, SEQ_LEN, STRIDE, pad_mode="left")
    if not wins:
        dropped_short += 1
        continue

    for w in wins:
        if active_ratio_of_window(w, hand_dims=42) >= MIN_ACTIVE_RATIO:
            X.append(w)                               # (L, F)  원본(스케일 전)
            M.append(frame_active_mask(w))           # (L, 1)  스케일 X
            y.append(m["y"])
            meta.append({"label": m["label"], "person": m["person"], "src": m["path"]})
            kept += 1
        else:
            dropped_inactive += 1

X = np.stack(X, axis=0)   # (N, L, F)
M = np.stack(M, axis=0)   # (N, L, 1)
y = np.array(y)
print(f"Windows kept: {kept}, dropped_short: {dropped_short}, dropped_inactive: {dropped_inactive}")
print("X shape:", X.shape, "M shape:", M.shape, "y shape:", y.shape)
# Out:
# Windows kept: 5248, dropped_short: 0, dropped_inactive: 0
# X shape: (5248, 45, 48) M shape: (5248, 45, 1) y shape: (5248,)

# %%
# === LOSO 분할 + 스케일링 (모델 학습 없이) ===
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
import numpy as np

# 윈도우별 사람 ID
persons = np.array([m["person"] for m in meta])  # 길이 N (X, y와 동일한 첫 축)

F = X.shape[-1]
# 손 좌표가 앞 42차원(21점 x,y)일 때 fit 마스킹에 사용
HAND_DIMS = 42 if F >= 42 else F
EPS = 1e-7

logo = LeaveOneGroupOut()
fold_no = 0

# 필요하면 결과를 모으고 싶을 때 사용 (메모리 고려해서 주석 유지 가능)
# all_folds = []

for train_idx, val_idx in logo.split(X, y, groups=persons):
    fold_no += 1

    # Split
    X_train, y_train = X[train_idx], y[train_idx]
    X_val,   y_val   = X[val_idx],   y[val_idx]
    persons_train, persons_val = persons[train_idx], persons[val_idx]

    # --- 스케일러: train으로만 fit ---
    scaler = StandardScaler(with_mean=True, with_std=True)

    Xtr_flat = X_train.reshape(-1, F)
    # 손이 아예 미검출(제로필)인 프레임은 fit에서 제외해 통계 왜곡 방지 (옵션)
    mask = (np.abs(Xtr_flat[:, :HAND_DIMS]).sum(axis=1) > EPS)
    if mask.any():
        scaler.fit(Xtr_flat[mask])
    else:
        # 드물지만 전부 제로인 경우를 대비한 fallback
        scaler.fit(Xtr_flat)

    # transform
    X_train_s = scaler.transform(Xtr_flat).reshape(X_train.shape)
    X_val_s   = scaler.transform(X_val.reshape(-1, F)).reshape(X_val.shape)

    print(f"[LOSO Fold {fold_no}] "
          f"Train {X_train_s.shape}, Val {X_val_s.shape} | "
          f"persons train={len(set(persons_train))}, val={len(set(persons_val))}")
# Out:
# [LOSO Fold 1] Train (4728, 45, 48), Val (520, 45, 48) | persons train=21, val=1
# [LOSO Fold 2] Train (4728, 45, 48), Val (520, 45, 48) | persons train=21, val=1
# [LOSO Fold 3] Train (4936, 45, 48), Val (312, 45, 48) | persons train=21, val=1
# [LOSO Fold 4] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 5] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 6] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 7] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 8] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 9] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 10] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 11] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 12] Train (5048, 45, 48), Val (200, 45, 48) | persons train=21, val=1
# [LOSO Fold 13] Train (5072, 45, 48), Val (176, 45, 48) | persons train=21, val=1
# [LOSO Fold 14] Train (5056, 45, 48), Val (192, 45, 48) | persons train=21, val=1
# [LOSO Fold 15] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 16] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 17] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 18] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 19] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 20] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 21] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1
# [LOSO Fold 22] Train (5040, 45, 48), Val (208, 45, 48) | persons train=21, val=1

# %%
import tensorflow as tf, gc, os
# (선택) GPU 메모리 점진 할당
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for g in gpus:
            tf.config.experimental.set_memory_growth(g, True)
    except Exception as e:
        print("set_memory_growth 실패:", e)

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

def _fixed_time_derivatives_with_mask(x, m):
    # x: (B,T,F)  // 스케일된 좌표
    # m: (B,T,1)  // 스케일 전 0/1 마스크
    x_prev = tf.pad(x[:, :-1, :], [[0,0],[1,0],[0,0]])
    dx = x - x_prev

    dx_prev = tf.pad(dx[:, :-1, :], [[0,0],[1,0],[0,0]])
    ddx = dx - dx_prev

    # 정의상 첫/두 프레임 0
    dx  = tf.concat([tf.zeros_like(dx[:, :1, :]),  dx[:, 1:, :]], axis=1)
    ddx = tf.concat([tf.zeros_like(ddx[:, :2, :]), ddx[:, 2:, :]], axis=1)

    # 게이팅은 "마스크"로 (스케일 영향 없음)
    gate_dx  = tf.concat([tf.zeros_like(m[:, :1, :]),  m[:, 1:, :]], axis=1)
    gate_ddx = tf.concat([tf.zeros_like(m[:, :2, :]), m[:, 2:, :]], axis=1)
    dx  = dx  * gate_dx
    ddx = ddx * gate_ddx

    return tf.concat([x, dx, ddx], axis=-1)  # (B,T,3F)

def build_gru_model_updown_with_diffs(input_shape, n_classes=2):
    L, F = input_shape
    inp_x = layers.Input(shape=(L, F), name="inp_x")   # 스케일된 (L,F)
    inp_m = layers.Input(shape=(L, 1), name="inp_m")   # 0/1 마스크

    # Δ/Δ² 부착
    x = layers.Lambda(lambda z: _fixed_time_derivatives_with_mask(z[0], z[1]),
                      name="fixed_diffs")([inp_x, inp_m])     # (L, 3F)

    # (선택) 1×1 Conv로 채널 압축 144→64
    x = layers.Conv1D(64, 1, padding='same', use_bias=False)(x)
    x = layers.LayerNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.SpatialDropout1D(0.3)(x)

    # RNN 헤드 (용량/규제 밸런스)
    x = layers.GRU(64, dropout=0.5, recurrent_dropout=0.0,
                   kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.LayerNormalization()(x)
    x = layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dropout(0.5)(x)

    out = layers.Dense(n_classes, activation='softmax')(x)
    model = tf.keras.Model([inp_x, inp_m], out)

    opt = tf.keras.optimizers.Adam(learning_rate=5e-5, clipnorm=1.0)
    model.compile(optimizer=opt,
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])
    return model

# %%
# =========================
# 위/아래 2-class LOSO 학습/평가 (평균 곡선 포함)
# =========================

from sklearn.model_selection import LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager
import tensorflow as tf
from tensorflow.keras import layers, regularizers

# ===== 옵션 =====
EPOCHS = 80
BATCH_SIZE = 64
ES_PATIENCE = 12
RLR_PATIENCE = 6

PLOT_LAST_FOLD_CURVES = True   # 폴드 개별 곡선(마지막 폴드만)
EVAL_LEVEL = "clip"            # "clip" 또는 "window"

# ===== 한글 폰트 =====
def setup_korean_font():
    candidates = ["Malgun Gothic", "AppleGothic", "NanumGothic", "Noto Sans CJK KR", "Noto Sans KR"]
    installed = {f.name for f in font_manager.fontManager.ttflist}
    for name in candidates:
        if name in installed:
            plt.rcParams["font.family"] = name
            break
    plt.rcParams["axes.unicode_minus"] = False
setup_korean_font()

# ===== 시각화 헬퍼 =====
def plot_training_curves(history, fold_no):
    H = history.history
    plt.figure()
    plt.plot(H.get('loss', []),     label='loss')
    plt.plot(H.get('val_loss', []), label='val_loss')
    plt.title(f'Fold {fold_no} - Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss')
    plt.legend(); plt.tight_layout(); plt.show()

    if 'accuracy' in H and 'val_accuracy' in H:
        plt.figure()
        plt.plot(H['accuracy'],     label='accuracy')
        plt.plot(H['val_accuracy'], label='val_accuracy')
        plt.title(f'Fold {fold_no} - Accuracy')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

def norm_cm(cm):
    with np.errstate(invalid='ignore', divide='ignore'):
        cmn = cm.astype(float) / cm.sum(axis=1, keepdims=True)
        cmn = np.nan_to_num(cmn)
    return cmn

def plot_confmat_ratio(cm, classes, title):
    M = norm_cm(cm)
    plt.figure()
    im = plt.imshow(M, interpolation='nearest', cmap='Blues', vmin=0.0, vmax=1.0)
    plt.title(title); plt.colorbar(im)
    ticks = np.arange(len(classes))
    plt.xticks(ticks, classes); plt.yticks(ticks, classes)
    for i in range(M.shape[0]):
        for j in range(M.shape[1]):
            val = M[i, j]
            txt_color = 'black' if val < 0.6 else 'white'
            plt.text(j, i, f"{val:.2f}", ha="center", va="center", color=txt_color, fontsize=10)
    plt.ylabel('실제 레이블'); plt.xlabel('예측 레이블')
    plt.tight_layout(); plt.show()

# ----- 폴드 평균 곡선 -----
def _nanmean_along_epochs(list_of_lists):
    if not list_of_lists:
        return None, None
    maxlen = max(len(s) for s in list_of_lists)
    M = np.full((len(list_of_lists), maxlen), np.nan, dtype=np.float32)
    for i, s in enumerate(list_of_lists):
        arr = np.asarray(s, dtype=np.float32)
        M[i, :len(arr)] = arr
    return np.nanmean(M, axis=0), np.nanstd(M, axis=0)

def plot_mean_training_curves(histories):
    # Loss
    mean_loss, std_loss         = _nanmean_along_epochs([h.get('loss', []) for h in histories])
    mean_val_loss, std_val_loss = _nanmean_along_epochs([h.get('val_loss', []) for h in histories])

    if mean_loss is not None:
        x = np.arange(len(mean_loss))
        plt.figure()
        plt.plot(x, mean_loss,     label='loss (mean)')
        plt.plot(x, mean_val_loss, label='val_loss (mean)')
        plt.fill_between(x, mean_loss - std_loss,     mean_loss + std_loss,     alpha=0.15)
        plt.fill_between(x, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.15)
        plt.title('LOSO 평균 Loss (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Loss')
        plt.legend(); plt.tight_layout(); plt.show()

    # Accuracy
    has_acc = all(('accuracy' in h and 'val_accuracy' in h) for h in histories)
    if has_acc:
        mean_acc, std_acc         = _nanmean_along_epochs([h['accuracy']     for h in histories])
        mean_val_acc, std_val_acc = _nanmean_along_epochs([h['val_accuracy'] for h in histories])
        x = np.arange(len(mean_acc))
        plt.figure()
        plt.plot(x, mean_acc,     label='accuracy (mean)')
        plt.plot(x, mean_val_acc, label='val_accuracy (mean)')
        plt.fill_between(x, mean_acc - std_acc,     mean_acc + std_acc,     alpha=0.15)
        plt.fill_between(x, mean_val_acc - std_val_acc, mean_val_acc + std_val_acc, alpha=0.15)
        plt.title('LOSO 평균 Accuracy (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

# ===== 13 → 2 (위/아래) 매핑 및 데이터 필터 =====
#  - 위(0): '구개측' 또는 '위-씹는면' 이 포함된 라벨
#  - 아래(1): '설측' 또는 '아래-씹는면' 이 포함된 라벨
#  - 그 외(예: '협측')는 제외
labels_np = np.array(KOREAN_LABELS, dtype=object)

def _ud_from_label(lab: str):
    if ('구개측' in lab) or ('위-씹는면' in lab):
        return 0  # 위
    if ('설측' in lab) or ('아래-씹는면' in lab):
        return 1  # 아래
    return None   # 제외(협측 등)

# 인덱스 마스크 생성
keep_indices = []
y_ud_list = []
for i, yi in enumerate(y):
    lab = labels_np[yi]
    mcls = _ud_from_label(lab)
    if mcls is not None:
        keep_indices.append(i)
        y_ud_list.append(mcls)

keep_indices = np.array(keep_indices, dtype=int)
X_ud = X[keep_indices]                 # (N_ud, L, F)
M_ud = M[keep_indices]                 # (N_ud, L, 1)  <- 추가
y_ud = np.array(y_ud_list, dtype=int)
meta_ud = [meta[i] for i in keep_indices]
persons_ud = np.array([m["person"] for m in meta_ud])

print(f"[Filter] 총 {len(X)}개 중 {len(X_ud)}개 사용.  M shape: {M_ud.shape},  분포:", np.bincount(y_ud))


# ===== LOSO 학습/평가 =====
F = X_ud.shape[-1]
HAND_DIMS = 42 if F >= 42 else F
EPS = 1e-7
logo = LeaveOneGroupOut()

CLASS_NAMES = ['위','아래']

# 집계 버퍼
histories = []
all_win_true, all_win_pred = [], []
all_clip_true, all_clip_pred = [], []
all_win_acc, all_clip_acc = [], []

fold_no = 0
total_folds = len(np.unique(persons_ud))

for train_idx, val_idx in logo.split(X_ud, y_ud, groups=persons_ud):
    X_train, y_train = X_ud[train_idx], y_ud[train_idx]
    X_val,   y_val   = X_ud[val_idx],   y_ud[val_idx]
    M_train, M_val   = M_ud[train_idx], M_ud[val_idx]     # ← 추가

    scaler = StandardScaler(with_mean=True, with_std=True)
    Xtr_flat = X_train.reshape(-1, F)
    mask = (np.abs(Xtr_flat[:, :HAND_DIMS]).sum(axis=1) > EPS)
    scaler.fit(Xtr_flat[mask] if mask.any() else Xtr_flat)

    X_train_s = scaler.transform(X_train.reshape(-1, F)).reshape(X_train.shape)
    X_val_s   = scaler.transform(X_val.reshape(-1, F)).reshape(X_val.shape)
    # M_train, M_val 는 스케일링 절대 금지 (0/1 유지)

    # 모델
    model = build_gru_model_updown_with_diffs(
    input_shape=(X_train_s.shape[1], X_train_s.shape[2]),
    n_classes=2
    )
    
    cls_counts = np.bincount(y_train, minlength=2)
    class_weights = {i: float(np.median(cls_counts)/c) for i, c in enumerate(cls_counts)}

    cb = [
        tf.keras.callbacks.EarlyStopping(patience=ES_PATIENCE, restore_best_weights=True, monitor='val_loss'),
        tf.keras.callbacks.ReduceLROnPlateau(patience=RLR_PATIENCE, factor=0.5, min_lr=1e-5),
    ]

    history = model.fit(
        [X_train_s, M_train], y_train,
        validation_data=([X_val_s, M_val], y_val),
        epochs=EPOCHS, batch_size=BATCH_SIZE,
        class_weight=class_weights,
        callbacks=cb, verbose=1
    )
    histories.append(history.history)

    if PLOT_LAST_FOLD_CURVES and fold_no == total_folds:
        plot_training_curves(history, fold_no)

    # 윈도우 단위
    p = model.predict([X_val_s, M_val], verbose=0)
    y_pred = p.argmax(1)
    win_acc = accuracy_score(y_val, y_pred)
    all_win_acc.append(win_acc)
    all_win_true.append(y_val); all_win_pred.append(y_pred)

    # 클립 단위
    bucket_p, bucket_y = defaultdict(list), {}
    val_meta = [meta_ud[i] for i in val_idx]
    for i, m in enumerate(val_meta):
        bucket_p[m["src"]].append(p[i])
        bucket_y[m["src"]] = y_val[i]
    P_clip, Y_clip = [], []
    for src, ps in bucket_p.items():
        P_clip.append(np.mean(ps, axis=0))
        Y_clip.append(bucket_y[src])
    clip_pred = np.argmax(np.vstack(P_clip), axis=1)
    clip_acc = accuracy_score(Y_clip, clip_pred)
    all_clip_acc.append(clip_acc)
    all_clip_true.append(np.array(Y_clip))
    all_clip_pred.append(clip_pred)

# ===== 폴드 전체 집계 =====
all_win_true  = np.concatenate(all_win_true, axis=0)
all_win_pred  = np.concatenate(all_win_pred, axis=0)
all_clip_true = np.concatenate(all_clip_true, axis=0)
all_clip_pred = np.concatenate(all_clip_pred, axis=0)

print("\n==== LOSO Summary (Up/Down) ====")
print(f"Mean Window Acc: {np.mean(all_win_acc):.3f} ± {np.std(all_win_acc):.3f}")
print(f"Mean Clip   Acc: {np.mean(all_clip_acc):.3f} ± {np.std(all_clip_acc):.3f}")

# ===== 최종(전체 사람) 혼동행렬/지표 =====
if EVAL_LEVEL == "clip":
    y_true_overall = all_clip_true; y_pred_overall = all_clip_pred; level_name = "클립"
else:
    y_true_overall = all_win_true;  y_pred_overall = all_win_pred;  level_name = "윈도우"

overall_acc = accuracy_score(y_true_overall, y_pred_overall)
print(f"\n==== OVERALL ({level_name}) ====")
print(f"Overall {level_name} Acc: {overall_acc:.3f}")
print(classification_report(y_true_overall, y_pred_overall, target_names=CLASS_NAMES, digits=3))

cm_overall = confusion_matrix(y_true_overall, y_pred_overall, labels=[0,1])
plot_confmat_ratio(cm_overall, CLASS_NAMES, f'전체 {level_name} 혼동행렬 (행 정규화, 비율)')

# ===== LOSO 평균 곡선 =====
plot_mean_training_curves(histories)
# Out:
# [Filter] 총 5248개 중 4016개 사용.  M shape: (4016, 45, 1),  분포: [2000 2016]
# Epoch 1/80
# 57/57 [==============================] - 2s 14ms/step - loss: 0.9541 - accuracy: 0.5130 - val_loss: 0.7070 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 2/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8856 - accuracy: 0.5177 - val_loss: 0.6493 - val_accuracy: 0.6225 - lr: 5.0000e-05
# Epoch 3/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8331 - accuracy: 0.5476 - val_loss: 0.6179 - val_accuracy: 0.6475 - lr: 5.0000e-05
# Epoch 4/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8060 - accuracy: 0.5456 - val_loss: 0.5961 - val_accuracy: 0.6650 - lr: 5.0000e-05
# Epoch 5/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.7803 - accuracy: 0.5564 - val_loss: 0.5852 - val_accuracy: 0.6800 - lr: 5.0000e-05
# Epoch 6/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.7527 - accuracy: 0.5783 - val_loss: 0.5791 - val_accuracy: 0.6775 - lr: 5.0000e-05
# Epoch 7/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.7509 - accuracy: 0.5752 - val_loss: 0.5688 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 8/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.7323 - accuracy: 0.5882 - val_loss: 0.5608 - val_accuracy: 0.7025 - lr: 5.0000e-05
# Epoch 9/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7147 - accuracy: 0.5987 - val_loss: 0.5535 - val_accuracy: 0.7075 - lr: 5.0000e-05
# Epoch 10/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7020 - accuracy: 0.5985 - val_loss: 0.5492 - val_accuracy: 0.7050 - lr: 5.0000e-05
# Epoch 11/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6859 - accuracy: 0.6065 - val_loss: 0.5467 - val_accuracy: 0.7125 - lr: 5.0000e-05
# Epoch 12/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6799 - accuracy: 0.6123 - val_loss: 0.5402 - val_accuracy: 0.7175 - lr: 5.0000e-05
# Epoch 13/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6817 - accuracy: 0.6291 - val_loss: 0.5376 - val_accuracy: 0.7275 - lr: 5.0000e-05
# Epoch 14/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6713 - accuracy: 0.6366 - val_loss: 0.5353 - val_accuracy: 0.7350 - lr: 5.0000e-05
# Epoch 15/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6647 - accuracy: 0.6380 - val_loss: 0.5312 - val_accuracy: 0.7475 - lr: 5.0000e-05
# Epoch 16/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6591 - accuracy: 0.6361 - val_loss: 0.5288 - val_accuracy: 0.7425 - lr: 5.0000e-05
# Epoch 17/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6560 - accuracy: 0.6427 - val_loss: 0.5253 - val_accuracy: 0.7350 - lr: 5.0000e-05
# Epoch 18/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6588 - accuracy: 0.6289 - val_loss: 0.5245 - val_accuracy: 0.7575 - lr: 5.0000e-05
# Epoch 19/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6450 - accuracy: 0.6510 - val_loss: 0.5179 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 20/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6363 - accuracy: 0.6557 - val_loss: 0.5162 - val_accuracy: 0.7550 - lr: 5.0000e-05
# Epoch 21/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6338 - accuracy: 0.6513 - val_loss: 0.5117 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 22/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6257 - accuracy: 0.6560 - val_loss: 0.5084 - val_accuracy: 0.7700 - lr: 5.0000e-05
# Epoch 23/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6241 - accuracy: 0.6695 - val_loss: 0.5055 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 24/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6284 - accuracy: 0.6687 - val_loss: 0.5022 - val_accuracy: 0.7550 - lr: 5.0000e-05
# Epoch 25/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6167 - accuracy: 0.6905 - val_loss: 0.4981 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 26/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6146 - accuracy: 0.6742 - val_loss: 0.4939 - val_accuracy: 0.7525 - lr: 5.0000e-05
# Epoch 27/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6148 - accuracy: 0.6745 - val_loss: 0.4931 - val_accuracy: 0.7525 - lr: 5.0000e-05
# Epoch 28/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5990 - accuracy: 0.6988 - val_loss: 0.4905 - val_accuracy: 0.7650 - lr: 5.0000e-05
# Epoch 29/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5954 - accuracy: 0.6889 - val_loss: 0.4851 - val_accuracy: 0.7875 - lr: 5.0000e-05
# Epoch 30/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6041 - accuracy: 0.6972 - val_loss: 0.4796 - val_accuracy: 0.7900 - lr: 5.0000e-05
# Epoch 31/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5965 - accuracy: 0.6889 - val_loss: 0.4804 - val_accuracy: 0.7900 - lr: 5.0000e-05
# Epoch 32/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5919 - accuracy: 0.7027 - val_loss: 0.4774 - val_accuracy: 0.7925 - lr: 5.0000e-05
# Epoch 33/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5885 - accuracy: 0.6972 - val_loss: 0.4740 - val_accuracy: 0.7925 - lr: 5.0000e-05
# Epoch 34/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5923 - accuracy: 0.7060 - val_loss: 0.4735 - val_accuracy: 0.7950 - lr: 5.0000e-05
# Epoch 35/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5788 - accuracy: 0.7152 - val_loss: 0.4707 - val_accuracy: 0.7975 - lr: 5.0000e-05
# Epoch 36/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5790 - accuracy: 0.7129 - val_loss: 0.4691 - val_accuracy: 0.7925 - lr: 5.0000e-05
# Epoch 37/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5733 - accuracy: 0.7199 - val_loss: 0.4696 - val_accuracy: 0.7925 - lr: 5.0000e-05
# Epoch 38/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5686 - accuracy: 0.7196 - val_loss: 0.4649 - val_accuracy: 0.7925 - lr: 5.0000e-05
# Epoch 39/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5674 - accuracy: 0.7262 - val_loss: 0.4651 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 40/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5673 - accuracy: 0.7212 - val_loss: 0.4629 - val_accuracy: 0.8025 - lr: 5.0000e-05
# Epoch 41/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5650 - accuracy: 0.7176 - val_loss: 0.4587 - val_accuracy: 0.8050 - lr: 5.0000e-05
# Epoch 42/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5638 - accuracy: 0.7265 - val_loss: 0.4611 - val_accuracy: 0.8075 - lr: 5.0000e-05
# Epoch 43/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5556 - accuracy: 0.7235 - val_loss: 0.4585 - val_accuracy: 0.8075 - lr: 5.0000e-05
# Epoch 44/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5548 - accuracy: 0.7340 - val_loss: 0.4518 - val_accuracy: 0.8100 - lr: 5.0000e-05
# Epoch 45/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5561 - accuracy: 0.7323 - val_loss: 0.4538 - val_accuracy: 0.8175 - lr: 5.0000e-05
# Epoch 46/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5427 - accuracy: 0.7439 - val_loss: 0.4516 - val_accuracy: 0.8150 - lr: 5.0000e-05
# Epoch 47/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5392 - accuracy: 0.7434 - val_loss: 0.4527 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 48/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5402 - accuracy: 0.7453 - val_loss: 0.4525 - val_accuracy: 0.8175 - lr: 5.0000e-05
# Epoch 49/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5278 - accuracy: 0.7412 - val_loss: 0.4464 - val_accuracy: 0.8150 - lr: 5.0000e-05
# Epoch 50/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5324 - accuracy: 0.7453 - val_loss: 0.4499 - val_accuracy: 0.8150 - lr: 5.0000e-05
# Epoch 51/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5306 - accuracy: 0.7528 - val_loss: 0.4537 - val_accuracy: 0.8100 - lr: 5.0000e-05
# Epoch 52/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5278 - accuracy: 0.7506 - val_loss: 0.4519 - val_accuracy: 0.8075 - lr: 5.0000e-05
# Epoch 53/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5276 - accuracy: 0.7528 - val_loss: 0.4513 - val_accuracy: 0.8075 - lr: 5.0000e-05
# Epoch 54/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5127 - accuracy: 0.7547 - val_loss: 0.4514 - val_accuracy: 0.8075 - lr: 5.0000e-05
# Epoch 55/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5065 - accuracy: 0.7735 - val_loss: 0.4606 - val_accuracy: 0.8050 - lr: 5.0000e-05
# Epoch 56/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5067 - accuracy: 0.7550 - val_loss: 0.4565 - val_accuracy: 0.8050 - lr: 2.5000e-05
# Epoch 57/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5086 - accuracy: 0.7627 - val_loss: 0.4561 - val_accuracy: 0.8025 - lr: 2.5000e-05
# Epoch 58/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4978 - accuracy: 0.7641 - val_loss: 0.4512 - val_accuracy: 0.8050 - lr: 2.5000e-05
# Epoch 59/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5035 - accuracy: 0.7660 - val_loss: 0.4580 - val_accuracy: 0.8025 - lr: 2.5000e-05
# Epoch 60/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5025 - accuracy: 0.7710 - val_loss: 0.4564 - val_accuracy: 0.8025 - lr: 2.5000e-05
# Epoch 61/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4894 - accuracy: 0.7718 - val_loss: 0.4629 - val_accuracy: 0.8025 - lr: 2.5000e-05
# Epoch 1/80
# 57/57 [==============================] - 2s 11ms/step - loss: 1.0141 - accuracy: 0.4770 - val_loss: 0.8128 - val_accuracy: 0.4575 - lr: 5.0000e-05
# Epoch 2/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8921 - accuracy: 0.5097 - val_loss: 0.7320 - val_accuracy: 0.5325 - lr: 5.0000e-05
# Epoch 3/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.8600 - accuracy: 0.5224 - val_loss: 0.6824 - val_accuracy: 0.6675 - lr: 5.0000e-05
# Epoch 4/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.8159 - accuracy: 0.5415 - val_loss: 0.6474 - val_accuracy: 0.6700 - lr: 5.0000e-05
# Epoch 5/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7672 - accuracy: 0.5730 - val_loss: 0.6265 - val_accuracy: 0.6775 - lr: 5.0000e-05
# Epoch 6/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7676 - accuracy: 0.5686 - val_loss: 0.6114 - val_accuracy: 0.6850 - lr: 5.0000e-05
# Epoch 7/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7398 - accuracy: 0.5791 - val_loss: 0.5959 - val_accuracy: 0.6900 - lr: 5.0000e-05
# Epoch 8/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7285 - accuracy: 0.6034 - val_loss: 0.5811 - val_accuracy: 0.7050 - lr: 5.0000e-05
# Epoch 9/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7242 - accuracy: 0.5949 - val_loss: 0.5716 - val_accuracy: 0.7200 - lr: 5.0000e-05
# Epoch 10/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7019 - accuracy: 0.6081 - val_loss: 0.5682 - val_accuracy: 0.7250 - lr: 5.0000e-05
# Epoch 11/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.7025 - accuracy: 0.6090 - val_loss: 0.5606 - val_accuracy: 0.7350 - lr: 5.0000e-05
# Epoch 12/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6809 - accuracy: 0.6247 - val_loss: 0.5532 - val_accuracy: 0.7350 - lr: 5.0000e-05
# Epoch 13/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6754 - accuracy: 0.6311 - val_loss: 0.5473 - val_accuracy: 0.7275 - lr: 5.0000e-05
# Epoch 14/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6626 - accuracy: 0.6341 - val_loss: 0.5448 - val_accuracy: 0.7400 - lr: 5.0000e-05
# Epoch 15/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6601 - accuracy: 0.6374 - val_loss: 0.5443 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 16/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6542 - accuracy: 0.6471 - val_loss: 0.5398 - val_accuracy: 0.7425 - lr: 5.0000e-05
# Epoch 17/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6422 - accuracy: 0.6496 - val_loss: 0.5340 - val_accuracy: 0.7475 - lr: 5.0000e-05
# Epoch 18/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6575 - accuracy: 0.6410 - val_loss: 0.5314 - val_accuracy: 0.7550 - lr: 5.0000e-05
# Epoch 19/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6399 - accuracy: 0.6565 - val_loss: 0.5303 - val_accuracy: 0.7575 - lr: 5.0000e-05
# Epoch 20/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6401 - accuracy: 0.6532 - val_loss: 0.5252 - val_accuracy: 0.7600 - lr: 5.0000e-05
# Epoch 21/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6389 - accuracy: 0.6607 - val_loss: 0.5181 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 22/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6342 - accuracy: 0.6687 - val_loss: 0.5180 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 23/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6277 - accuracy: 0.6717 - val_loss: 0.5142 - val_accuracy: 0.7650 - lr: 5.0000e-05
# Epoch 24/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6294 - accuracy: 0.6634 - val_loss: 0.5097 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 25/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6264 - accuracy: 0.6695 - val_loss: 0.5069 - val_accuracy: 0.7650 - lr: 5.0000e-05
# Epoch 26/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6159 - accuracy: 0.6861 - val_loss: 0.5009 - val_accuracy: 0.7650 - lr: 5.0000e-05
# Epoch 27/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6145 - accuracy: 0.6850 - val_loss: 0.4965 - val_accuracy: 0.7675 - lr: 5.0000e-05
# Epoch 28/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6005 - accuracy: 0.6853 - val_loss: 0.4920 - val_accuracy: 0.7675 - lr: 5.0000e-05
# Epoch 29/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6100 - accuracy: 0.6856 - val_loss: 0.4888 - val_accuracy: 0.7575 - lr: 5.0000e-05
# Epoch 30/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5990 - accuracy: 0.6908 - val_loss: 0.4830 - val_accuracy: 0.7600 - lr: 5.0000e-05
# Epoch 31/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5982 - accuracy: 0.6905 - val_loss: 0.4786 - val_accuracy: 0.7675 - lr: 5.0000e-05
# Epoch 32/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.6043 - accuracy: 0.6911 - val_loss: 0.4711 - val_accuracy: 0.7725 - lr: 5.0000e-05
# Epoch 33/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5987 - accuracy: 0.6944 - val_loss: 0.4662 - val_accuracy: 0.7800 - lr: 5.0000e-05
# Epoch 34/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5898 - accuracy: 0.7066 - val_loss: 0.4625 - val_accuracy: 0.7825 - lr: 5.0000e-05
# Epoch 35/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5848 - accuracy: 0.7082 - val_loss: 0.4555 - val_accuracy: 0.7800 - lr: 5.0000e-05
# Epoch 36/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5834 - accuracy: 0.7135 - val_loss: 0.4492 - val_accuracy: 0.7900 - lr: 5.0000e-05
# Epoch 37/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5768 - accuracy: 0.7074 - val_loss: 0.4391 - val_accuracy: 0.7900 - lr: 5.0000e-05
# Epoch 38/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5835 - accuracy: 0.7105 - val_loss: 0.4363 - val_accuracy: 0.8075 - lr: 5.0000e-05
# Epoch 39/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5746 - accuracy: 0.7110 - val_loss: 0.4282 - val_accuracy: 0.8050 - lr: 5.0000e-05
# Epoch 40/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5749 - accuracy: 0.7179 - val_loss: 0.4257 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 41/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5723 - accuracy: 0.7190 - val_loss: 0.4219 - val_accuracy: 0.8100 - lr: 5.0000e-05
# Epoch 42/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5637 - accuracy: 0.7306 - val_loss: 0.4180 - val_accuracy: 0.8100 - lr: 5.0000e-05
# Epoch 43/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5628 - accuracy: 0.7259 - val_loss: 0.4084 - val_accuracy: 0.8175 - lr: 5.0000e-05
# Epoch 44/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5542 - accuracy: 0.7329 - val_loss: 0.4061 - val_accuracy: 0.8200 - lr: 5.0000e-05
# Epoch 45/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5574 - accuracy: 0.7304 - val_loss: 0.4017 - val_accuracy: 0.8225 - lr: 5.0000e-05
# Epoch 46/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5526 - accuracy: 0.7384 - val_loss: 0.3917 - val_accuracy: 0.8200 - lr: 5.0000e-05
# Epoch 47/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5473 - accuracy: 0.7356 - val_loss: 0.3841 - val_accuracy: 0.8225 - lr: 5.0000e-05
# Epoch 48/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5471 - accuracy: 0.7345 - val_loss: 0.3816 - val_accuracy: 0.8200 - lr: 5.0000e-05
# Epoch 49/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5422 - accuracy: 0.7395 - val_loss: 0.3745 - val_accuracy: 0.8250 - lr: 5.0000e-05
# Epoch 50/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5448 - accuracy: 0.7445 - val_loss: 0.3699 - val_accuracy: 0.8300 - lr: 5.0000e-05
# Epoch 51/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5312 - accuracy: 0.7406 - val_loss: 0.3665 - val_accuracy: 0.8300 - lr: 5.0000e-05
# Epoch 52/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5326 - accuracy: 0.7436 - val_loss: 0.3604 - val_accuracy: 0.8300 - lr: 5.0000e-05
# Epoch 53/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5360 - accuracy: 0.7497 - val_loss: 0.3577 - val_accuracy: 0.8300 - lr: 5.0000e-05
# Epoch 54/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5234 - accuracy: 0.7530 - val_loss: 0.3531 - val_accuracy: 0.8300 - lr: 5.0000e-05
# Epoch 55/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5237 - accuracy: 0.7519 - val_loss: 0.3456 - val_accuracy: 0.8325 - lr: 5.0000e-05
# Epoch 56/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5301 - accuracy: 0.7514 - val_loss: 0.3399 - val_accuracy: 0.8325 - lr: 5.0000e-05
# Epoch 57/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5131 - accuracy: 0.7658 - val_loss: 0.3346 - val_accuracy: 0.8375 - lr: 5.0000e-05
# Epoch 58/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5128 - accuracy: 0.7591 - val_loss: 0.3305 - val_accuracy: 0.8375 - lr: 5.0000e-05
# Epoch 59/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5139 - accuracy: 0.7533 - val_loss: 0.3231 - val_accuracy: 0.8350 - lr: 5.0000e-05
# Epoch 60/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5036 - accuracy: 0.7677 - val_loss: 0.3203 - val_accuracy: 0.8400 - lr: 5.0000e-05
# Epoch 61/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5067 - accuracy: 0.7630 - val_loss: 0.3136 - val_accuracy: 0.8450 - lr: 5.0000e-05
# Epoch 62/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5041 - accuracy: 0.7671 - val_loss: 0.3078 - val_accuracy: 0.8450 - lr: 5.0000e-05
# Epoch 63/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4889 - accuracy: 0.7757 - val_loss: 0.3047 - val_accuracy: 0.8425 - lr: 5.0000e-05
# Epoch 64/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4915 - accuracy: 0.7749 - val_loss: 0.2983 - val_accuracy: 0.8450 - lr: 5.0000e-05
# Epoch 65/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4879 - accuracy: 0.7765 - val_loss: 0.2941 - val_accuracy: 0.8525 - lr: 5.0000e-05
# Epoch 66/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4924 - accuracy: 0.7746 - val_loss: 0.2892 - val_accuracy: 0.8650 - lr: 5.0000e-05
# Epoch 67/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4694 - accuracy: 0.7868 - val_loss: 0.2821 - val_accuracy: 0.8650 - lr: 5.0000e-05
# Epoch 68/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4719 - accuracy: 0.7901 - val_loss: 0.2779 - val_accuracy: 0.8650 - lr: 5.0000e-05
# Epoch 69/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4620 - accuracy: 0.7846 - val_loss: 0.2738 - val_accuracy: 0.8675 - lr: 5.0000e-05
# Epoch 70/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4631 - accuracy: 0.7973 - val_loss: 0.2691 - val_accuracy: 0.8700 - lr: 5.0000e-05
# Epoch 71/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4698 - accuracy: 0.7876 - val_loss: 0.2675 - val_accuracy: 0.8675 - lr: 5.0000e-05
# Epoch 72/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4533 - accuracy: 0.7962 - val_loss: 0.2643 - val_accuracy: 0.8700 - lr: 5.0000e-05
# Epoch 73/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4565 - accuracy: 0.7976 - val_loss: 0.2647 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 74/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4493 - accuracy: 0.7962 - val_loss: 0.2605 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 75/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4581 - accuracy: 0.7995 - val_loss: 0.2573 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 76/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4469 - accuracy: 0.8003 - val_loss: 0.2541 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 77/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4426 - accuracy: 0.8017 - val_loss: 0.2522 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 78/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4421 - accuracy: 0.8064 - val_loss: 0.2517 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 79/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4391 - accuracy: 0.8056 - val_loss: 0.2489 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 80/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4283 - accuracy: 0.8155 - val_loss: 0.2515 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 1/80
# 59/59 [==============================] - 1s 11ms/step - loss: 1.0159 - accuracy: 0.4942 - val_loss: 0.7080 - val_accuracy: 0.5333 - lr: 5.0000e-05
# Epoch 2/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.9114 - accuracy: 0.5090 - val_loss: 0.6678 - val_accuracy: 0.5958 - lr: 5.0000e-05
# Epoch 3/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.8526 - accuracy: 0.5405 - val_loss: 0.6834 - val_accuracy: 0.6042 - lr: 5.0000e-05
# Epoch 4/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.7992 - accuracy: 0.5599 - val_loss: 0.6883 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 5/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.7927 - accuracy: 0.5694 - val_loss: 0.6894 - val_accuracy: 0.5792 - lr: 5.0000e-05
# Epoch 6/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.7514 - accuracy: 0.5802 - val_loss: 0.6939 - val_accuracy: 0.5792 - lr: 5.0000e-05
# Epoch 7/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.7490 - accuracy: 0.5887 - val_loss: 0.6912 - val_accuracy: 0.5708 - lr: 5.0000e-05
# Epoch 8/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.7206 - accuracy: 0.6041 - val_loss: 0.6812 - val_accuracy: 0.5750 - lr: 5.0000e-05
# Epoch 9/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.6991 - accuracy: 0.6176 - val_loss: 0.6734 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 10/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.7191 - accuracy: 0.6004 - val_loss: 0.6713 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 11/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.7051 - accuracy: 0.6065 - val_loss: 0.6706 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 12/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6977 - accuracy: 0.6078 - val_loss: 0.6674 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 13/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6834 - accuracy: 0.6274 - val_loss: 0.6661 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 14/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6806 - accuracy: 0.6274 - val_loss: 0.6633 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 15/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6773 - accuracy: 0.6186 - val_loss: 0.6615 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 16/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6663 - accuracy: 0.6393 - val_loss: 0.6608 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 17/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6667 - accuracy: 0.6314 - val_loss: 0.6614 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 18/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6763 - accuracy: 0.6210 - val_loss: 0.6593 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 19/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6648 - accuracy: 0.6364 - val_loss: 0.6581 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 20/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6600 - accuracy: 0.6451 - val_loss: 0.6573 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 21/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6578 - accuracy: 0.6343 - val_loss: 0.6561 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 22/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6586 - accuracy: 0.6377 - val_loss: 0.6533 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 23/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6522 - accuracy: 0.6441 - val_loss: 0.6526 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 24/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6636 - accuracy: 0.6316 - val_loss: 0.6511 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 25/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6482 - accuracy: 0.6396 - val_loss: 0.6488 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 26/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6521 - accuracy: 0.6380 - val_loss: 0.6493 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 27/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6362 - accuracy: 0.6592 - val_loss: 0.6478 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 28/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6477 - accuracy: 0.6369 - val_loss: 0.6489 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 29/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6304 - accuracy: 0.6608 - val_loss: 0.6463 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 30/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6260 - accuracy: 0.6623 - val_loss: 0.6461 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 31/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6265 - accuracy: 0.6568 - val_loss: 0.6447 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 32/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6232 - accuracy: 0.6610 - val_loss: 0.6445 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 33/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6181 - accuracy: 0.6666 - val_loss: 0.6448 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 34/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6226 - accuracy: 0.6671 - val_loss: 0.6441 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 35/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6234 - accuracy: 0.6660 - val_loss: 0.6422 - val_accuracy: 0.5708 - lr: 2.5000e-05
# Epoch 36/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6142 - accuracy: 0.6756 - val_loss: 0.6411 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 37/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6181 - accuracy: 0.6642 - val_loss: 0.6409 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 38/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6072 - accuracy: 0.6743 - val_loss: 0.6404 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 39/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6203 - accuracy: 0.6658 - val_loss: 0.6405 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 40/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6069 - accuracy: 0.6774 - val_loss: 0.6394 - val_accuracy: 0.5667 - lr: 2.5000e-05
# Epoch 41/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5966 - accuracy: 0.6846 - val_loss: 0.6379 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 42/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6101 - accuracy: 0.6751 - val_loss: 0.6378 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 43/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6060 - accuracy: 0.6796 - val_loss: 0.6367 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 44/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.6110 - accuracy: 0.6777 - val_loss: 0.6356 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 45/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6055 - accuracy: 0.6777 - val_loss: 0.6337 - val_accuracy: 0.5792 - lr: 2.5000e-05
# Epoch 46/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6051 - accuracy: 0.6827 - val_loss: 0.6332 - val_accuracy: 0.5792 - lr: 2.5000e-05
# Epoch 47/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.6011 - accuracy: 0.6894 - val_loss: 0.6313 - val_accuracy: 0.5875 - lr: 2.5000e-05
# Epoch 48/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5968 - accuracy: 0.6933 - val_loss: 0.6314 - val_accuracy: 0.5833 - lr: 2.5000e-05
# Epoch 49/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5970 - accuracy: 0.6825 - val_loss: 0.6317 - val_accuracy: 0.5792 - lr: 2.5000e-05
# Epoch 50/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5903 - accuracy: 0.6931 - val_loss: 0.6315 - val_accuracy: 0.5792 - lr: 2.5000e-05
# Epoch 51/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5930 - accuracy: 0.6986 - val_loss: 0.6296 - val_accuracy: 0.5917 - lr: 2.5000e-05
# Epoch 52/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5886 - accuracy: 0.6915 - val_loss: 0.6285 - val_accuracy: 0.5917 - lr: 2.5000e-05
# Epoch 53/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5825 - accuracy: 0.6973 - val_loss: 0.6295 - val_accuracy: 0.5875 - lr: 2.5000e-05
# Epoch 54/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5846 - accuracy: 0.6970 - val_loss: 0.6264 - val_accuracy: 0.5958 - lr: 2.5000e-05
# Epoch 55/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5806 - accuracy: 0.7023 - val_loss: 0.6251 - val_accuracy: 0.6125 - lr: 2.5000e-05
# Epoch 56/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5776 - accuracy: 0.6999 - val_loss: 0.6248 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 57/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5851 - accuracy: 0.6981 - val_loss: 0.6251 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 58/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5750 - accuracy: 0.7002 - val_loss: 0.6245 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 59/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5718 - accuracy: 0.6989 - val_loss: 0.6240 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 60/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5805 - accuracy: 0.7015 - val_loss: 0.6238 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 61/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5777 - accuracy: 0.7066 - val_loss: 0.6239 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 62/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5762 - accuracy: 0.7066 - val_loss: 0.6226 - val_accuracy: 0.6292 - lr: 2.5000e-05
# Epoch 63/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5774 - accuracy: 0.7039 - val_loss: 0.6240 - val_accuracy: 0.6125 - lr: 2.5000e-05
# Epoch 64/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5714 - accuracy: 0.7103 - val_loss: 0.6226 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 65/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5612 - accuracy: 0.7124 - val_loss: 0.6217 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 66/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5614 - accuracy: 0.7201 - val_loss: 0.6222 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 67/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5621 - accuracy: 0.7148 - val_loss: 0.6218 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 68/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5672 - accuracy: 0.7211 - val_loss: 0.6231 - val_accuracy: 0.6208 - lr: 2.5000e-05
# Epoch 69/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5632 - accuracy: 0.7132 - val_loss: 0.6240 - val_accuracy: 0.6125 - lr: 2.5000e-05
# Epoch 70/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5657 - accuracy: 0.7166 - val_loss: 0.6227 - val_accuracy: 0.6333 - lr: 2.5000e-05
# Epoch 71/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.5485 - accuracy: 0.7211 - val_loss: 0.6199 - val_accuracy: 0.6417 - lr: 2.5000e-05
# Epoch 72/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5667 - accuracy: 0.7137 - val_loss: 0.6200 - val_accuracy: 0.6375 - lr: 2.5000e-05
# Epoch 73/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5465 - accuracy: 0.7275 - val_loss: 0.6184 - val_accuracy: 0.6417 - lr: 2.5000e-05
# Epoch 74/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5527 - accuracy: 0.7251 - val_loss: 0.6194 - val_accuracy: 0.6458 - lr: 2.5000e-05
# Epoch 75/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5471 - accuracy: 0.7299 - val_loss: 0.6161 - val_accuracy: 0.6667 - lr: 2.5000e-05
# Epoch 76/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5570 - accuracy: 0.7206 - val_loss: 0.6167 - val_accuracy: 0.6708 - lr: 2.5000e-05
# Epoch 77/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5432 - accuracy: 0.7336 - val_loss: 0.6155 - val_accuracy: 0.6708 - lr: 2.5000e-05
# Epoch 78/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5462 - accuracy: 0.7259 - val_loss: 0.6151 - val_accuracy: 0.6792 - lr: 2.5000e-05
# Epoch 79/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5520 - accuracy: 0.7267 - val_loss: 0.6153 - val_accuracy: 0.6833 - lr: 2.5000e-05
# Epoch 80/80
# 59/59 [==============================] - 0s 5ms/step - loss: 0.5456 - accuracy: 0.7381 - val_loss: 0.6160 - val_accuracy: 0.6792 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 2s 11ms/step - loss: 0.9443 - accuracy: 0.5270 - val_loss: 0.7200 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8935 - accuracy: 0.5389 - val_loss: 0.6829 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8352 - accuracy: 0.5612 - val_loss: 0.6707 - val_accuracy: 0.6500 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8091 - accuracy: 0.5796 - val_loss: 0.6656 - val_accuracy: 0.6187 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.7847 - accuracy: 0.5744 - val_loss: 0.6657 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.7478 - accuracy: 0.6048 - val_loss: 0.6704 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7467 - accuracy: 0.5983 - val_loss: 0.6673 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7187 - accuracy: 0.6055 - val_loss: 0.6631 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6980 - accuracy: 0.6367 - val_loss: 0.6634 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.7019 - accuracy: 0.6242 - val_loss: 0.6672 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6909 - accuracy: 0.6291 - val_loss: 0.6689 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6782 - accuracy: 0.6253 - val_loss: 0.6685 - val_accuracy: 0.5938 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6635 - accuracy: 0.6424 - val_loss: 0.6699 - val_accuracy: 0.5875 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6671 - accuracy: 0.6445 - val_loss: 0.6749 - val_accuracy: 0.5750 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6492 - accuracy: 0.6525 - val_loss: 0.6750 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 16/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6380 - accuracy: 0.6623 - val_loss: 0.6787 - val_accuracy: 0.5562 - lr: 2.5000e-05
# Epoch 17/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6540 - accuracy: 0.6483 - val_loss: 0.6810 - val_accuracy: 0.5500 - lr: 2.5000e-05
# Epoch 18/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6432 - accuracy: 0.6657 - val_loss: 0.6831 - val_accuracy: 0.5562 - lr: 2.5000e-05
# Epoch 19/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6417 - accuracy: 0.6590 - val_loss: 0.6845 - val_accuracy: 0.5500 - lr: 2.5000e-05
# Epoch 20/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6240 - accuracy: 0.6704 - val_loss: 0.6882 - val_accuracy: 0.5375 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 2s 11ms/step - loss: 1.0172 - accuracy: 0.5104 - val_loss: 1.0347 - val_accuracy: 0.4250 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.8965 - accuracy: 0.5451 - val_loss: 0.9257 - val_accuracy: 0.4187 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.8238 - accuracy: 0.5716 - val_loss: 0.8676 - val_accuracy: 0.4500 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8129 - accuracy: 0.5781 - val_loss: 0.8251 - val_accuracy: 0.4938 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7815 - accuracy: 0.5954 - val_loss: 0.7944 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7714 - accuracy: 0.5900 - val_loss: 0.7706 - val_accuracy: 0.5188 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7445 - accuracy: 0.6030 - val_loss: 0.7496 - val_accuracy: 0.5188 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7309 - accuracy: 0.6177 - val_loss: 0.7385 - val_accuracy: 0.5250 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7154 - accuracy: 0.6206 - val_loss: 0.7236 - val_accuracy: 0.5125 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7069 - accuracy: 0.6227 - val_loss: 0.7111 - val_accuracy: 0.5188 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6911 - accuracy: 0.6263 - val_loss: 0.7018 - val_accuracy: 0.5375 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6654 - accuracy: 0.6447 - val_loss: 0.6961 - val_accuracy: 0.5312 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6665 - accuracy: 0.6533 - val_loss: 0.6910 - val_accuracy: 0.5437 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6674 - accuracy: 0.6478 - val_loss: 0.6854 - val_accuracy: 0.5562 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6495 - accuracy: 0.6613 - val_loss: 0.6785 - val_accuracy: 0.5688 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6511 - accuracy: 0.6566 - val_loss: 0.6761 - val_accuracy: 0.5562 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6420 - accuracy: 0.6608 - val_loss: 0.6709 - val_accuracy: 0.5688 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6426 - accuracy: 0.6649 - val_loss: 0.6692 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6339 - accuracy: 0.6751 - val_loss: 0.6645 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 20/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.6281 - accuracy: 0.6763 - val_loss: 0.6622 - val_accuracy: 0.5437 - lr: 5.0000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.6154 - accuracy: 0.6862 - val_loss: 0.6621 - val_accuracy: 0.5500 - lr: 5.0000e-05
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6190 - accuracy: 0.6706 - val_loss: 0.6598 - val_accuracy: 0.5500 - lr: 5.0000e-05
# Epoch 23/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6135 - accuracy: 0.6839 - val_loss: 0.6541 - val_accuracy: 0.5500 - lr: 5.0000e-05
# Epoch 24/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6025 - accuracy: 0.6950 - val_loss: 0.6545 - val_accuracy: 0.5375 - lr: 5.0000e-05
# Epoch 25/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5955 - accuracy: 0.6958 - val_loss: 0.6488 - val_accuracy: 0.5500 - lr: 5.0000e-05
# Epoch 26/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5942 - accuracy: 0.6968 - val_loss: 0.6467 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 27/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6020 - accuracy: 0.6945 - val_loss: 0.6414 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 28/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5835 - accuracy: 0.7114 - val_loss: 0.6398 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 29/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5825 - accuracy: 0.7085 - val_loss: 0.6411 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 30/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5764 - accuracy: 0.7152 - val_loss: 0.6370 - val_accuracy: 0.5688 - lr: 5.0000e-05
# Epoch 31/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5766 - accuracy: 0.7142 - val_loss: 0.6327 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 32/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5739 - accuracy: 0.7217 - val_loss: 0.6273 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 33/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5645 - accuracy: 0.7189 - val_loss: 0.6248 - val_accuracy: 0.5875 - lr: 5.0000e-05
# Epoch 34/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5587 - accuracy: 0.7233 - val_loss: 0.6251 - val_accuracy: 0.5875 - lr: 5.0000e-05
# Epoch 35/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5610 - accuracy: 0.7256 - val_loss: 0.6258 - val_accuracy: 0.5750 - lr: 5.0000e-05
# Epoch 36/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5546 - accuracy: 0.7344 - val_loss: 0.6156 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 37/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.5416 - accuracy: 0.7440 - val_loss: 0.6094 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 38/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.5391 - accuracy: 0.7482 - val_loss: 0.6072 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 39/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.5437 - accuracy: 0.7376 - val_loss: 0.6036 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 40/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5423 - accuracy: 0.7274 - val_loss: 0.6039 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 41/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5326 - accuracy: 0.7453 - val_loss: 0.6026 - val_accuracy: 0.6438 - lr: 5.0000e-05
# Epoch 42/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5350 - accuracy: 0.7521 - val_loss: 0.5993 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 43/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5318 - accuracy: 0.7487 - val_loss: 0.5936 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 44/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5266 - accuracy: 0.7516 - val_loss: 0.5935 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 45/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.5140 - accuracy: 0.7591 - val_loss: 0.5875 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 46/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.5127 - accuracy: 0.7534 - val_loss: 0.5878 - val_accuracy: 0.6500 - lr: 5.0000e-05
# Epoch 47/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5085 - accuracy: 0.7599 - val_loss: 0.5825 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 48/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.4922 - accuracy: 0.7835 - val_loss: 0.5732 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 49/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5006 - accuracy: 0.7645 - val_loss: 0.5745 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 50/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4953 - accuracy: 0.7707 - val_loss: 0.5695 - val_accuracy: 0.6750 - lr: 5.0000e-05
# Epoch 51/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4870 - accuracy: 0.7777 - val_loss: 0.5656 - val_accuracy: 0.6750 - lr: 5.0000e-05
# Epoch 52/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4875 - accuracy: 0.7793 - val_loss: 0.5625 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 53/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4859 - accuracy: 0.7772 - val_loss: 0.5563 - val_accuracy: 0.6938 - lr: 5.0000e-05
# Epoch 54/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4887 - accuracy: 0.7720 - val_loss: 0.5642 - val_accuracy: 0.6812 - lr: 5.0000e-05
# Epoch 55/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4746 - accuracy: 0.7853 - val_loss: 0.5683 - val_accuracy: 0.6938 - lr: 5.0000e-05
# Epoch 56/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.4819 - accuracy: 0.7822 - val_loss: 0.5481 - val_accuracy: 0.7063 - lr: 5.0000e-05
# Epoch 57/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.4664 - accuracy: 0.7871 - val_loss: 0.5595 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 58/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4686 - accuracy: 0.7886 - val_loss: 0.5551 - val_accuracy: 0.7312 - lr: 5.0000e-05
# Epoch 59/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.4537 - accuracy: 0.7943 - val_loss: 0.5470 - val_accuracy: 0.7375 - lr: 5.0000e-05
# Epoch 60/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.4538 - accuracy: 0.7964 - val_loss: 0.5626 - val_accuracy: 0.7375 - lr: 5.0000e-05
# Epoch 61/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4602 - accuracy: 0.7912 - val_loss: 0.5702 - val_accuracy: 0.7125 - lr: 5.0000e-05
# Epoch 62/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.4370 - accuracy: 0.8099 - val_loss: 0.5717 - val_accuracy: 0.7250 - lr: 5.0000e-05
# Epoch 63/80
# ...
# Epoch 28/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5933 - accuracy: 0.7031 - val_loss: 0.4946 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 29/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5914 - accuracy: 0.7025 - val_loss: 0.4923 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 30/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5825 - accuracy: 0.7137 - val_loss: 0.4907 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 31/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5872 - accuracy: 0.7103 - val_loss: 0.4888 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 32/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5829 - accuracy: 0.7095 - val_loss: 0.4884 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 33/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5806 - accuracy: 0.7127 - val_loss: 0.4890 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 34/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5692 - accuracy: 0.7383 - val_loss: 0.4889 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 35/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5696 - accuracy: 0.7223 - val_loss: 0.4883 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 36/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5686 - accuracy: 0.7261 - val_loss: 0.4880 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 37/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5606 - accuracy: 0.7331 - val_loss: 0.4854 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 38/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5494 - accuracy: 0.7251 - val_loss: 0.4860 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 39/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5499 - accuracy: 0.7326 - val_loss: 0.4903 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 40/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5495 - accuracy: 0.7347 - val_loss: 0.4890 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 41/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5373 - accuracy: 0.7456 - val_loss: 0.4891 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 42/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5405 - accuracy: 0.7391 - val_loss: 0.4933 - val_accuracy: 0.7437 - lr: 5.0000e-05
# Epoch 43/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5282 - accuracy: 0.7529 - val_loss: 0.4914 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 44/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5371 - accuracy: 0.7487 - val_loss: 0.4896 - val_accuracy: 0.7500 - lr: 2.5000e-05
# Epoch 45/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5332 - accuracy: 0.7562 - val_loss: 0.4907 - val_accuracy: 0.7500 - lr: 2.5000e-05
# Epoch 46/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5258 - accuracy: 0.7573 - val_loss: 0.4901 - val_accuracy: 0.7500 - lr: 2.5000e-05
# Epoch 47/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5249 - accuracy: 0.7588 - val_loss: 0.4906 - val_accuracy: 0.7437 - lr: 2.5000e-05
# Epoch 48/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5252 - accuracy: 0.7518 - val_loss: 0.4881 - val_accuracy: 0.7437 - lr: 2.5000e-05
# Epoch 49/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5192 - accuracy: 0.7567 - val_loss: 0.4886 - val_accuracy: 0.7437 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.9493 - accuracy: 0.5270 - val_loss: 0.7028 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8788 - accuracy: 0.5425 - val_loss: 0.6715 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.8501 - accuracy: 0.5508 - val_loss: 0.6685 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8011 - accuracy: 0.5716 - val_loss: 0.6705 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7678 - accuracy: 0.5915 - val_loss: 0.6678 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7595 - accuracy: 0.5926 - val_loss: 0.6583 - val_accuracy: 0.7125 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7349 - accuracy: 0.6138 - val_loss: 0.6481 - val_accuracy: 0.7000 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7104 - accuracy: 0.6110 - val_loss: 0.6417 - val_accuracy: 0.6625 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6905 - accuracy: 0.6253 - val_loss: 0.6372 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6908 - accuracy: 0.6175 - val_loss: 0.6319 - val_accuracy: 0.5875 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6762 - accuracy: 0.6294 - val_loss: 0.6273 - val_accuracy: 0.5750 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6827 - accuracy: 0.6320 - val_loss: 0.6239 - val_accuracy: 0.5562 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6586 - accuracy: 0.6468 - val_loss: 0.6261 - val_accuracy: 0.5375 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6484 - accuracy: 0.6543 - val_loss: 0.6249 - val_accuracy: 0.5375 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6532 - accuracy: 0.6395 - val_loss: 0.6192 - val_accuracy: 0.5312 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6557 - accuracy: 0.6419 - val_loss: 0.6221 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6327 - accuracy: 0.6680 - val_loss: 0.6183 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6374 - accuracy: 0.6548 - val_loss: 0.6190 - val_accuracy: 0.5875 - lr: 5.0000e-05
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6282 - accuracy: 0.6618 - val_loss: 0.6178 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 20/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6135 - accuracy: 0.6732 - val_loss: 0.6124 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 21/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6197 - accuracy: 0.6701 - val_loss: 0.6081 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6174 - accuracy: 0.6683 - val_loss: 0.6077 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 23/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6164 - accuracy: 0.6769 - val_loss: 0.6046 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 24/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6206 - accuracy: 0.6639 - val_loss: 0.6028 - val_accuracy: 0.6187 - lr: 5.0000e-05
# Epoch 25/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6083 - accuracy: 0.6815 - val_loss: 0.6043 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 26/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5980 - accuracy: 0.6802 - val_loss: 0.6021 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 27/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5989 - accuracy: 0.6810 - val_loss: 0.5991 - val_accuracy: 0.6500 - lr: 5.0000e-05
# Epoch 28/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5876 - accuracy: 0.6904 - val_loss: 0.5948 - val_accuracy: 0.6187 - lr: 5.0000e-05
# Epoch 29/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5977 - accuracy: 0.6878 - val_loss: 0.5940 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 30/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5948 - accuracy: 0.6929 - val_loss: 0.5891 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 31/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6018 - accuracy: 0.6898 - val_loss: 0.5866 - val_accuracy: 0.5938 - lr: 5.0000e-05
# Epoch 32/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5858 - accuracy: 0.6966 - val_loss: 0.5863 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 33/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5905 - accuracy: 0.6922 - val_loss: 0.5868 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 34/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5796 - accuracy: 0.7033 - val_loss: 0.5833 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 35/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5684 - accuracy: 0.7106 - val_loss: 0.5828 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 36/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5826 - accuracy: 0.7036 - val_loss: 0.5813 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 37/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5762 - accuracy: 0.7095 - val_loss: 0.5810 - val_accuracy: 0.6438 - lr: 5.0000e-05
# Epoch 38/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5760 - accuracy: 0.6999 - val_loss: 0.5789 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 39/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5743 - accuracy: 0.7046 - val_loss: 0.5782 - val_accuracy: 0.6438 - lr: 5.0000e-05
# Epoch 40/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5670 - accuracy: 0.7184 - val_loss: 0.5794 - val_accuracy: 0.6438 - lr: 5.0000e-05
# Epoch 41/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5644 - accuracy: 0.7207 - val_loss: 0.5808 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 42/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5686 - accuracy: 0.7137 - val_loss: 0.5818 - val_accuracy: 0.6500 - lr: 5.0000e-05
# Epoch 43/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5605 - accuracy: 0.7212 - val_loss: 0.5820 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 44/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5568 - accuracy: 0.7207 - val_loss: 0.5800 - val_accuracy: 0.6625 - lr: 5.0000e-05
# Epoch 45/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5475 - accuracy: 0.7256 - val_loss: 0.5749 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 46/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5443 - accuracy: 0.7264 - val_loss: 0.5723 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 47/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5424 - accuracy: 0.7430 - val_loss: 0.5727 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 48/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5503 - accuracy: 0.7308 - val_loss: 0.5735 - val_accuracy: 0.6375 - lr: 5.0000e-05
# Epoch 49/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5407 - accuracy: 0.7360 - val_loss: 0.5766 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 50/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5352 - accuracy: 0.7482 - val_loss: 0.5766 - val_accuracy: 0.6375 - lr: 5.0000e-05
# Epoch 51/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5339 - accuracy: 0.7474 - val_loss: 0.5713 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 52/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5239 - accuracy: 0.7484 - val_loss: 0.5738 - val_accuracy: 0.5875 - lr: 5.0000e-05
# Epoch 53/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5198 - accuracy: 0.7526 - val_loss: 0.5818 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 54/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5177 - accuracy: 0.7599 - val_loss: 0.5809 - val_accuracy: 0.5938 - lr: 5.0000e-05
# Epoch 55/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5140 - accuracy: 0.7578 - val_loss: 0.5791 - val_accuracy: 0.5938 - lr: 5.0000e-05
# Epoch 56/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5147 - accuracy: 0.7643 - val_loss: 0.5827 - val_accuracy: 0.5938 - lr: 5.0000e-05
# Epoch 57/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5123 - accuracy: 0.7614 - val_loss: 0.5828 - val_accuracy: 0.5813 - lr: 5.0000e-05
# Epoch 58/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5059 - accuracy: 0.7658 - val_loss: 0.5850 - val_accuracy: 0.5813 - lr: 2.5000e-05
# Epoch 59/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5032 - accuracy: 0.7687 - val_loss: 0.5860 - val_accuracy: 0.5813 - lr: 2.5000e-05
# Epoch 60/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5080 - accuracy: 0.7669 - val_loss: 0.5822 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 61/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5064 - accuracy: 0.7637 - val_loss: 0.5842 - val_accuracy: 0.5813 - lr: 2.5000e-05
# Epoch 62/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5030 - accuracy: 0.7658 - val_loss: 0.5822 - val_accuracy: 0.5813 - lr: 2.5000e-05
# Epoch 63/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5042 - accuracy: 0.7695 - val_loss: 0.5837 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 2s 11ms/step - loss: 0.9037 - accuracy: 0.5534 - val_loss: 0.8824 - val_accuracy: 0.3938 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8617 - accuracy: 0.5537 - val_loss: 0.9623 - val_accuracy: 0.3625 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.8074 - accuracy: 0.5812 - val_loss: 0.9706 - val_accuracy: 0.3625 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7952 - accuracy: 0.5775 - val_loss: 0.9881 - val_accuracy: 0.3500 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7522 - accuracy: 0.6045 - val_loss: 0.9959 - val_accuracy: 0.3625 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7241 - accuracy: 0.6149 - val_loss: 0.9971 - val_accuracy: 0.3750 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7217 - accuracy: 0.6126 - val_loss: 0.9822 - val_accuracy: 0.4062 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7217 - accuracy: 0.6157 - val_loss: 0.9726 - val_accuracy: 0.4062 - lr: 2.5000e-05
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7018 - accuracy: 0.6201 - val_loss: 0.9632 - val_accuracy: 0.4187 - lr: 2.5000e-05
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.7082 - accuracy: 0.6154 - val_loss: 0.9559 - val_accuracy: 0.4125 - lr: 2.5000e-05
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6881 - accuracy: 0.6193 - val_loss: 0.9493 - val_accuracy: 0.4062 - lr: 2.5000e-05
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6858 - accuracy: 0.6385 - val_loss: 0.9486 - val_accuracy: 0.4062 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6774 - accuracy: 0.6367 - val_loss: 0.9393 - val_accuracy: 0.4062 - lr: 2.5000e-05
#
# ==== LOSO Summary (Up/Down) ====
# Mean Window Acc: 0.718 ± 0.146
# Mean Clip   Acc: 0.713 ± 0.156
#
# ==== OVERALL (클립) ====
# Overall 클립 Acc: 0.729
#               precision    recall  f1-score   support
#
#            위      0.744     0.696     0.719       250
#           아래      0.716     0.762     0.738       252
#
#     accuracy                          0.729       502
#    macro avg      0.730     0.729     0.729       502
# weighted avg      0.730     0.729     0.729       502

# %%
# 윈도 단위 활성 비율 점검
ratios = (M.reshape(M.shape[0], -1).mean(axis=1))  # 각 윈도의 활성 비율
print("median active ratio:", np.median(ratios), " 10/90pct:",
      np.percentile(ratios,[10,90]))
# Out:
# median active ratio: 1.0  10/90pct: [1. 1.]

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

def _fixed_delta_with_mask(x, m):
    # x: (B,T,F), m: (B,T,1)  [여기선 m≡1에 가까워도 괜찮]
    x_prev = tf.pad(x[:, :-1, :], [[0,0],[1,0],[0,0]])
    dx = x - x_prev
    dx = tf.concat([tf.zeros_like(dx[:, :1, :]), dx[:, 1:, :]], axis=1)
    gate_dx = tf.concat([tf.zeros_like(m[:, :1, :]), m[:, 1:, :]], axis=1)
    dx *= gate_dx
    return x, dx

def build_updown_x_plus_delta(input_shape, n_classes=2):
    L, F = input_shape
    inp_x = layers.Input((L, F),  name="inp_x")
    inp_m = layers.Input((L, 1),  name="inp_m")   # m은 지금 거의 1이지만 인터페이스 유지

    # x, Δ 생성
    x, dx = layers.Lambda(lambda z: _fixed_delta_with_mask(z[0], z[1]))([inp_x, inp_m])

    # 그룹별 정규화 후 결합 (분포 안정화)
    x  = layers.LayerNormalization()(x)
    dx = layers.LayerNormalization()(dx)
    feat = layers.Concatenate(axis=-1)([x, dx])   # (L, 2F)

    # 1x1 Conv로 채널 압축/혼합
    feat = layers.Conv1D(128, 1, padding='same', use_bias=False)(feat)
    feat = layers.LayerNormalization()(feat)
    feat = layers.Activation('relu')(feat)
    feat = layers.SpatialDropout1D(0.15)(feat)

    # RNN 헤드 (용량 ↑, 규제 완화)
    h = layers.GRU(96, dropout=0.3, recurrent_dropout=0.0,
                   kernel_regularizer=regularizers.l2(5e-5))(feat)
    h = layers.LayerNormalization()(h)
    h = layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(5e-5))(h)
    h = layers.Dropout(0.4)(h)

    out = layers.Dense(n_classes, activation='softmax')(h)
    model = tf.keras.Model([inp_x, inp_m], out)

    opt = tf.keras.optimizers.Adam(learning_rate=3e-4, clipnorm=1.0)
    model.compile(optimizer=opt,
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])
    return model

# %%
# =========================
# 위/아래 2-class LOSO 학습/평가 (평균 곡선 포함)
# =========================

from sklearn.model_selection import LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager
import tensorflow as tf
from tensorflow.keras import layers, regularizers

# ===== 옵션 =====
EPOCHS = 80
BATCH_SIZE = 64
ES_PATIENCE = 12
RLR_PATIENCE = 6

PLOT_LAST_FOLD_CURVES = True   # 폴드 개별 곡선(마지막 폴드만)
EVAL_LEVEL = "clip"            # "clip" 또는 "window"

# ===== 한글 폰트 =====
def setup_korean_font():
    candidates = ["Malgun Gothic", "AppleGothic", "NanumGothic", "Noto Sans CJK KR", "Noto Sans KR"]
    installed = {f.name for f in font_manager.fontManager.ttflist}
    for name in candidates:
        if name in installed:
            plt.rcParams["font.family"] = name
            break
    plt.rcParams["axes.unicode_minus"] = False
setup_korean_font()

# ===== 시각화 헬퍼 =====
def plot_training_curves(history, fold_no):
    H = history.history
    plt.figure()
    plt.plot(H.get('loss', []),     label='loss')
    plt.plot(H.get('val_loss', []), label='val_loss')
    plt.title(f'Fold {fold_no} - Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss')
    plt.legend(); plt.tight_layout(); plt.show()

    if 'accuracy' in H and 'val_accuracy' in H:
        plt.figure()
        plt.plot(H['accuracy'],     label='accuracy')
        plt.plot(H['val_accuracy'], label='val_accuracy')
        plt.title(f'Fold {fold_no} - Accuracy')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

def norm_cm(cm):
    with np.errstate(invalid='ignore', divide='ignore'):
        cmn = cm.astype(float) / cm.sum(axis=1, keepdims=True)
        cmn = np.nan_to_num(cmn)
    return cmn

def plot_confmat_ratio(cm, classes, title):
    M = norm_cm(cm)
    plt.figure()
    im = plt.imshow(M, interpolation='nearest', cmap='Blues', vmin=0.0, vmax=1.0)
    plt.title(title); plt.colorbar(im)
    ticks = np.arange(len(classes))
    plt.xticks(ticks, classes); plt.yticks(ticks, classes)
    for i in range(M.shape[0]):
        for j in range(M.shape[1]):
            val = M[i, j]
            txt_color = 'black' if val < 0.6 else 'white'
            plt.text(j, i, f"{val:.2f}", ha="center", va="center", color=txt_color, fontsize=10)
    plt.ylabel('실제 레이블'); plt.xlabel('예측 레이블')
    plt.tight_layout(); plt.show()

# ----- 폴드 평균 곡선 -----
def _nanmean_along_epochs(list_of_lists):
    if not list_of_lists:
        return None, None
    maxlen = max(len(s) for s in list_of_lists)
    M = np.full((len(list_of_lists), maxlen), np.nan, dtype=np.float32)
    for i, s in enumerate(list_of_lists):
        arr = np.asarray(s, dtype=np.float32)
        M[i, :len(arr)] = arr
    return np.nanmean(M, axis=0), np.nanstd(M, axis=0)

def plot_mean_training_curves(histories):
    # Loss
    mean_loss, std_loss         = _nanmean_along_epochs([h.get('loss', []) for h in histories])
    mean_val_loss, std_val_loss = _nanmean_along_epochs([h.get('val_loss', []) for h in histories])

    if mean_loss is not None:
        x = np.arange(len(mean_loss))
        plt.figure()
        plt.plot(x, mean_loss,     label='loss (mean)')
        plt.plot(x, mean_val_loss, label='val_loss (mean)')
        plt.fill_between(x, mean_loss - std_loss,     mean_loss + std_loss,     alpha=0.15)
        plt.fill_between(x, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.15)
        plt.title('LOSO 평균 Loss (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Loss')
        plt.legend(); plt.tight_layout(); plt.show()

    # Accuracy
    has_acc = all(('accuracy' in h and 'val_accuracy' in h) for h in histories)
    if has_acc:
        mean_acc, std_acc         = _nanmean_along_epochs([h['accuracy']     for h in histories])
        mean_val_acc, std_val_acc = _nanmean_along_epochs([h['val_accuracy'] for h in histories])
        x = np.arange(len(mean_acc))
        plt.figure()
        plt.plot(x, mean_acc,     label='accuracy (mean)')
        plt.plot(x, mean_val_acc, label='val_accuracy (mean)')
        plt.fill_between(x, mean_acc - std_acc,     mean_acc + std_acc,     alpha=0.15)
        plt.fill_between(x, mean_val_acc - std_val_acc, mean_val_acc + std_val_acc, alpha=0.15)
        plt.title('LOSO 평균 Accuracy (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

# ===== 13 → 2 (위/아래) 매핑 및 데이터 필터 =====
#  - 위(0): '구개측' 또는 '위-씹는면' 이 포함된 라벨
#  - 아래(1): '설측' 또는 '아래-씹는면' 이 포함된 라벨
#  - 그 외(예: '협측')는 제외
labels_np = np.array(KOREAN_LABELS, dtype=object)

def _ud_from_label(lab: str):
    if ('구개측' in lab) or ('위-씹는면' in lab):
        return 0  # 위
    if ('설측' in lab) or ('아래-씹는면' in lab):
        return 1  # 아래
    return None   # 제외(협측 등)

# 인덱스 마스크 생성
keep_indices = []
y_ud_list = []
for i, yi in enumerate(y):
    lab = labels_np[yi]
    mcls = _ud_from_label(lab)
    if mcls is not None:
        keep_indices.append(i)
        y_ud_list.append(mcls)

keep_indices = np.array(keep_indices, dtype=int)
X_ud = X[keep_indices]                 # (N_ud, L, F)
M_ud = M[keep_indices]                 # (N_ud, L, 1)  <- 추가
y_ud = np.array(y_ud_list, dtype=int)
meta_ud = [meta[i] for i in keep_indices]
persons_ud = np.array([m["person"] for m in meta_ud])

print(f"[Filter] 총 {len(X)}개 중 {len(X_ud)}개 사용.  M shape: {M_ud.shape},  분포:", np.bincount(y_ud))


# ===== LOSO 학습/평가 =====
F = X_ud.shape[-1]
HAND_DIMS = 42 if F >= 42 else F
EPS = 1e-7
logo = LeaveOneGroupOut()

CLASS_NAMES = ['위','아래']

# 집계 버퍼
histories = []
all_win_true, all_win_pred = [], []
all_clip_true, all_clip_pred = [], []
all_win_acc, all_clip_acc = [], []

fold_no = 0
total_folds = len(np.unique(persons_ud))

for train_idx, val_idx in logo.split(X_ud, y_ud, groups=persons_ud):
    X_train, y_train = X_ud[train_idx], y_ud[train_idx]
    X_val,   y_val   = X_ud[val_idx],   y_ud[val_idx]
    M_train, M_val   = M_ud[train_idx], M_ud[val_idx]     # ← 추가

    scaler = StandardScaler(with_mean=True, with_std=True)
    Xtr_flat = X_train.reshape(-1, F)
    mask = (np.abs(Xtr_flat[:, :HAND_DIMS]).sum(axis=1) > EPS)
    scaler.fit(Xtr_flat[mask] if mask.any() else Xtr_flat)

    X_train_s = scaler.transform(X_train.reshape(-1, F)).reshape(X_train.shape)
    X_val_s   = scaler.transform(X_val.reshape(-1, F)).reshape(X_val.shape)
    # M_train, M_val 는 스케일링 절대 금지 (0/1 유지)

    # 모델
    model = build_updown_x_plus_delta(
    input_shape=(X_train_s.shape[1], X_train_s.shape[2]),
    n_classes=2
    )
    
    cls_counts = np.bincount(y_train, minlength=2)
    class_weights = {i: float(np.median(cls_counts)/c) for i, c in enumerate(cls_counts)}

    cb = [
        tf.keras.callbacks.EarlyStopping(patience=ES_PATIENCE, restore_best_weights=True, monitor='val_loss'),
        tf.keras.callbacks.ReduceLROnPlateau(patience=RLR_PATIENCE, factor=0.5, min_lr=1e-5),
    ]

    history = model.fit(
        [X_train_s, M_train], y_train,
        validation_data=([X_val_s, M_val], y_val),
        epochs=EPOCHS, batch_size=BATCH_SIZE,
        class_weight=class_weights,
        callbacks=cb, verbose=1
    )
    histories.append(history.history)

    if PLOT_LAST_FOLD_CURVES and fold_no == total_folds:
        plot_training_curves(history, fold_no)

    # 윈도우 단위
    p = model.predict([X_val_s, M_val], verbose=0)
    y_pred = p.argmax(1)
    win_acc = accuracy_score(y_val, y_pred)
    all_win_acc.append(win_acc)
    all_win_true.append(y_val); all_win_pred.append(y_pred)

    # 클립 단위
    bucket_p, bucket_y = defaultdict(list), {}
    val_meta = [meta_ud[i] for i in val_idx]
    for i, m in enumerate(val_meta):
        bucket_p[m["src"]].append(p[i])
        bucket_y[m["src"]] = y_val[i]
    P_clip, Y_clip = [], []
    for src, ps in bucket_p.items():
        P_clip.append(np.mean(ps, axis=0))
        Y_clip.append(bucket_y[src])
    clip_pred = np.argmax(np.vstack(P_clip), axis=1)
    clip_acc = accuracy_score(Y_clip, clip_pred)
    all_clip_acc.append(clip_acc)
    all_clip_true.append(np.array(Y_clip))
    all_clip_pred.append(clip_pred)

# ===== 폴드 전체 집계 =====
all_win_true  = np.concatenate(all_win_true, axis=0)
all_win_pred  = np.concatenate(all_win_pred, axis=0)
all_clip_true = np.concatenate(all_clip_true, axis=0)
all_clip_pred = np.concatenate(all_clip_pred, axis=0)

print("\n==== LOSO Summary (Up/Down) ====")
print(f"Mean Window Acc: {np.mean(all_win_acc):.3f} ± {np.std(all_win_acc):.3f}")
print(f"Mean Clip   Acc: {np.mean(all_clip_acc):.3f} ± {np.std(all_clip_acc):.3f}")

# ===== 최종(전체 사람) 혼동행렬/지표 =====
if EVAL_LEVEL == "clip":
    y_true_overall = all_clip_true; y_pred_overall = all_clip_pred; level_name = "클립"
else:
    y_true_overall = all_win_true;  y_pred_overall = all_win_pred;  level_name = "윈도우"

overall_acc = accuracy_score(y_true_overall, y_pred_overall)
print(f"\n==== OVERALL ({level_name}) ====")
print(f"Overall {level_name} Acc: {overall_acc:.3f}")
print(classification_report(y_true_overall, y_pred_overall, target_names=CLASS_NAMES, digits=3))

cm_overall = confusion_matrix(y_true_overall, y_pred_overall, labels=[0,1])
plot_confmat_ratio(cm_overall, CLASS_NAMES, f'전체 {level_name} 혼동행렬 (행 정규화, 비율)')

# ===== LOSO 평균 곡선 =====
plot_mean_training_curves(histories)
# Out:
# [Filter] 총 5248개 중 4016개 사용.  M shape: (4016, 45, 1),  분포: [2000 2016]
# Epoch 1/80
# 57/57 [==============================] - 2s 14ms/step - loss: 0.7350 - accuracy: 0.6004 - val_loss: 0.5670 - val_accuracy: 0.6675 - lr: 3.0000e-04
# Epoch 2/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6207 - accuracy: 0.6723 - val_loss: 0.5910 - val_accuracy: 0.7200 - lr: 3.0000e-04
# Epoch 3/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5740 - accuracy: 0.7174 - val_loss: 0.6131 - val_accuracy: 0.7350 - lr: 3.0000e-04
# Epoch 4/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.5485 - accuracy: 0.7243 - val_loss: 0.7392 - val_accuracy: 0.6875 - lr: 3.0000e-04
# Epoch 5/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.5120 - accuracy: 0.7575 - val_loss: 0.7969 - val_accuracy: 0.7000 - lr: 3.0000e-04
# Epoch 6/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4736 - accuracy: 0.7771 - val_loss: 1.0901 - val_accuracy: 0.6150 - lr: 3.0000e-04
# Epoch 7/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.4500 - accuracy: 0.7876 - val_loss: 1.0272 - val_accuracy: 0.6800 - lr: 3.0000e-04
# Epoch 8/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.4186 - accuracy: 0.8059 - val_loss: 1.3559 - val_accuracy: 0.6225 - lr: 1.5000e-04
# Epoch 9/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3884 - accuracy: 0.8238 - val_loss: 1.4248 - val_accuracy: 0.6325 - lr: 1.5000e-04
# Epoch 10/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3831 - accuracy: 0.8200 - val_loss: 1.5211 - val_accuracy: 0.6275 - lr: 1.5000e-04
# Epoch 11/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.3773 - accuracy: 0.8202 - val_loss: 1.6558 - val_accuracy: 0.6200 - lr: 1.5000e-04
# Epoch 12/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3592 - accuracy: 0.8335 - val_loss: 2.0434 - val_accuracy: 0.5975 - lr: 1.5000e-04
# Epoch 13/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3497 - accuracy: 0.8479 - val_loss: 1.6280 - val_accuracy: 0.6625 - lr: 1.5000e-04
# Epoch 1/80
# 57/57 [==============================] - 2s 11ms/step - loss: 0.7165 - accuracy: 0.6145 - val_loss: 0.5476 - val_accuracy: 0.7900 - lr: 3.0000e-04
# Epoch 2/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.6119 - accuracy: 0.6869 - val_loss: 0.4707 - val_accuracy: 0.7850 - lr: 3.0000e-04
# Epoch 3/80
# 57/57 [==============================] - 0s 8ms/step - loss: 0.5652 - accuracy: 0.7323 - val_loss: 0.3880 - val_accuracy: 0.8225 - lr: 3.0000e-04
# Epoch 4/80
# 57/57 [==============================] - 0s 9ms/step - loss: 0.5277 - accuracy: 0.7530 - val_loss: 0.3253 - val_accuracy: 0.8275 - lr: 3.0000e-04
# Epoch 5/80
# 57/57 [==============================] - 0s 8ms/step - loss: 0.4881 - accuracy: 0.7735 - val_loss: 0.3172 - val_accuracy: 0.8425 - lr: 3.0000e-04
# Epoch 6/80
# 57/57 [==============================] - 0s 8ms/step - loss: 0.4459 - accuracy: 0.7970 - val_loss: 0.2790 - val_accuracy: 0.8375 - lr: 3.0000e-04
# Epoch 7/80
# 57/57 [==============================] - 0s 8ms/step - loss: 0.4095 - accuracy: 0.8158 - val_loss: 0.3016 - val_accuracy: 0.8475 - lr: 3.0000e-04
# Epoch 8/80
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3963 - accuracy: 0.8280 - val_loss: 0.3077 - val_accuracy: 0.8475 - lr: 3.0000e-04
# Epoch 9/80
# 57/57 [==============================] - 0s 8ms/step - loss: 0.3577 - accuracy: 0.8449 - val_loss: 0.3022 - val_accuracy: 0.8175 - lr: 3.0000e-04
# Epoch 10/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3560 - accuracy: 0.8429 - val_loss: 0.2857 - val_accuracy: 0.8325 - lr: 3.0000e-04
# Epoch 11/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3334 - accuracy: 0.8590 - val_loss: 0.3050 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 12/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.3003 - accuracy: 0.8678 - val_loss: 0.3184 - val_accuracy: 0.8425 - lr: 3.0000e-04
# Epoch 13/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2776 - accuracy: 0.8855 - val_loss: 0.3530 - val_accuracy: 0.8225 - lr: 1.5000e-04
# Epoch 14/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2653 - accuracy: 0.8869 - val_loss: 0.3484 - val_accuracy: 0.8375 - lr: 1.5000e-04
# Epoch 15/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2526 - accuracy: 0.8971 - val_loss: 0.3628 - val_accuracy: 0.8225 - lr: 1.5000e-04
# Epoch 16/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2505 - accuracy: 0.8957 - val_loss: 0.3407 - val_accuracy: 0.8250 - lr: 1.5000e-04
# Epoch 17/80
# 57/57 [==============================] - 0s 6ms/step - loss: 0.2304 - accuracy: 0.9079 - val_loss: 0.4132 - val_accuracy: 0.8250 - lr: 1.5000e-04
# Epoch 18/80
# 57/57 [==============================] - 0s 7ms/step - loss: 0.2304 - accuracy: 0.9068 - val_loss: 0.4217 - val_accuracy: 0.8200 - lr: 1.5000e-04
# Epoch 1/80
# 59/59 [==============================] - 2s 12ms/step - loss: 0.7420 - accuracy: 0.5990 - val_loss: 0.7034 - val_accuracy: 0.5958 - lr: 3.0000e-04
# Epoch 2/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.6050 - accuracy: 0.6949 - val_loss: 0.7366 - val_accuracy: 0.5917 - lr: 3.0000e-04
# Epoch 3/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.5574 - accuracy: 0.7275 - val_loss: 0.7258 - val_accuracy: 0.6625 - lr: 3.0000e-04
# Epoch 4/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.5180 - accuracy: 0.7484 - val_loss: 0.7776 - val_accuracy: 0.6583 - lr: 3.0000e-04
# Epoch 5/80
# 59/59 [==============================] - 0s 8ms/step - loss: 0.4759 - accuracy: 0.7791 - val_loss: 0.8066 - val_accuracy: 0.7333 - lr: 3.0000e-04
# Epoch 6/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4442 - accuracy: 0.7979 - val_loss: 0.8652 - val_accuracy: 0.7583 - lr: 3.0000e-04
# Epoch 7/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.4207 - accuracy: 0.8125 - val_loss: 0.8845 - val_accuracy: 0.7583 - lr: 3.0000e-04
# Epoch 8/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3846 - accuracy: 0.8247 - val_loss: 0.9047 - val_accuracy: 0.7583 - lr: 1.5000e-04
# Epoch 9/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3647 - accuracy: 0.8424 - val_loss: 0.9833 - val_accuracy: 0.7583 - lr: 1.5000e-04
# Epoch 10/80
# 59/59 [==============================] - 0s 6ms/step - loss: 0.3586 - accuracy: 0.8385 - val_loss: 0.9652 - val_accuracy: 0.7583 - lr: 1.5000e-04
# Epoch 11/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3371 - accuracy: 0.8543 - val_loss: 0.9750 - val_accuracy: 0.7708 - lr: 1.5000e-04
# Epoch 12/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3175 - accuracy: 0.8652 - val_loss: 1.0235 - val_accuracy: 0.7667 - lr: 1.5000e-04
# Epoch 13/80
# 59/59 [==============================] - 0s 7ms/step - loss: 0.3123 - accuracy: 0.8633 - val_loss: 1.0436 - val_accuracy: 0.7667 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 13ms/step - loss: 0.7484 - accuracy: 0.6232 - val_loss: 0.8200 - val_accuracy: 0.4750 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6030 - accuracy: 0.7049 - val_loss: 0.8521 - val_accuracy: 0.5188 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.5519 - accuracy: 0.7337 - val_loss: 0.9180 - val_accuracy: 0.5125 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.5060 - accuracy: 0.7684 - val_loss: 0.9961 - val_accuracy: 0.5125 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4706 - accuracy: 0.7881 - val_loss: 0.9937 - val_accuracy: 0.5188 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.4411 - accuracy: 0.8060 - val_loss: 1.1016 - val_accuracy: 0.5250 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4097 - accuracy: 0.8177 - val_loss: 1.0987 - val_accuracy: 0.5188 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3726 - accuracy: 0.8366 - val_loss: 1.1595 - val_accuracy: 0.5688 - lr: 1.5000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3725 - accuracy: 0.8369 - val_loss: 1.1808 - val_accuracy: 0.5750 - lr: 1.5000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3496 - accuracy: 0.8387 - val_loss: 1.3974 - val_accuracy: 0.5188 - lr: 1.5000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3377 - accuracy: 0.8587 - val_loss: 1.2988 - val_accuracy: 0.6000 - lr: 1.5000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3292 - accuracy: 0.8509 - val_loss: 1.2955 - val_accuracy: 0.5625 - lr: 1.5000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3091 - accuracy: 0.8688 - val_loss: 1.5619 - val_accuracy: 0.5875 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.7325 - accuracy: 0.6024 - val_loss: 0.6864 - val_accuracy: 0.5688 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6044 - accuracy: 0.6981 - val_loss: 0.6605 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5616 - accuracy: 0.7350 - val_loss: 0.6079 - val_accuracy: 0.7188 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5378 - accuracy: 0.7466 - val_loss: 0.5542 - val_accuracy: 0.7250 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4963 - accuracy: 0.7798 - val_loss: 0.5228 - val_accuracy: 0.7563 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4685 - accuracy: 0.7871 - val_loss: 0.4830 - val_accuracy: 0.7875 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4451 - accuracy: 0.8024 - val_loss: 0.5278 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4178 - accuracy: 0.8195 - val_loss: 0.5818 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3855 - accuracy: 0.8288 - val_loss: 0.4742 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3619 - accuracy: 0.8382 - val_loss: 0.5857 - val_accuracy: 0.7937 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3409 - accuracy: 0.8480 - val_loss: 0.7642 - val_accuracy: 0.7000 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3231 - accuracy: 0.8571 - val_loss: 0.4924 - val_accuracy: 0.8375 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3198 - accuracy: 0.8654 - val_loss: 0.8049 - val_accuracy: 0.7188 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3023 - accuracy: 0.8711 - val_loss: 0.7048 - val_accuracy: 0.7188 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2736 - accuracy: 0.8802 - val_loss: 0.6705 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2600 - accuracy: 0.8921 - val_loss: 0.6187 - val_accuracy: 0.8062 - lr: 1.5000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2513 - accuracy: 0.8919 - val_loss: 0.8984 - val_accuracy: 0.7188 - lr: 1.5000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2331 - accuracy: 0.9056 - val_loss: 0.8600 - val_accuracy: 0.7312 - lr: 1.5000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2285 - accuracy: 0.9064 - val_loss: 0.7013 - val_accuracy: 0.7688 - lr: 1.5000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2200 - accuracy: 0.9079 - val_loss: 0.5388 - val_accuracy: 0.8438 - lr: 1.5000e-04
# Epoch 21/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2138 - accuracy: 0.9155 - val_loss: 0.9066 - val_accuracy: 0.7312 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.6895 - accuracy: 0.6183 - val_loss: 0.4185 - val_accuracy: 0.8813 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5888 - accuracy: 0.6937 - val_loss: 0.3758 - val_accuracy: 0.9312 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.5563 - accuracy: 0.7212 - val_loss: 0.3896 - val_accuracy: 0.9250 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5224 - accuracy: 0.7477 - val_loss: 0.3466 - val_accuracy: 0.9375 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4865 - accuracy: 0.7697 - val_loss: 0.2849 - val_accuracy: 0.9563 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.4651 - accuracy: 0.7860 - val_loss: 0.1743 - val_accuracy: 0.9875 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4265 - accuracy: 0.8016 - val_loss: 0.2262 - val_accuracy: 0.9312 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3928 - accuracy: 0.8224 - val_loss: 0.1535 - val_accuracy: 0.9688 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3753 - accuracy: 0.8340 - val_loss: 0.1122 - val_accuracy: 1.0000 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3502 - accuracy: 0.8480 - val_loss: 0.1604 - val_accuracy: 0.9438 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3272 - accuracy: 0.8594 - val_loss: 0.1447 - val_accuracy: 0.9563 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3060 - accuracy: 0.8641 - val_loss: 0.1384 - val_accuracy: 0.9438 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2954 - accuracy: 0.8760 - val_loss: 0.1609 - val_accuracy: 0.9375 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2682 - accuracy: 0.8846 - val_loss: 0.0838 - val_accuracy: 0.9500 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2571 - accuracy: 0.8970 - val_loss: 0.1410 - val_accuracy: 0.9375 - lr: 3.0000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2264 - accuracy: 0.9110 - val_loss: 0.1360 - val_accuracy: 0.9438 - lr: 3.0000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2191 - accuracy: 0.9126 - val_loss: 0.1020 - val_accuracy: 0.9500 - lr: 3.0000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2100 - accuracy: 0.9186 - val_loss: 0.0637 - val_accuracy: 0.9750 - lr: 3.0000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1874 - accuracy: 0.9279 - val_loss: 0.0907 - val_accuracy: 0.9500 - lr: 3.0000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1715 - accuracy: 0.9349 - val_loss: 0.0754 - val_accuracy: 0.9625 - lr: 3.0000e-04
# Epoch 21/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1550 - accuracy: 0.9458 - val_loss: 0.1503 - val_accuracy: 0.9375 - lr: 3.0000e-04
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1456 - accuracy: 0.9492 - val_loss: 0.2032 - val_accuracy: 0.9438 - lr: 3.0000e-04
# Epoch 23/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1317 - accuracy: 0.9585 - val_loss: 0.3319 - val_accuracy: 0.8813 - lr: 3.0000e-04
# Epoch 24/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1306 - accuracy: 0.9557 - val_loss: 0.1881 - val_accuracy: 0.9500 - lr: 3.0000e-04
# Epoch 25/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1044 - accuracy: 0.9655 - val_loss: 0.1230 - val_accuracy: 0.9625 - lr: 1.5000e-04
# Epoch 26/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1006 - accuracy: 0.9642 - val_loss: 0.0969 - val_accuracy: 0.9750 - lr: 1.5000e-04
# Epoch 27/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0961 - accuracy: 0.9710 - val_loss: 0.2493 - val_accuracy: 0.9375 - lr: 1.5000e-04
# Epoch 28/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0810 - accuracy: 0.9769 - val_loss: 0.3005 - val_accuracy: 0.9438 - lr: 1.5000e-04
# Epoch 29/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0773 - accuracy: 0.9759 - val_loss: 0.3771 - val_accuracy: 0.9312 - lr: 1.5000e-04
# Epoch 30/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0854 - accuracy: 0.9746 - val_loss: 0.1468 - val_accuracy: 0.9625 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 11ms/step - loss: 0.7217 - accuracy: 0.6128 - val_loss: 0.8262 - val_accuracy: 0.5188 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5937 - accuracy: 0.6974 - val_loss: 0.9412 - val_accuracy: 0.4938 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5479 - accuracy: 0.7433 - val_loss: 0.8310 - val_accuracy: 0.5312 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5151 - accuracy: 0.7637 - val_loss: 0.8620 - val_accuracy: 0.5437 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4759 - accuracy: 0.7819 - val_loss: 0.9322 - val_accuracy: 0.5437 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4458 - accuracy: 0.7967 - val_loss: 0.8268 - val_accuracy: 0.5750 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4195 - accuracy: 0.8063 - val_loss: 0.9794 - val_accuracy: 0.5625 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.3957 - accuracy: 0.8172 - val_loss: 1.0432 - val_accuracy: 0.5625 - lr: 1.5000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3723 - accuracy: 0.8301 - val_loss: 1.1583 - val_accuracy: 0.5625 - lr: 1.5000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3565 - accuracy: 0.8361 - val_loss: 1.0680 - val_accuracy: 0.5688 - lr: 1.5000e-04
# Epoch 11/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.3467 - accuracy: 0.8462 - val_loss: 1.1058 - val_accuracy: 0.5813 - lr: 1.5000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3451 - accuracy: 0.8524 - val_loss: 1.0808 - val_accuracy: 0.6250 - lr: 1.5000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3214 - accuracy: 0.8607 - val_loss: 1.4128 - val_accuracy: 0.5688 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.7437 - accuracy: 0.6216 - val_loss: 0.6866 - val_accuracy: 0.5625 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 1s 8ms/step - loss: 0.5977 - accuracy: 0.6950 - val_loss: 0.6230 - val_accuracy: 0.6938 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5448 - accuracy: 0.7305 - val_loss: 0.6067 - val_accuracy: 0.7250 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5033 - accuracy: 0.7609 - val_loss: 0.5900 - val_accuracy: 0.7375 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4738 - accuracy: 0.7871 - val_loss: 0.5882 - val_accuracy: 0.7750 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4409 - accuracy: 0.8016 - val_loss: 0.5501 - val_accuracy: 0.6875 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4208 - accuracy: 0.8050 - val_loss: 0.5713 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3931 - accuracy: 0.8190 - val_loss: 0.5251 - val_accuracy: 0.7125 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3665 - accuracy: 0.8400 - val_loss: 0.5537 - val_accuracy: 0.7000 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3379 - accuracy: 0.8485 - val_loss: 0.4953 - val_accuracy: 0.7625 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3161 - accuracy: 0.8636 - val_loss: 0.5259 - val_accuracy: 0.7250 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3062 - accuracy: 0.8680 - val_loss: 0.5391 - val_accuracy: 0.6938 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2885 - accuracy: 0.8773 - val_loss: 0.5156 - val_accuracy: 0.7063 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2684 - accuracy: 0.8874 - val_loss: 0.4976 - val_accuracy: 0.7250 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2485 - accuracy: 0.8973 - val_loss: 0.5022 - val_accuracy: 0.7188 - lr: 3.0000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2393 - accuracy: 0.9012 - val_loss: 0.5146 - val_accuracy: 0.7125 - lr: 3.0000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2175 - accuracy: 0.9105 - val_loss: 0.4951 - val_accuracy: 0.7250 - lr: 1.5000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2022 - accuracy: 0.9219 - val_loss: 0.4339 - val_accuracy: 0.7625 - lr: 1.5000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1967 - accuracy: 0.9235 - val_loss: 0.5222 - val_accuracy: 0.7063 - lr: 1.5000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1894 - accuracy: 0.9235 - val_loss: 0.5104 - val_accuracy: 0.7500 - lr: 1.5000e-04
# Epoch 21/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1818 - accuracy: 0.9300 - val_loss: 0.5251 - val_accuracy: 0.7500 - lr: 1.5000e-04
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1720 - accuracy: 0.9359 - val_loss: 0.5736 - val_accuracy: 0.7250 - lr: 1.5000e-04
# Epoch 23/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1595 - accuracy: 0.9391 - val_loss: 0.4900 - val_accuracy: 0.7250 - lr: 1.5000e-04
# Epoch 24/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1507 - accuracy: 0.9432 - val_loss: 0.4851 - val_accuracy: 0.7250 - lr: 1.5000e-04
# Epoch 25/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1461 - accuracy: 0.9466 - val_loss: 0.5043 - val_accuracy: 0.7250 - lr: 7.5000e-05
# Epoch 26/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1358 - accuracy: 0.9515 - val_loss: 0.5052 - val_accuracy: 0.7500 - lr: 7.5000e-05
# Epoch 27/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1428 - accuracy: 0.9499 - val_loss: 0.4848 - val_accuracy: 0.7625 - lr: 7.5000e-05
# Epoch 28/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1402 - accuracy: 0.9499 - val_loss: 0.4746 - val_accuracy: 0.7500 - lr: 7.5000e-05
# Epoch 29/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1271 - accuracy: 0.9551 - val_loss: 0.4272 - val_accuracy: 0.7750 - lr: 7.5000e-05
# Epoch 30/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1252 - accuracy: 0.9588 - val_loss: 0.5174 - val_accuracy: 0.7375 - lr: 7.5000e-05
# Epoch 31/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1194 - accuracy: 0.9580 - val_loss: 0.5093 - val_accuracy: 0.7437 - lr: 7.5000e-05
# Epoch 32/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1157 - accuracy: 0.9603 - val_loss: 0.4973 - val_accuracy: 0.7625 - lr: 7.5000e-05
# Epoch 33/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1141 - accuracy: 0.9590 - val_loss: 0.6279 - val_accuracy: 0.7563 - lr: 7.5000e-05
# Epoch 34/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1192 - accuracy: 0.9564 - val_loss: 0.4564 - val_accuracy: 0.7688 - lr: 7.5000e-05
# Epoch 35/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1203 - accuracy: 0.9632 - val_loss: 0.4902 - val_accuracy: 0.7750 - lr: 7.5000e-05
# Epoch 36/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1109 - accuracy: 0.9655 - val_loss: 0.5474 - val_accuracy: 0.7375 - lr: 3.7500e-05
# Epoch 37/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0992 - accuracy: 0.9663 - val_loss: 0.4760 - val_accuracy: 0.7812 - lr: 3.7500e-05
# Epoch 38/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0946 - accuracy: 0.9704 - val_loss: 0.4963 - val_accuracy: 0.7688 - lr: 3.7500e-05
# Epoch 39/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1045 - accuracy: 0.9663 - val_loss: 0.4921 - val_accuracy: 0.7563 - lr: 3.7500e-05
# Epoch 40/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0893 - accuracy: 0.9723 - val_loss: 0.5061 - val_accuracy: 0.7750 - lr: 3.7500e-05
# Epoch 41/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1103 - accuracy: 0.9616 - val_loss: 0.5388 - val_accuracy: 0.7688 - lr: 3.7500e-05
# Epoch 1/80
# 61/61 [==============================] - 2s 11ms/step - loss: 0.7527 - accuracy: 0.6043 - val_loss: 0.4626 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6185 - accuracy: 0.6673 - val_loss: 0.4079 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5568 - accuracy: 0.7241 - val_loss: 0.4095 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5054 - accuracy: 0.7599 - val_loss: 0.3856 - val_accuracy: 0.8625 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.4749 - accuracy: 0.7790 - val_loss: 0.3906 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.4338 - accuracy: 0.8029 - val_loss: 0.4058 - val_accuracy: 0.8062 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.4006 - accuracy: 0.8148 - val_loss: 0.4933 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3777 - accuracy: 0.8296 - val_loss: 0.4837 - val_accuracy: 0.8062 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3546 - accuracy: 0.8405 - val_loss: 0.6228 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.3335 - accuracy: 0.8537 - val_loss: 0.4802 - val_accuracy: 0.8125 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3057 - accuracy: 0.8677 - val_loss: 0.5817 - val_accuracy: 0.8375 - lr: 1.5000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2944 - accuracy: 0.8729 - val_loss: 0.6642 - val_accuracy: 0.8750 - lr: 1.5000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2834 - accuracy: 0.8812 - val_loss: 0.6408 - val_accuracy: 0.8375 - lr: 1.5000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2661 - accuracy: 0.8903 - val_loss: 0.6617 - val_accuracy: 0.8438 - lr: 1.5000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2654 - accuracy: 0.8911 - val_loss: 0.6396 - val_accuracy: 0.8125 - lr: 1.5000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 6ms/step - loss: 0.2581 - accuracy: 0.8916 - val_loss: 0.6733 - val_accuracy: 0.8375 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 11ms/step - loss: 0.7841 - accuracy: 0.5980 - val_loss: 0.4455 - val_accuracy: 0.8875 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6319 - accuracy: 0.6738 - val_loss: 0.3795 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5785 - accuracy: 0.7070 - val_loss: 0.3277 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5481 - accuracy: 0.7344 - val_loss: 0.2893 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5049 - accuracy: 0.7619 - val_loss: 0.2559 - val_accuracy: 0.9062 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4734 - accuracy: 0.7796 - val_loss: 0.2444 - val_accuracy: 0.9563 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4397 - accuracy: 0.7972 - val_loss: 0.2250 - val_accuracy: 0.9688 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4070 - accuracy: 0.8141 - val_loss: 0.1958 - val_accuracy: 0.9875 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3782 - accuracy: 0.8286 - val_loss: 0.2473 - val_accuracy: 0.9688 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3610 - accuracy: 0.8400 - val_loss: 0.2314 - val_accuracy: 0.9500 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3323 - accuracy: 0.8553 - val_loss: 0.2413 - val_accuracy: 0.9062 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3180 - accuracy: 0.8571 - val_loss: 0.2209 - val_accuracy: 0.9125 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2933 - accuracy: 0.8747 - val_loss: 0.2066 - val_accuracy: 0.9625 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2883 - accuracy: 0.8732 - val_loss: 0.1993 - val_accuracy: 0.9500 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2576 - accuracy: 0.8924 - val_loss: 0.2847 - val_accuracy: 0.8813 - lr: 1.5000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2496 - accuracy: 0.8963 - val_loss: 0.2828 - val_accuracy: 0.8562 - lr: 1.5000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2427 - accuracy: 0.8968 - val_loss: 0.3067 - val_accuracy: 0.8813 - lr: 1.5000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2354 - accuracy: 0.9056 - val_loss: 0.4416 - val_accuracy: 0.8750 - lr: 1.5000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2248 - accuracy: 0.9066 - val_loss: 0.3047 - val_accuracy: 0.8438 - lr: 1.5000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2227 - accuracy: 0.9090 - val_loss: 0.3371 - val_accuracy: 0.8313 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 13ms/step - loss: 0.7414 - accuracy: 0.6110 - val_loss: 0.6416 - val_accuracy: 0.6375 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6040 - accuracy: 0.6880 - val_loss: 0.5756 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5672 - accuracy: 0.7181 - val_loss: 0.5334 - val_accuracy: 0.7063 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5245 - accuracy: 0.7516 - val_loss: 0.4340 - val_accuracy: 0.7937 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4829 - accuracy: 0.7746 - val_loss: 0.4175 - val_accuracy: 0.7625 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4513 - accuracy: 0.7907 - val_loss: 0.4042 - val_accuracy: 0.7437 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4183 - accuracy: 0.8107 - val_loss: 0.3737 - val_accuracy: 0.7563 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3944 - accuracy: 0.8216 - val_loss: 0.3164 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3716 - accuracy: 0.8299 - val_loss: 0.3484 - val_accuracy: 0.8125 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3296 - accuracy: 0.8506 - val_loss: 0.5117 - val_accuracy: 0.7812 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3247 - accuracy: 0.8561 - val_loss: 0.3902 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3099 - accuracy: 0.8688 - val_loss: 0.4195 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2694 - accuracy: 0.8838 - val_loss: 0.5234 - val_accuracy: 0.8625 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2565 - accuracy: 0.8932 - val_loss: 0.8100 - val_accuracy: 0.8125 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2426 - accuracy: 0.9009 - val_loss: 0.6364 - val_accuracy: 0.8375 - lr: 1.5000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2278 - accuracy: 0.9095 - val_loss: 0.6222 - val_accuracy: 0.8687 - lr: 1.5000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2183 - accuracy: 0.9118 - val_loss: 0.6831 - val_accuracy: 0.8500 - lr: 1.5000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2141 - accuracy: 0.9173 - val_loss: 0.8054 - val_accuracy: 0.8250 - lr: 1.5000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1936 - accuracy: 0.9274 - val_loss: 0.7784 - val_accuracy: 0.8313 - lr: 1.5000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1996 - accuracy: 0.9245 - val_loss: 0.7404 - val_accuracy: 0.8375 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 11ms/step - loss: 0.7634 - accuracy: 0.6131 - val_loss: 0.5380 - val_accuracy: 0.7778 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6011 - accuracy: 0.6989 - val_loss: 0.5480 - val_accuracy: 0.7569 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5591 - accuracy: 0.7322 - val_loss: 0.5109 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5229 - accuracy: 0.7557 - val_loss: 0.4568 - val_accuracy: 0.7778 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4822 - accuracy: 0.7812 - val_loss: 0.4118 - val_accuracy: 0.7847 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4540 - accuracy: 0.7944 - val_loss: 0.4417 - val_accuracy: 0.7639 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4239 - accuracy: 0.8040 - val_loss: 0.4220 - val_accuracy: 0.7917 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3936 - accuracy: 0.8262 - val_loss: 0.3229 - val_accuracy: 0.8403 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3750 - accuracy: 0.8347 - val_loss: 0.3957 - val_accuracy: 0.8194 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3537 - accuracy: 0.8388 - val_loss: 0.2897 - val_accuracy: 0.8403 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3252 - accuracy: 0.8564 - val_loss: 0.2892 - val_accuracy: 0.8194 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3122 - accuracy: 0.8605 - val_loss: 0.3148 - val_accuracy: 0.8403 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2814 - accuracy: 0.8750 - val_loss: 0.1805 - val_accuracy: 0.9514 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2670 - accuracy: 0.8866 - val_loss: 0.1879 - val_accuracy: 0.9514 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2627 - accuracy: 0.8882 - val_loss: 0.1987 - val_accuracy: 0.9167 - lr: 3.0000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2517 - accuracy: 0.8957 - val_loss: 0.1981 - val_accuracy: 0.9028 - lr: 3.0000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2387 - accuracy: 0.9019 - val_loss: 0.2160 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2174 - accuracy: 0.9099 - val_loss: 0.2391 - val_accuracy: 0.8819 - lr: 3.0000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2055 - accuracy: 0.9171 - val_loss: 0.1207 - val_accuracy: 0.9583 - lr: 3.0000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1837 - accuracy: 0.9321 - val_loss: 0.1199 - val_accuracy: 0.9653 - lr: 3.0000e-04
# Epoch 21/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1802 - accuracy: 0.9326 - val_loss: 0.1942 - val_accuracy: 0.9028 - lr: 3.0000e-04
# Epoch 22/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1694 - accuracy: 0.9360 - val_loss: 0.1541 - val_accuracy: 0.9167 - lr: 3.0000e-04
# Epoch 23/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1482 - accuracy: 0.9478 - val_loss: 0.0870 - val_accuracy: 0.9722 - lr: 3.0000e-04
# Epoch 24/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1501 - accuracy: 0.9432 - val_loss: 0.1849 - val_accuracy: 0.9097 - lr: 3.0000e-04
# Epoch 25/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1344 - accuracy: 0.9491 - val_loss: 0.1001 - val_accuracy: 0.9583 - lr: 3.0000e-04
# Epoch 26/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1194 - accuracy: 0.9582 - val_loss: 0.0829 - val_accuracy: 0.9722 - lr: 3.0000e-04
# Epoch 27/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1023 - accuracy: 0.9662 - val_loss: 0.1377 - val_accuracy: 0.9583 - lr: 3.0000e-04
# Epoch 28/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0972 - accuracy: 0.9700 - val_loss: 0.0758 - val_accuracy: 0.9792 - lr: 3.0000e-04
# Epoch 29/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0937 - accuracy: 0.9698 - val_loss: 0.1796 - val_accuracy: 0.9444 - lr: 3.0000e-04
# Epoch 30/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0904 - accuracy: 0.9724 - val_loss: 0.0832 - val_accuracy: 0.9653 - lr: 3.0000e-04
# Epoch 31/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0847 - accuracy: 0.9726 - val_loss: 0.3422 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 32/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0858 - accuracy: 0.9742 - val_loss: 0.1144 - val_accuracy: 0.9653 - lr: 3.0000e-04
# Epoch 33/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0710 - accuracy: 0.9811 - val_loss: 0.2051 - val_accuracy: 0.9097 - lr: 3.0000e-04
# Epoch 34/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0696 - accuracy: 0.9809 - val_loss: 0.0976 - val_accuracy: 0.9583 - lr: 3.0000e-04
# Epoch 35/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0584 - accuracy: 0.9858 - val_loss: 0.1676 - val_accuracy: 0.9444 - lr: 1.5000e-04
# Epoch 36/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0560 - accuracy: 0.9853 - val_loss: 0.1802 - val_accuracy: 0.9375 - lr: 1.5000e-04
# Epoch 37/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0541 - accuracy: 0.9871 - val_loss: 0.1240 - val_accuracy: 0.9514 - lr: 1.5000e-04
# Epoch 38/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0455 - accuracy: 0.9886 - val_loss: 0.0899 - val_accuracy: 0.9653 - lr: 1.5000e-04
# Epoch 39/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0585 - accuracy: 0.9858 - val_loss: 0.0742 - val_accuracy: 0.9792 - lr: 1.5000e-04
# Epoch 40/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0484 - accuracy: 0.9876 - val_loss: 0.1243 - val_accuracy: 0.9722 - lr: 1.5000e-04
# Epoch 41/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0452 - accuracy: 0.9886 - val_loss: 0.1215 - val_accuracy: 0.9583 - lr: 1.5000e-04
# Epoch 42/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0459 - accuracy: 0.9884 - val_loss: 0.2544 - val_accuracy: 0.9028 - lr: 1.5000e-04
# Epoch 43/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0442 - accuracy: 0.9886 - val_loss: 0.2138 - val_accuracy: 0.9583 - lr: 1.5000e-04
# Epoch 44/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0411 - accuracy: 0.9889 - val_loss: 0.1646 - val_accuracy: 0.9722 - lr: 1.5000e-04
# Epoch 45/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0441 - accuracy: 0.9889 - val_loss: 0.2424 - val_accuracy: 0.9375 - lr: 1.5000e-04
# Epoch 46/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0470 - accuracy: 0.9904 - val_loss: 0.2010 - val_accuracy: 0.9514 - lr: 7.5000e-05
# Epoch 47/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0344 - accuracy: 0.9920 - val_loss: 0.1588 - val_accuracy: 0.9583 - lr: 7.5000e-05
# Epoch 48/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0376 - accuracy: 0.9917 - val_loss: 0.1271 - val_accuracy: 0.9653 - lr: 7.5000e-05
# Epoch 49/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0292 - accuracy: 0.9951 - val_loss: 0.1766 - val_accuracy: 0.9583 - lr: 7.5000e-05
# Epoch 50/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.0354 - accuracy: 0.9930 - val_loss: 0.1943 - val_accuracy: 0.9583 - lr: 7.5000e-05
# Epoch 51/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0328 - accuracy: 0.9933 - val_loss: 0.1795 - val_accuracy: 0.9653 - lr: 7.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 2s 14ms/step - loss: 0.7159 - accuracy: 0.6019 - val_loss: 0.5887 - val_accuracy: 0.6875 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.6045 - accuracy: 0.6973 - val_loss: 0.5510 - val_accuracy: 0.7109 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5682 - accuracy: 0.7225 - val_loss: 0.4663 - val_accuracy: 0.7266 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5322 - accuracy: 0.7395 - val_loss: 0.4295 - val_accuracy: 0.7891 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4914 - accuracy: 0.7747 - val_loss: 0.3926 - val_accuracy: 0.8281 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4515 - accuracy: 0.7919 - val_loss: 0.3337 - val_accuracy: 0.8594 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4248 - accuracy: 0.8076 - val_loss: 0.3349 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4029 - accuracy: 0.8182 - val_loss: 0.2798 - val_accuracy: 0.9297 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3798 - accuracy: 0.8338 - val_loss: 0.2617 - val_accuracy: 0.9609 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3456 - accuracy: 0.8521 - val_loss: 0.2439 - val_accuracy: 0.8984 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3238 - accuracy: 0.8552 - val_loss: 0.2613 - val_accuracy: 0.9609 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2978 - accuracy: 0.8722 - val_loss: 0.2858 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2841 - accuracy: 0.8801 - val_loss: 0.2301 - val_accuracy: 0.9688 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2565 - accuracy: 0.8958 - val_loss: 0.2505 - val_accuracy: 0.8594 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2552 - accuracy: 0.8989 - val_loss: 0.2692 - val_accuracy: 0.8594 - lr: 3.0000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2295 - accuracy: 0.9113 - val_loss: 0.2359 - val_accuracy: 0.8594 - lr: 3.0000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2034 - accuracy: 0.9162 - val_loss: 0.2328 - val_accuracy: 0.8828 - lr: 3.0000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2093 - accuracy: 0.9213 - val_loss: 0.1847 - val_accuracy: 0.8906 - lr: 3.0000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1910 - accuracy: 0.9267 - val_loss: 0.2500 - val_accuracy: 0.8594 - lr: 3.0000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1955 - accuracy: 0.9252 - val_loss: 0.1774 - val_accuracy: 0.8828 - lr: 3.0000e-04
# Epoch 21/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1523 - accuracy: 0.9475 - val_loss: 0.1330 - val_accuracy: 0.9609 - lr: 3.0000e-04
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1535 - accuracy: 0.9465 - val_loss: 0.2045 - val_accuracy: 0.8828 - lr: 3.0000e-04
# Epoch 23/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1486 - accuracy: 0.9486 - val_loss: 0.1223 - val_accuracy: 0.9766 - lr: 3.0000e-04
# Epoch 24/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1351 - accuracy: 0.9534 - val_loss: 0.0990 - val_accuracy: 0.9609 - lr: 3.0000e-04
# Epoch 25/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1169 - accuracy: 0.9614 - val_loss: 0.0662 - val_accuracy: 0.9922 - lr: 3.0000e-04
# Epoch 26/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1114 - accuracy: 0.9653 - val_loss: 0.1715 - val_accuracy: 0.9062 - lr: 3.0000e-04
# Epoch 27/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1141 - accuracy: 0.9586 - val_loss: 0.2612 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 28/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1021 - accuracy: 0.9663 - val_loss: 0.1004 - val_accuracy: 0.9609 - lr: 3.0000e-04
# Epoch 29/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0923 - accuracy: 0.9709 - val_loss: 0.0773 - val_accuracy: 0.9844 - lr: 3.0000e-04
# Epoch 30/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0763 - accuracy: 0.9758 - val_loss: 0.0986 - val_accuracy: 0.9609 - lr: 3.0000e-04
# Epoch 31/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0915 - accuracy: 0.9694 - val_loss: 0.0551 - val_accuracy: 0.9922 - lr: 3.0000e-04
# Epoch 32/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0846 - accuracy: 0.9733 - val_loss: 0.1234 - val_accuracy: 0.9297 - lr: 3.0000e-04
# Epoch 33/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0752 - accuracy: 0.9771 - val_loss: 0.2465 - val_accuracy: 0.8984 - lr: 3.0000e-04
# Epoch 34/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0731 - accuracy: 0.9807 - val_loss: 0.0352 - val_accuracy: 0.9922 - lr: 3.0000e-04
# Epoch 35/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.0625 - accuracy: 0.9835 - val_loss: 0.0301 - val_accuracy: 1.0000 - lr: 3.0000e-04
# ...
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1706 - accuracy: 0.9339 - val_loss: 0.8913 - val_accuracy: 0.6500 - lr: 1.5000e-04
# Epoch 23/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1436 - accuracy: 0.9450 - val_loss: 0.9554 - val_accuracy: 0.6625 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.7022 - accuracy: 0.6271 - val_loss: 0.6823 - val_accuracy: 0.5938 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5926 - accuracy: 0.7059 - val_loss: 0.6891 - val_accuracy: 0.5813 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5448 - accuracy: 0.7391 - val_loss: 0.6921 - val_accuracy: 0.5938 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5081 - accuracy: 0.7609 - val_loss: 0.6886 - val_accuracy: 0.5688 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4689 - accuracy: 0.7848 - val_loss: 0.6919 - val_accuracy: 0.5562 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4399 - accuracy: 0.7943 - val_loss: 0.7060 - val_accuracy: 0.5437 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4169 - accuracy: 0.8099 - val_loss: 0.7082 - val_accuracy: 0.5938 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3819 - accuracy: 0.8309 - val_loss: 0.6939 - val_accuracy: 0.5938 - lr: 1.5000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3752 - accuracy: 0.8343 - val_loss: 0.6222 - val_accuracy: 0.7125 - lr: 1.5000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3580 - accuracy: 0.8353 - val_loss: 0.5646 - val_accuracy: 0.7063 - lr: 1.5000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3465 - accuracy: 0.8465 - val_loss: 0.7114 - val_accuracy: 0.7125 - lr: 1.5000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3423 - accuracy: 0.8431 - val_loss: 0.6527 - val_accuracy: 0.7375 - lr: 1.5000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3185 - accuracy: 0.8579 - val_loss: 0.6512 - val_accuracy: 0.7312 - lr: 1.5000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3073 - accuracy: 0.8641 - val_loss: 0.6716 - val_accuracy: 0.7812 - lr: 1.5000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3024 - accuracy: 0.8628 - val_loss: 0.6211 - val_accuracy: 0.8000 - lr: 1.5000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2781 - accuracy: 0.8823 - val_loss: 0.7045 - val_accuracy: 0.7250 - lr: 1.5000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2764 - accuracy: 0.8849 - val_loss: 0.6695 - val_accuracy: 0.7437 - lr: 7.5000e-05
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2684 - accuracy: 0.8859 - val_loss: 0.6926 - val_accuracy: 0.7563 - lr: 7.5000e-05
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2590 - accuracy: 0.8911 - val_loss: 0.6969 - val_accuracy: 0.7875 - lr: 7.5000e-05
# Epoch 20/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2511 - accuracy: 0.8890 - val_loss: 0.6775 - val_accuracy: 0.7937 - lr: 7.5000e-05
# Epoch 21/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2552 - accuracy: 0.8864 - val_loss: 0.8265 - val_accuracy: 0.7750 - lr: 7.5000e-05
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2476 - accuracy: 0.8942 - val_loss: 0.7711 - val_accuracy: 0.7875 - lr: 7.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.7510 - accuracy: 0.6247 - val_loss: 0.5016 - val_accuracy: 0.7812 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5864 - accuracy: 0.7088 - val_loss: 0.5349 - val_accuracy: 0.7375 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5539 - accuracy: 0.7373 - val_loss: 0.5118 - val_accuracy: 0.7937 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5041 - accuracy: 0.7632 - val_loss: 0.4834 - val_accuracy: 0.8062 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 1s 10ms/step - loss: 0.4720 - accuracy: 0.7783 - val_loss: 0.4871 - val_accuracy: 0.7812 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4412 - accuracy: 0.8060 - val_loss: 0.4465 - val_accuracy: 0.8687 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4108 - accuracy: 0.8109 - val_loss: 0.4555 - val_accuracy: 0.7937 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3852 - accuracy: 0.8260 - val_loss: 0.4573 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3560 - accuracy: 0.8415 - val_loss: 0.4277 - val_accuracy: 0.7437 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3251 - accuracy: 0.8592 - val_loss: 0.3793 - val_accuracy: 0.8375 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3123 - accuracy: 0.8574 - val_loss: 0.3871 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3015 - accuracy: 0.8703 - val_loss: 0.4006 - val_accuracy: 0.7063 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2901 - accuracy: 0.8740 - val_loss: 0.4501 - val_accuracy: 0.7063 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2714 - accuracy: 0.8828 - val_loss: 0.3977 - val_accuracy: 0.7625 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2431 - accuracy: 0.8989 - val_loss: 0.6917 - val_accuracy: 0.6187 - lr: 3.0000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2381 - accuracy: 0.9009 - val_loss: 0.4205 - val_accuracy: 0.7250 - lr: 3.0000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2165 - accuracy: 0.9085 - val_loss: 0.4086 - val_accuracy: 0.7750 - lr: 1.5000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2080 - accuracy: 0.9183 - val_loss: 0.4195 - val_accuracy: 0.7563 - lr: 1.5000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1891 - accuracy: 0.9219 - val_loss: 0.3916 - val_accuracy: 0.8125 - lr: 1.5000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1964 - accuracy: 0.9238 - val_loss: 0.4547 - val_accuracy: 0.7437 - lr: 1.5000e-04
# Epoch 21/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1816 - accuracy: 0.9279 - val_loss: 0.7172 - val_accuracy: 0.7000 - lr: 1.5000e-04
# Epoch 22/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1767 - accuracy: 0.9289 - val_loss: 0.5103 - val_accuracy: 0.7625 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.7254 - accuracy: 0.6131 - val_loss: 0.5773 - val_accuracy: 0.7437 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6145 - accuracy: 0.6875 - val_loss: 0.5690 - val_accuracy: 0.7375 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5563 - accuracy: 0.7321 - val_loss: 0.5592 - val_accuracy: 0.7812 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.5118 - accuracy: 0.7554 - val_loss: 0.5728 - val_accuracy: 0.7812 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4729 - accuracy: 0.7873 - val_loss: 0.6108 - val_accuracy: 0.6562 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4362 - accuracy: 0.8013 - val_loss: 0.6687 - val_accuracy: 0.6500 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4090 - accuracy: 0.8161 - val_loss: 0.6786 - val_accuracy: 0.6187 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3736 - accuracy: 0.8345 - val_loss: 0.7702 - val_accuracy: 0.5750 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3521 - accuracy: 0.8509 - val_loss: 0.8213 - val_accuracy: 0.4938 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3184 - accuracy: 0.8688 - val_loss: 0.8958 - val_accuracy: 0.4625 - lr: 1.5000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3124 - accuracy: 0.8703 - val_loss: 0.8576 - val_accuracy: 0.5125 - lr: 1.5000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3008 - accuracy: 0.8784 - val_loss: 0.8879 - val_accuracy: 0.4812 - lr: 1.5000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2939 - accuracy: 0.8760 - val_loss: 0.9521 - val_accuracy: 0.5188 - lr: 1.5000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2707 - accuracy: 0.8937 - val_loss: 1.1028 - val_accuracy: 0.4875 - lr: 1.5000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2656 - accuracy: 0.8952 - val_loss: 1.0616 - val_accuracy: 0.4938 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 12ms/step - loss: 0.6981 - accuracy: 0.6247 - val_loss: 0.6136 - val_accuracy: 0.6250 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5830 - accuracy: 0.7077 - val_loss: 0.6363 - val_accuracy: 0.6062 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5497 - accuracy: 0.7350 - val_loss: 0.6087 - val_accuracy: 0.6187 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5160 - accuracy: 0.7622 - val_loss: 0.6320 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4577 - accuracy: 0.7912 - val_loss: 0.7157 - val_accuracy: 0.6375 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4218 - accuracy: 0.8104 - val_loss: 0.7206 - val_accuracy: 0.6187 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3882 - accuracy: 0.8299 - val_loss: 0.9383 - val_accuracy: 0.6125 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3526 - accuracy: 0.8467 - val_loss: 0.8948 - val_accuracy: 0.6500 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3343 - accuracy: 0.8527 - val_loss: 0.8298 - val_accuracy: 0.6500 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3114 - accuracy: 0.8638 - val_loss: 0.8957 - val_accuracy: 0.6500 - lr: 1.5000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2949 - accuracy: 0.8729 - val_loss: 0.9020 - val_accuracy: 0.6438 - lr: 1.5000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2873 - accuracy: 0.8794 - val_loss: 0.9246 - val_accuracy: 0.6313 - lr: 1.5000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2601 - accuracy: 0.8939 - val_loss: 1.0410 - val_accuracy: 0.6313 - lr: 1.5000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2657 - accuracy: 0.8955 - val_loss: 1.0660 - val_accuracy: 0.6375 - lr: 1.5000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2495 - accuracy: 0.9051 - val_loss: 1.0659 - val_accuracy: 0.6313 - lr: 1.5000e-04
# Epoch 1/80
# 61/61 [==============================] - 2s 13ms/step - loss: 0.7479 - accuracy: 0.6131 - val_loss: 0.6755 - val_accuracy: 0.5250 - lr: 3.0000e-04
# Epoch 2/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.6087 - accuracy: 0.6857 - val_loss: 0.6534 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 3/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5553 - accuracy: 0.7295 - val_loss: 0.6119 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 4/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.5120 - accuracy: 0.7503 - val_loss: 0.6120 - val_accuracy: 0.7812 - lr: 3.0000e-04
# Epoch 5/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4854 - accuracy: 0.7746 - val_loss: 0.5970 - val_accuracy: 0.7563 - lr: 3.0000e-04
# Epoch 6/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.4447 - accuracy: 0.8011 - val_loss: 0.5965 - val_accuracy: 0.7063 - lr: 3.0000e-04
# Epoch 7/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.4117 - accuracy: 0.8125 - val_loss: 0.5877 - val_accuracy: 0.6625 - lr: 3.0000e-04
# Epoch 8/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3898 - accuracy: 0.8205 - val_loss: 0.5999 - val_accuracy: 0.6438 - lr: 3.0000e-04
# Epoch 9/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3559 - accuracy: 0.8426 - val_loss: 0.6223 - val_accuracy: 0.6187 - lr: 3.0000e-04
# Epoch 10/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3360 - accuracy: 0.8550 - val_loss: 0.5678 - val_accuracy: 0.6438 - lr: 3.0000e-04
# Epoch 11/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.3138 - accuracy: 0.8651 - val_loss: 0.6170 - val_accuracy: 0.6125 - lr: 3.0000e-04
# Epoch 12/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.3100 - accuracy: 0.8649 - val_loss: 0.6502 - val_accuracy: 0.5688 - lr: 3.0000e-04
# Epoch 13/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2686 - accuracy: 0.8825 - val_loss: 0.6850 - val_accuracy: 0.5375 - lr: 3.0000e-04
# Epoch 14/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2520 - accuracy: 0.8950 - val_loss: 0.6488 - val_accuracy: 0.5813 - lr: 3.0000e-04
# Epoch 15/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2369 - accuracy: 0.9012 - val_loss: 0.7014 - val_accuracy: 0.5375 - lr: 3.0000e-04
# Epoch 16/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.2383 - accuracy: 0.9033 - val_loss: 0.6047 - val_accuracy: 0.6125 - lr: 3.0000e-04
# Epoch 17/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2079 - accuracy: 0.9173 - val_loss: 0.7370 - val_accuracy: 0.5688 - lr: 1.5000e-04
# Epoch 18/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.2090 - accuracy: 0.9139 - val_loss: 0.7175 - val_accuracy: 0.5437 - lr: 1.5000e-04
# Epoch 19/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1972 - accuracy: 0.9196 - val_loss: 0.6908 - val_accuracy: 0.5625 - lr: 1.5000e-04
# Epoch 20/80
# 61/61 [==============================] - 0s 7ms/step - loss: 0.1909 - accuracy: 0.9300 - val_loss: 0.8277 - val_accuracy: 0.5312 - lr: 1.5000e-04
# Epoch 21/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1903 - accuracy: 0.9292 - val_loss: 0.8071 - val_accuracy: 0.5250 - lr: 1.5000e-04
# Epoch 22/80
# 61/61 [==============================] - 0s 8ms/step - loss: 0.1706 - accuracy: 0.9359 - val_loss: 0.8566 - val_accuracy: 0.5375 - lr: 1.5000e-04
#
# ==== LOSO Summary (Up/Down) ====
# Mean Window Acc: 0.768 ± 0.145
# Mean Clip   Acc: 0.778 ± 0.147
#
# ==== OVERALL (클립) ====
# Overall 클립 Acc: 0.769
#               precision    recall  f1-score   support
#
#            위      0.768     0.768     0.768       250
#           아래      0.770     0.770     0.770       252
#
#     accuracy                          0.769       502
#    macro avg      0.769     0.769     0.769       502
# weighted avg      0.769     0.769     0.769       502

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

# --- 그대로 재사용 ---
def _fixed_time_derivatives_with_mask(x, m):
    x_prev = tf.pad(x[:, :-1, :], [[0,0],[1,0],[0,0]])
    dx = x - x_prev
    dx_prev = tf.pad(dx[:, :-1, :], [[0,0],[1,0],[0,0]])
    ddx = dx - dx_prev
    dx  = tf.concat([tf.zeros_like(dx[:, :1, :]),  dx[:, 1:, :]], axis=1)
    ddx = tf.concat([tf.zeros_like(ddx[:, :2, :]), ddx[:, 2:, :]], axis=1)

    gate_dx  = tf.concat([tf.zeros_like(m[:, :1, :]),  m[:, 1:, :]], axis=1)
    gate_ddx = tf.concat([tf.zeros_like(m[:, :2, :]), m[:, 2:, :]], axis=1)
    dx  = dx  * gate_dx
    ddx = ddx * gate_ddx
    return tf.concat([x, dx, ddx], axis=-1)  # (B,T,3F)

def build_hybrid_cnn_gru_updown(input_shape, n_classes=2,
                                base_ch=64,   # CNN 채널 폭
                                k=5,          # 커널 크기
                                gru_units=64, # 첫 GRU 유닛
                                l2=1e-4,
                                p_spatial=0.2,
                                p_drop=0.5,
                                lr=5e-5):
    """
    입력: inp_x=(L,F) (스케일된 좌표), inp_m=(L,1) (0/1 마스크)
    블록: [Δ/Δ² 부착] -> [1×1 bottleneck] -> [Separable TConv × 3 (dilation=1,2,4, residual)]
        -> SpatialDropout -> [GRU(64, rs=True) -> GRU(32)] -> 마스크드 어텐션 -> Dense
    """
    L, F = input_shape
    inp_x = layers.Input(shape=(L, F), name="inp_x")
    inp_m = layers.Input(shape=(L, 1), name="inp_m")   # 0/1

    # 1) Δ/Δ² 부착
    x = layers.Lambda(lambda z: _fixed_time_derivatives_with_mask(z[0], z[1]),
                      name="fixed_diffs")([inp_x, inp_m])      # (B,T,3F)

    # 2) 1×1 bottleneck로 채널 압축 (3F -> base_ch)
    x = layers.Conv1D(base_ch, 1, use_bias=False,
                      kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.LayerNormalization()(x)
    x = layers.Activation('relu')(x)

    # 3) 마스크로 비활성 프레임 zero-out (CNN/GRU 모두에 적용)
    x = layers.Multiply()([x, inp_m])

    # 4) 다이레이티드 Separable Temporal Convs (+Residual)
    def sep_block(x, dilation):
        shortcut = x
        y = layers.SeparableConv1D(base_ch, k, padding='same', dilation_rate=dilation,
                                   depthwise_regularizer=regularizers.l2(l2),
                                   pointwise_regularizer=regularizers.l2(l2),
                                   use_bias=False)(x)
        y = layers.LayerNormalization()(y)
        y = layers.Activation('relu')(y)
        y = layers.SeparableConv1D(base_ch, 1, padding='same', use_bias=False)(y)
        y = layers.LayerNormalization()(y)
        # Residual
        x = layers.Add()([shortcut, y])
        x = layers.Activation('relu')(x)
        return x

    x = sep_block(x, dilation=1)
    x = sep_block(x, dilation=2)
    x = sep_block(x, dilation=4)
    x = layers.SpatialDropout1D(p_spatial)(x)

    # 5) GRU 스택 (장기 의존성)
    x = layers.GRU(gru_units, return_sequences=True,
                   dropout=p_drop, recurrent_dropout=0.0,
                   kernel_regularizer=regularizers.l2(l2),
                   recurrent_regularizer=regularizers.l2(l2))(x)
    x = layers.GRU(gru_units//2, return_sequences=True,
                   dropout=p_drop, recurrent_dropout=0.0,
                   kernel_regularizer=regularizers.l2(l2),
                   recurrent_regularizer=regularizers.l2(l2))(x)

    # 6) 마스크드 어텐션 풀링 (가중 평균)
    # scores: (B,T,1)
    scores = layers.Dense(1, use_bias=False)(x)
    # 마스크가 0인 위치는 큰 음수로 가려서 softmax 제외
    very_neg = -1e9
    scores = layers.Add()([scores, (inp_m - 1.0) * very_neg])
    alpha = layers.Softmax(axis=1, name="attn_weights")(scores)      # (B,T,1)
    x = layers.Multiply()([x, alpha])                                # (B,T,C)
    x = tf.reduce_sum(x, axis=1)                                     # (B,C)

    # 7) 분류 헤드
    x = layers.LayerNormalization()(x)
    x = layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.Dropout(p_drop)(x)
    out = layers.Dense(n_classes, activation='softmax')(x)

    model = tf.keras.Model([inp_x, inp_m], out)
    opt = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=1.0)
    model.compile(optimizer=opt,
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])
    return model

# %%
# =========================
# 위/아래 2-class LOSO 학습/평가 (평균 곡선 포함)
# =========================

from sklearn.model_selection import LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager
import tensorflow as tf
from tensorflow.keras import layers, regularizers

# ===== 옵션 =====
EPOCHS = 80
BATCH_SIZE = 64
ES_PATIENCE = 12
RLR_PATIENCE = 6

PLOT_LAST_FOLD_CURVES = True   # 폴드 개별 곡선(마지막 폴드만)
EVAL_LEVEL = "clip"            # "clip" 또는 "window"

# ===== 한글 폰트 =====
def setup_korean_font():
    candidates = ["Malgun Gothic", "AppleGothic", "NanumGothic", "Noto Sans CJK KR", "Noto Sans KR"]
    installed = {f.name for f in font_manager.fontManager.ttflist}
    for name in candidates:
        if name in installed:
            plt.rcParams["font.family"] = name
            break
    plt.rcParams["axes.unicode_minus"] = False
setup_korean_font()

# ===== 시각화 헬퍼 =====
def plot_training_curves(history, fold_no):
    H = history.history
    plt.figure()
    plt.plot(H.get('loss', []),     label='loss')
    plt.plot(H.get('val_loss', []), label='val_loss')
    plt.title(f'Fold {fold_no} - Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss')
    plt.legend(); plt.tight_layout(); plt.show()

    if 'accuracy' in H and 'val_accuracy' in H:
        plt.figure()
        plt.plot(H['accuracy'],     label='accuracy')
        plt.plot(H['val_accuracy'], label='val_accuracy')
        plt.title(f'Fold {fold_no} - Accuracy')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

def norm_cm(cm):
    with np.errstate(invalid='ignore', divide='ignore'):
        cmn = cm.astype(float) / cm.sum(axis=1, keepdims=True)
        cmn = np.nan_to_num(cmn)
    return cmn

def plot_confmat_ratio(cm, classes, title):
    M = norm_cm(cm)
    plt.figure()
    im = plt.imshow(M, interpolation='nearest', cmap='Blues', vmin=0.0, vmax=1.0)
    plt.title(title); plt.colorbar(im)
    ticks = np.arange(len(classes))
    plt.xticks(ticks, classes); plt.yticks(ticks, classes)
    for i in range(M.shape[0]):
        for j in range(M.shape[1]):
            val = M[i, j]
            txt_color = 'black' if val < 0.6 else 'white'
            plt.text(j, i, f"{val:.2f}", ha="center", va="center", color=txt_color, fontsize=10)
    plt.ylabel('실제 레이블'); plt.xlabel('예측 레이블')
    plt.tight_layout(); plt.show()

# ----- 폴드 평균 곡선 -----
def _nanmean_along_epochs(list_of_lists):
    if not list_of_lists:
        return None, None
    maxlen = max(len(s) for s in list_of_lists)
    M = np.full((len(list_of_lists), maxlen), np.nan, dtype=np.float32)
    for i, s in enumerate(list_of_lists):
        arr = np.asarray(s, dtype=np.float32)
        M[i, :len(arr)] = arr
    return np.nanmean(M, axis=0), np.nanstd(M, axis=0)

def plot_mean_training_curves(histories):
    # Loss
    mean_loss, std_loss         = _nanmean_along_epochs([h.get('loss', []) for h in histories])
    mean_val_loss, std_val_loss = _nanmean_along_epochs([h.get('val_loss', []) for h in histories])

    if mean_loss is not None:
        x = np.arange(len(mean_loss))
        plt.figure()
        plt.plot(x, mean_loss,     label='loss (mean)')
        plt.plot(x, mean_val_loss, label='val_loss (mean)')
        plt.fill_between(x, mean_loss - std_loss,     mean_loss + std_loss,     alpha=0.15)
        plt.fill_between(x, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.15)
        plt.title('LOSO 평균 Loss (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Loss')
        plt.legend(); plt.tight_layout(); plt.show()

    # Accuracy
    has_acc = all(('accuracy' in h and 'val_accuracy' in h) for h in histories)
    if has_acc:
        mean_acc, std_acc         = _nanmean_along_epochs([h['accuracy']     for h in histories])
        mean_val_acc, std_val_acc = _nanmean_along_epochs([h['val_accuracy'] for h in histories])
        x = np.arange(len(mean_acc))
        plt.figure()
        plt.plot(x, mean_acc,     label='accuracy (mean)')
        plt.plot(x, mean_val_acc, label='val_accuracy (mean)')
        plt.fill_between(x, mean_acc - std_acc,     mean_acc + std_acc,     alpha=0.15)
        plt.fill_between(x, mean_val_acc - std_val_acc, mean_val_acc + std_val_acc, alpha=0.15)
        plt.title('LOSO 평균 Accuracy (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

# ===== 13 → 2 (위/아래) 매핑 및 데이터 필터 =====
#  - 위(0): '구개측' 또는 '위-씹는면' 이 포함된 라벨
#  - 아래(1): '설측' 또는 '아래-씹는면' 이 포함된 라벨
#  - 그 외(예: '협측')는 제외
labels_np = np.array(KOREAN_LABELS, dtype=object)

def _ud_from_label(lab: str):
    if ('구개측' in lab) or ('위-씹는면' in lab):
        return 0  # 위
    if ('설측' in lab) or ('아래-씹는면' in lab):
        return 1  # 아래
    return None   # 제외(협측 등)

# 인덱스 마스크 생성
keep_indices = []
y_ud_list = []
for i, yi in enumerate(y):
    lab = labels_np[yi]
    mcls = _ud_from_label(lab)
    if mcls is not None:
        keep_indices.append(i)
        y_ud_list.append(mcls)

keep_indices = np.array(keep_indices, dtype=int)
X_ud = X[keep_indices]                 # (N_ud, L, F)
M_ud = M[keep_indices]                 # (N_ud, L, 1)  <- 추가
y_ud = np.array(y_ud_list, dtype=int)
meta_ud = [meta[i] for i in keep_indices]
persons_ud = np.array([m["person"] for m in meta_ud])

print(f"[Filter] 총 {len(X)}개 중 {len(X_ud)}개 사용.  M shape: {M_ud.shape},  분포:", np.bincount(y_ud))


# ===== LOSO 학습/평가 =====
F = X_ud.shape[-1]
HAND_DIMS = 42 if F >= 42 else F
EPS = 1e-7
logo = LeaveOneGroupOut()

CLASS_NAMES = ['위','아래']

# 집계 버퍼
histories = []
all_win_true, all_win_pred = [], []
all_clip_true, all_clip_pred = [], []
all_win_acc, all_clip_acc = [], []

fold_no = 0
total_folds = len(np.unique(persons_ud))

for train_idx, val_idx in logo.split(X_ud, y_ud, groups=persons_ud):
    X_train, y_train = X_ud[train_idx], y_ud[train_idx]
    X_val,   y_val   = X_ud[val_idx],   y_ud[val_idx]
    M_train, M_val   = M_ud[train_idx], M_ud[val_idx]     # ← 추가

    scaler = StandardScaler(with_mean=True, with_std=True)
    Xtr_flat = X_train.reshape(-1, F)
    mask = (np.abs(Xtr_flat[:, :HAND_DIMS]).sum(axis=1) > EPS)
    scaler.fit(Xtr_flat[mask] if mask.any() else Xtr_flat)

    X_train_s = scaler.transform(X_train.reshape(-1, F)).reshape(X_train.shape)
    X_val_s   = scaler.transform(X_val.reshape(-1, F)).reshape(X_val.shape)
    # M_train, M_val 는 스케일링 절대 금지 (0/1 유지)

    # 모델
    model = build_hybrid_cnn_gru_updown(
    input_shape=(X_train_s.shape[1], X_train_s.shape[2]),
    n_classes=2
    )
    
    cls_counts = np.bincount(y_train, minlength=2)
    class_weights = {i: float(np.median(cls_counts)/c) for i, c in enumerate(cls_counts)}

    cb = [
        tf.keras.callbacks.EarlyStopping(patience=ES_PATIENCE, restore_best_weights=True, monitor='val_loss'),
        tf.keras.callbacks.ReduceLROnPlateau(patience=RLR_PATIENCE, factor=0.5, min_lr=1e-5),
    ]

    history = model.fit(
        [X_train_s, M_train], y_train,
        validation_data=([X_val_s, M_val], y_val),
        epochs=EPOCHS, batch_size=BATCH_SIZE,
        class_weight=class_weights,
        callbacks=cb, verbose=1
    )
    histories.append(history.history)

    if PLOT_LAST_FOLD_CURVES and fold_no == total_folds:
        plot_training_curves(history, fold_no)

    # 윈도우 단위
    p = model.predict([X_val_s, M_val], verbose=0)
    y_pred = p.argmax(1)
    win_acc = accuracy_score(y_val, y_pred)
    all_win_acc.append(win_acc)
    all_win_true.append(y_val); all_win_pred.append(y_pred)

    # 클립 단위
    bucket_p, bucket_y = defaultdict(list), {}
    val_meta = [meta_ud[i] for i in val_idx]
    for i, m in enumerate(val_meta):
        bucket_p[m["src"]].append(p[i])
        bucket_y[m["src"]] = y_val[i]
    P_clip, Y_clip = [], []
    for src, ps in bucket_p.items():
        P_clip.append(np.mean(ps, axis=0))
        Y_clip.append(bucket_y[src])
    clip_pred = np.argmax(np.vstack(P_clip), axis=1)
    clip_acc = accuracy_score(Y_clip, clip_pred)
    all_clip_acc.append(clip_acc)
    all_clip_true.append(np.array(Y_clip))
    all_clip_pred.append(clip_pred)

# ===== 폴드 전체 집계 =====
all_win_true  = np.concatenate(all_win_true, axis=0)
all_win_pred  = np.concatenate(all_win_pred, axis=0)
all_clip_true = np.concatenate(all_clip_true, axis=0)
all_clip_pred = np.concatenate(all_clip_pred, axis=0)

print("\n==== LOSO Summary (Up/Down) ====")
print(f"Mean Window Acc: {np.mean(all_win_acc):.3f} ± {np.std(all_win_acc):.3f}")
print(f"Mean Clip   Acc: {np.mean(all_clip_acc):.3f} ± {np.std(all_clip_acc):.3f}")

# ===== 최종(전체 사람) 혼동행렬/지표 =====
if EVAL_LEVEL == "clip":
    y_true_overall = all_clip_true; y_pred_overall = all_clip_pred; level_name = "클립"
else:
    y_true_overall = all_win_true;  y_pred_overall = all_win_pred;  level_name = "윈도우"

overall_acc = accuracy_score(y_true_overall, y_pred_overall)
print(f"\n==== OVERALL ({level_name}) ====")
print(f"Overall {level_name} Acc: {overall_acc:.3f}")
print(classification_report(y_true_overall, y_pred_overall, target_names=CLASS_NAMES, digits=3))

cm_overall = confusion_matrix(y_true_overall, y_pred_overall, labels=[0,1])
plot_confmat_ratio(cm_overall, CLASS_NAMES, f'전체 {level_name} 혼동행렬 (행 정규화, 비율)')

# ===== LOSO 평균 곡선 =====
plot_mean_training_curves(histories)
# Out:
# [Filter] 총 5248개 중 4016개 사용.  M shape: (4016, 45, 1),  분포: [2000 2016]
# Epoch 1/80
# 57/57 [==============================] - 4s 24ms/step - loss: 0.8831 - accuracy: 0.5028 - val_loss: 0.7094 - val_accuracy: 0.6325 - lr: 5.0000e-05
# Epoch 2/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.8024 - accuracy: 0.5216 - val_loss: 0.6881 - val_accuracy: 0.7925 - lr: 5.0000e-05
# Epoch 3/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7779 - accuracy: 0.5401 - val_loss: 0.6804 - val_accuracy: 0.8100 - lr: 5.0000e-05
# Epoch 4/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7526 - accuracy: 0.5639 - val_loss: 0.6772 - val_accuracy: 0.7800 - lr: 5.0000e-05
# Epoch 5/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7399 - accuracy: 0.5813 - val_loss: 0.6671 - val_accuracy: 0.7400 - lr: 5.0000e-05
# Epoch 6/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7233 - accuracy: 0.6065 - val_loss: 0.6531 - val_accuracy: 0.7150 - lr: 5.0000e-05
# Epoch 7/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7043 - accuracy: 0.6181 - val_loss: 0.6323 - val_accuracy: 0.6950 - lr: 5.0000e-05
# Epoch 8/80
# 57/57 [==============================] - 1s 15ms/step - loss: 0.6929 - accuracy: 0.6319 - val_loss: 0.6090 - val_accuracy: 0.7400 - lr: 5.0000e-05
# Epoch 9/80
# 57/57 [==============================] - 1s 15ms/step - loss: 0.6787 - accuracy: 0.6565 - val_loss: 0.5868 - val_accuracy: 0.7450 - lr: 5.0000e-05
# Epoch 10/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6647 - accuracy: 0.6692 - val_loss: 0.5953 - val_accuracy: 0.6700 - lr: 5.0000e-05
# Epoch 11/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6470 - accuracy: 0.6787 - val_loss: 0.5585 - val_accuracy: 0.7375 - lr: 5.0000e-05
# Epoch 12/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6278 - accuracy: 0.7046 - val_loss: 0.5390 - val_accuracy: 0.7750 - lr: 5.0000e-05
# Epoch 13/80
# 57/57 [==============================] - 1s 15ms/step - loss: 0.6079 - accuracy: 0.7190 - val_loss: 0.5243 - val_accuracy: 0.7800 - lr: 5.0000e-05
# Epoch 14/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5908 - accuracy: 0.7257 - val_loss: 0.4819 - val_accuracy: 0.8400 - lr: 5.0000e-05
# Epoch 15/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5622 - accuracy: 0.7539 - val_loss: 0.4970 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 16/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5101 - accuracy: 0.7873 - val_loss: 0.4592 - val_accuracy: 0.7250 - lr: 5.0000e-05
# Epoch 17/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.4751 - accuracy: 0.8136 - val_loss: 0.4516 - val_accuracy: 0.7525 - lr: 5.0000e-05
# Epoch 18/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.4391 - accuracy: 0.8299 - val_loss: 0.4211 - val_accuracy: 0.7975 - lr: 5.0000e-05
# Epoch 19/80
# 57/57 [==============================] - 1s 13ms/step - loss: 0.4060 - accuracy: 0.8485 - val_loss: 0.4508 - val_accuracy: 0.8225 - lr: 5.0000e-05
# Epoch 20/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3715 - accuracy: 0.8750 - val_loss: 0.4945 - val_accuracy: 0.8175 - lr: 5.0000e-05
# Epoch 21/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3497 - accuracy: 0.8855 - val_loss: 0.4551 - val_accuracy: 0.8300 - lr: 5.0000e-05
# Epoch 22/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3095 - accuracy: 0.9029 - val_loss: 0.4693 - val_accuracy: 0.8350 - lr: 5.0000e-05
# Epoch 23/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2994 - accuracy: 0.9104 - val_loss: 0.5740 - val_accuracy: 0.8175 - lr: 5.0000e-05
# Epoch 24/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2696 - accuracy: 0.9226 - val_loss: 0.5644 - val_accuracy: 0.8175 - lr: 5.0000e-05
# Epoch 25/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2602 - accuracy: 0.9281 - val_loss: 0.6258 - val_accuracy: 0.8100 - lr: 2.5000e-05
# Epoch 26/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2561 - accuracy: 0.9289 - val_loss: 0.5605 - val_accuracy: 0.8225 - lr: 2.5000e-05
# Epoch 27/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2490 - accuracy: 0.9394 - val_loss: 0.6105 - val_accuracy: 0.8150 - lr: 2.5000e-05
# Epoch 28/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2295 - accuracy: 0.9433 - val_loss: 0.6305 - val_accuracy: 0.8150 - lr: 2.5000e-05
# Epoch 29/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2372 - accuracy: 0.9372 - val_loss: 0.6405 - val_accuracy: 0.8100 - lr: 2.5000e-05
# Epoch 30/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2216 - accuracy: 0.9436 - val_loss: 0.6181 - val_accuracy: 0.8175 - lr: 2.5000e-05
# Epoch 1/80
# 57/57 [==============================] - 4s 24ms/step - loss: 0.8700 - accuracy: 0.5133 - val_loss: 0.7268 - val_accuracy: 0.6450 - lr: 5.0000e-05
# Epoch 2/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7991 - accuracy: 0.5442 - val_loss: 0.6936 - val_accuracy: 0.6425 - lr: 5.0000e-05
# Epoch 3/80
# 57/57 [==============================] - 1s 15ms/step - loss: 0.7437 - accuracy: 0.5708 - val_loss: 0.6702 - val_accuracy: 0.6950 - lr: 5.0000e-05
# Epoch 4/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7320 - accuracy: 0.5902 - val_loss: 0.6426 - val_accuracy: 0.7075 - lr: 5.0000e-05
# Epoch 5/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.7143 - accuracy: 0.6106 - val_loss: 0.6124 - val_accuracy: 0.7375 - lr: 5.0000e-05
# Epoch 6/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6930 - accuracy: 0.6311 - val_loss: 0.5803 - val_accuracy: 0.7400 - lr: 5.0000e-05
# Epoch 7/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6811 - accuracy: 0.6540 - val_loss: 0.5525 - val_accuracy: 0.7550 - lr: 5.0000e-05
# Epoch 8/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6601 - accuracy: 0.6767 - val_loss: 0.5205 - val_accuracy: 0.7725 - lr: 5.0000e-05
# Epoch 9/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6406 - accuracy: 0.6817 - val_loss: 0.4937 - val_accuracy: 0.7950 - lr: 5.0000e-05
# Epoch 10/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.6200 - accuracy: 0.7163 - val_loss: 0.4652 - val_accuracy: 0.7875 - lr: 5.0000e-05
# Epoch 11/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5952 - accuracy: 0.7259 - val_loss: 0.4268 - val_accuracy: 0.8300 - lr: 5.0000e-05
# Epoch 12/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5662 - accuracy: 0.7530 - val_loss: 0.3782 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 13/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.5286 - accuracy: 0.7810 - val_loss: 0.3306 - val_accuracy: 0.9225 - lr: 5.0000e-05
# Epoch 14/80
# 57/57 [==============================] - 1s 13ms/step - loss: 0.5015 - accuracy: 0.8059 - val_loss: 0.2978 - val_accuracy: 0.9300 - lr: 5.0000e-05
# Epoch 15/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.4455 - accuracy: 0.8366 - val_loss: 0.2835 - val_accuracy: 0.9225 - lr: 5.0000e-05
# Epoch 16/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.4175 - accuracy: 0.8490 - val_loss: 0.2849 - val_accuracy: 0.9100 - lr: 5.0000e-05
# Epoch 17/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3825 - accuracy: 0.8695 - val_loss: 0.2823 - val_accuracy: 0.9200 - lr: 5.0000e-05
# Epoch 18/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3562 - accuracy: 0.8836 - val_loss: 0.3072 - val_accuracy: 0.9025 - lr: 5.0000e-05
# Epoch 19/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.3218 - accuracy: 0.8985 - val_loss: 0.3466 - val_accuracy: 0.8925 - lr: 5.0000e-05
# Epoch 20/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2956 - accuracy: 0.9154 - val_loss: 0.3579 - val_accuracy: 0.8950 - lr: 5.0000e-05
# Epoch 21/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2722 - accuracy: 0.9209 - val_loss: 0.3571 - val_accuracy: 0.8975 - lr: 5.0000e-05
# Epoch 22/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2507 - accuracy: 0.9322 - val_loss: 0.3766 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 23/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2339 - accuracy: 0.9386 - val_loss: 0.4037 - val_accuracy: 0.8825 - lr: 5.0000e-05
# Epoch 24/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2117 - accuracy: 0.9488 - val_loss: 0.4310 - val_accuracy: 0.8825 - lr: 2.5000e-05
# Epoch 25/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.2008 - accuracy: 0.9538 - val_loss: 0.4429 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 26/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1872 - accuracy: 0.9599 - val_loss: 0.4706 - val_accuracy: 0.8775 - lr: 2.5000e-05
# Epoch 27/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1900 - accuracy: 0.9569 - val_loss: 0.4721 - val_accuracy: 0.8700 - lr: 2.5000e-05
# Epoch 28/80
# 57/57 [==============================] - 1s 14ms/step - loss: 0.1804 - accuracy: 0.9629 - val_loss: 0.4841 - val_accuracy: 0.8725 - lr: 2.5000e-05
# Epoch 29/80
# 57/57 [==============================] - 1s 13ms/step - loss: 0.1752 - accuracy: 0.9616 - val_loss: 0.5209 - val_accuracy: 0.8725 - lr: 2.5000e-05
# Epoch 1/80
# 59/59 [==============================] - 4s 24ms/step - loss: 0.8719 - accuracy: 0.5252 - val_loss: 0.7303 - val_accuracy: 0.5958 - lr: 5.0000e-05
# Epoch 2/80
# 59/59 [==============================] - 1s 13ms/step - loss: 0.7933 - accuracy: 0.5561 - val_loss: 0.7143 - val_accuracy: 0.6417 - lr: 5.0000e-05
# Epoch 3/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.7577 - accuracy: 0.5824 - val_loss: 0.7059 - val_accuracy: 0.5875 - lr: 5.0000e-05
# Epoch 4/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.7197 - accuracy: 0.6088 - val_loss: 0.6761 - val_accuracy: 0.6458 - lr: 5.0000e-05
# Epoch 5/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.7002 - accuracy: 0.6250 - val_loss: 0.6572 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 6/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.6786 - accuracy: 0.6457 - val_loss: 0.6563 - val_accuracy: 0.6708 - lr: 5.0000e-05
# Epoch 7/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.6626 - accuracy: 0.6637 - val_loss: 0.6576 - val_accuracy: 0.5958 - lr: 5.0000e-05
# Epoch 8/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.6444 - accuracy: 0.6727 - val_loss: 0.6632 - val_accuracy: 0.5583 - lr: 5.0000e-05
# Epoch 9/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.6257 - accuracy: 0.6928 - val_loss: 0.6644 - val_accuracy: 0.6583 - lr: 5.0000e-05
# Epoch 10/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.6024 - accuracy: 0.7230 - val_loss: 0.6621 - val_accuracy: 0.6792 - lr: 5.0000e-05
# Epoch 11/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.5718 - accuracy: 0.7413 - val_loss: 0.6705 - val_accuracy: 0.7292 - lr: 5.0000e-05
# Epoch 12/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.5476 - accuracy: 0.7717 - val_loss: 0.6805 - val_accuracy: 0.7750 - lr: 5.0000e-05
# Epoch 13/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.5254 - accuracy: 0.7858 - val_loss: 0.6747 - val_accuracy: 0.7750 - lr: 2.5000e-05
# Epoch 14/80
# 59/59 [==============================] - 1s 13ms/step - loss: 0.5109 - accuracy: 0.7926 - val_loss: 0.6840 - val_accuracy: 0.7750 - lr: 2.5000e-05
# Epoch 15/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.4949 - accuracy: 0.7916 - val_loss: 0.6780 - val_accuracy: 0.7792 - lr: 2.5000e-05
# Epoch 16/80
# 59/59 [==============================] - 1s 12ms/step - loss: 0.4818 - accuracy: 0.8099 - val_loss: 0.6826 - val_accuracy: 0.7833 - lr: 2.5000e-05
# Epoch 17/80
# 59/59 [==============================] - 1s 13ms/step - loss: 0.4618 - accuracy: 0.8242 - val_loss: 0.6898 - val_accuracy: 0.7792 - lr: 2.5000e-05
# Epoch 18/80
# 59/59 [==============================] - 1s 13ms/step - loss: 0.4445 - accuracy: 0.8347 - val_loss: 0.6921 - val_accuracy: 0.7542 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 28ms/step - loss: 0.8858 - accuracy: 0.5036 - val_loss: 0.6843 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.8155 - accuracy: 0.5379 - val_loss: 0.7145 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7593 - accuracy: 0.5760 - val_loss: 0.6976 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7357 - accuracy: 0.6048 - val_loss: 0.7376 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6970 - accuracy: 0.6419 - val_loss: 0.7138 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6740 - accuracy: 0.6776 - val_loss: 0.7538 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6347 - accuracy: 0.7098 - val_loss: 0.7714 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6196 - accuracy: 0.7261 - val_loss: 0.7809 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5912 - accuracy: 0.7451 - val_loss: 0.8005 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5881 - accuracy: 0.7451 - val_loss: 0.8800 - val_accuracy: 0.5688 - lr: 2.5000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5647 - accuracy: 0.7630 - val_loss: 0.8809 - val_accuracy: 0.5938 - lr: 2.5000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5402 - accuracy: 0.7832 - val_loss: 0.9267 - val_accuracy: 0.5813 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5189 - accuracy: 0.7930 - val_loss: 0.9627 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 24ms/step - loss: 0.8008 - accuracy: 0.5156 - val_loss: 0.7464 - val_accuracy: 0.5813 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7712 - accuracy: 0.5373 - val_loss: 0.7487 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7450 - accuracy: 0.5685 - val_loss: 0.7661 - val_accuracy: 0.5938 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7204 - accuracy: 0.5954 - val_loss: 0.8133 - val_accuracy: 0.5562 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6967 - accuracy: 0.6346 - val_loss: 0.8667 - val_accuracy: 0.5625 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6832 - accuracy: 0.6504 - val_loss: 0.8666 - val_accuracy: 0.5562 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6513 - accuracy: 0.6797 - val_loss: 0.9135 - val_accuracy: 0.5500 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 15ms/step - loss: 0.6298 - accuracy: 0.7059 - val_loss: 0.9405 - val_accuracy: 0.5500 - lr: 2.5000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6190 - accuracy: 0.7204 - val_loss: 0.8960 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5957 - accuracy: 0.7459 - val_loss: 0.9556 - val_accuracy: 0.5562 - lr: 2.5000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5687 - accuracy: 0.7666 - val_loss: 0.9484 - val_accuracy: 0.5312 - lr: 2.5000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5416 - accuracy: 0.7814 - val_loss: 1.0146 - val_accuracy: 0.5188 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5228 - accuracy: 0.8013 - val_loss: 1.0003 - val_accuracy: 0.5188 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 23ms/step - loss: 0.8422 - accuracy: 0.5249 - val_loss: 0.7280 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7650 - accuracy: 0.5399 - val_loss: 0.6876 - val_accuracy: 0.8250 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7279 - accuracy: 0.6004 - val_loss: 0.6532 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7110 - accuracy: 0.6255 - val_loss: 0.6020 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6962 - accuracy: 0.6317 - val_loss: 0.5582 - val_accuracy: 0.8938 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6705 - accuracy: 0.6696 - val_loss: 0.5259 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6464 - accuracy: 0.6901 - val_loss: 0.4843 - val_accuracy: 0.8938 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6281 - accuracy: 0.7082 - val_loss: 0.4550 - val_accuracy: 0.8938 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6097 - accuracy: 0.7303 - val_loss: 0.4264 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5796 - accuracy: 0.7588 - val_loss: 0.4288 - val_accuracy: 0.8625 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5606 - accuracy: 0.7770 - val_loss: 0.4078 - val_accuracy: 0.8625 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5255 - accuracy: 0.7988 - val_loss: 0.4082 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4862 - accuracy: 0.8164 - val_loss: 0.4397 - val_accuracy: 0.8062 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4619 - accuracy: 0.8371 - val_loss: 0.4089 - val_accuracy: 0.8313 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4285 - accuracy: 0.8579 - val_loss: 0.4981 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3980 - accuracy: 0.8677 - val_loss: 0.5312 - val_accuracy: 0.7875 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3723 - accuracy: 0.8830 - val_loss: 0.4840 - val_accuracy: 0.8125 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3579 - accuracy: 0.8880 - val_loss: 0.6311 - val_accuracy: 0.7812 - lr: 2.5000e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3404 - accuracy: 0.9002 - val_loss: 0.6238 - val_accuracy: 0.7875 - lr: 2.5000e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3212 - accuracy: 0.9051 - val_loss: 0.6061 - val_accuracy: 0.7875 - lr: 2.5000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3134 - accuracy: 0.9118 - val_loss: 0.6771 - val_accuracy: 0.7750 - lr: 2.5000e-05
# Epoch 22/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3029 - accuracy: 0.9136 - val_loss: 0.7507 - val_accuracy: 0.7625 - lr: 2.5000e-05
# Epoch 23/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2831 - accuracy: 0.9243 - val_loss: 0.7268 - val_accuracy: 0.7812 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 23ms/step - loss: 0.9202 - accuracy: 0.5195 - val_loss: 0.7278 - val_accuracy: 0.6375 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7877 - accuracy: 0.5534 - val_loss: 0.7375 - val_accuracy: 0.5312 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7404 - accuracy: 0.5890 - val_loss: 0.7819 - val_accuracy: 0.4625 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7002 - accuracy: 0.6315 - val_loss: 0.8216 - val_accuracy: 0.4625 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6893 - accuracy: 0.6538 - val_loss: 0.8257 - val_accuracy: 0.4812 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6643 - accuracy: 0.6732 - val_loss: 0.8591 - val_accuracy: 0.4875 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6355 - accuracy: 0.7067 - val_loss: 0.8871 - val_accuracy: 0.5188 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6264 - accuracy: 0.7121 - val_loss: 0.8360 - val_accuracy: 0.4812 - lr: 2.5000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6125 - accuracy: 0.7197 - val_loss: 0.9408 - val_accuracy: 0.5000 - lr: 2.5000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5971 - accuracy: 0.7321 - val_loss: 0.8540 - val_accuracy: 0.5125 - lr: 2.5000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5801 - accuracy: 0.7433 - val_loss: 0.9159 - val_accuracy: 0.5312 - lr: 2.5000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5704 - accuracy: 0.7500 - val_loss: 0.8957 - val_accuracy: 0.5625 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5597 - accuracy: 0.7637 - val_loss: 0.9467 - val_accuracy: 0.5750 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 22ms/step - loss: 0.8334 - accuracy: 0.5171 - val_loss: 0.7155 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7596 - accuracy: 0.5493 - val_loss: 0.7159 - val_accuracy: 0.6750 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7339 - accuracy: 0.5890 - val_loss: 0.7133 - val_accuracy: 0.6375 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7135 - accuracy: 0.6058 - val_loss: 0.7101 - val_accuracy: 0.5750 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6861 - accuracy: 0.6515 - val_loss: 0.6937 - val_accuracy: 0.5813 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6620 - accuracy: 0.6680 - val_loss: 0.6442 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6370 - accuracy: 0.6961 - val_loss: 0.6021 - val_accuracy: 0.6750 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6075 - accuracy: 0.7300 - val_loss: 0.5522 - val_accuracy: 0.7250 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5852 - accuracy: 0.7388 - val_loss: 0.5216 - val_accuracy: 0.8188 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5525 - accuracy: 0.7604 - val_loss: 0.4548 - val_accuracy: 0.8562 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5199 - accuracy: 0.7863 - val_loss: 0.4480 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4943 - accuracy: 0.8052 - val_loss: 0.4204 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4470 - accuracy: 0.8345 - val_loss: 0.3848 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4148 - accuracy: 0.8530 - val_loss: 0.3704 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3835 - accuracy: 0.8729 - val_loss: 0.3710 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3558 - accuracy: 0.8807 - val_loss: 0.3740 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3258 - accuracy: 0.9009 - val_loss: 0.3658 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.3109 - accuracy: 0.9087 - val_loss: 0.3774 - val_accuracy: 0.8562 - lr: 5.0000e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2773 - accuracy: 0.9188 - val_loss: 0.4090 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2718 - accuracy: 0.9240 - val_loss: 0.4059 - val_accuracy: 0.8687 - lr: 5.0000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2450 - accuracy: 0.9326 - val_loss: 0.3943 - val_accuracy: 0.8562 - lr: 5.0000e-05
# Epoch 22/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2452 - accuracy: 0.9323 - val_loss: 0.3841 - val_accuracy: 0.8562 - lr: 5.0000e-05
# Epoch 23/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2156 - accuracy: 0.9476 - val_loss: 0.4189 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 24/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2103 - accuracy: 0.9476 - val_loss: 0.4223 - val_accuracy: 0.8500 - lr: 2.5000e-05
# Epoch 25/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1911 - accuracy: 0.9557 - val_loss: 0.4159 - val_accuracy: 0.8687 - lr: 2.5000e-05
# Epoch 26/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1849 - accuracy: 0.9598 - val_loss: 0.4704 - val_accuracy: 0.8313 - lr: 2.5000e-05
# Epoch 27/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.1834 - accuracy: 0.9603 - val_loss: 0.4502 - val_accuracy: 0.8500 - lr: 2.5000e-05
# Epoch 28/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1740 - accuracy: 0.9619 - val_loss: 0.4744 - val_accuracy: 0.8500 - lr: 2.5000e-05
# Epoch 29/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.1666 - accuracy: 0.9658 - val_loss: 0.4648 - val_accuracy: 0.8500 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 24ms/step - loss: 0.8683 - accuracy: 0.5140 - val_loss: 0.7231 - val_accuracy: 0.5063 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.8037 - accuracy: 0.5366 - val_loss: 0.6832 - val_accuracy: 0.6500 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7553 - accuracy: 0.5695 - val_loss: 0.6386 - val_accuracy: 0.7625 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7368 - accuracy: 0.5832 - val_loss: 0.6022 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7180 - accuracy: 0.6048 - val_loss: 0.5779 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6942 - accuracy: 0.6271 - val_loss: 0.5760 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6879 - accuracy: 0.6398 - val_loss: 0.5557 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6752 - accuracy: 0.6522 - val_loss: 0.5461 - val_accuracy: 0.8188 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6516 - accuracy: 0.6758 - val_loss: 0.5329 - val_accuracy: 0.8375 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6314 - accuracy: 0.6950 - val_loss: 0.5257 - val_accuracy: 0.8562 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6098 - accuracy: 0.7124 - val_loss: 0.5217 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.5699 - accuracy: 0.7523 - val_loss: 0.5142 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.5308 - accuracy: 0.7798 - val_loss: 0.5184 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.4862 - accuracy: 0.8109 - val_loss: 0.5254 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.4540 - accuracy: 0.8307 - val_loss: 0.5360 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4246 - accuracy: 0.8493 - val_loss: 0.5467 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3880 - accuracy: 0.8685 - val_loss: 0.5581 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3668 - accuracy: 0.8763 - val_loss: 0.5741 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.3494 - accuracy: 0.8926 - val_loss: 0.5801 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.3393 - accuracy: 0.8957 - val_loss: 0.5788 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3225 - accuracy: 0.9027 - val_loss: 0.5817 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 22/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.3173 - accuracy: 0.9048 - val_loss: 0.5927 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 23/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.3002 - accuracy: 0.9173 - val_loss: 0.5968 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 24/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.2924 - accuracy: 0.9142 - val_loss: 0.6065 - val_accuracy: 0.9000 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 25ms/step - loss: 0.8300 - accuracy: 0.5283 - val_loss: 0.6883 - val_accuracy: 0.6625 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7792 - accuracy: 0.5490 - val_loss: 0.6373 - val_accuracy: 0.8250 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7564 - accuracy: 0.5679 - val_loss: 0.6141 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7383 - accuracy: 0.5864 - val_loss: 0.5631 - val_accuracy: 0.8375 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7107 - accuracy: 0.6245 - val_loss: 0.5209 - val_accuracy: 0.8375 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7040 - accuracy: 0.6255 - val_loss: 0.4932 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6827 - accuracy: 0.6603 - val_loss: 0.4692 - val_accuracy: 0.8687 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6708 - accuracy: 0.6639 - val_loss: 0.4560 - val_accuracy: 0.8938 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6548 - accuracy: 0.6813 - val_loss: 0.4384 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6253 - accuracy: 0.7082 - val_loss: 0.3955 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6200 - accuracy: 0.7103 - val_loss: 0.3823 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5818 - accuracy: 0.7505 - val_loss: 0.3469 - val_accuracy: 0.9000 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5599 - accuracy: 0.7728 - val_loss: 0.3316 - val_accuracy: 0.8938 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5374 - accuracy: 0.7814 - val_loss: 0.2922 - val_accuracy: 0.9750 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4931 - accuracy: 0.8177 - val_loss: 0.2871 - val_accuracy: 0.9500 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4669 - accuracy: 0.8229 - val_loss: 0.2695 - val_accuracy: 0.9563 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4423 - accuracy: 0.8421 - val_loss: 0.2600 - val_accuracy: 0.9438 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4247 - accuracy: 0.8545 - val_loss: 0.2607 - val_accuracy: 0.9438 - lr: 5.0000e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3891 - accuracy: 0.8727 - val_loss: 0.2835 - val_accuracy: 0.9250 - lr: 5.0000e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3740 - accuracy: 0.8776 - val_loss: 0.3078 - val_accuracy: 0.8938 - lr: 5.0000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3372 - accuracy: 0.8957 - val_loss: 0.3044 - val_accuracy: 0.8938 - lr: 5.0000e-05
# Epoch 22/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3111 - accuracy: 0.9043 - val_loss: 0.3685 - val_accuracy: 0.8625 - lr: 5.0000e-05
# Epoch 23/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2863 - accuracy: 0.9147 - val_loss: 0.3650 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 24/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2670 - accuracy: 0.9289 - val_loss: 0.4269 - val_accuracy: 0.8313 - lr: 2.5000e-05
# Epoch 25/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2595 - accuracy: 0.9292 - val_loss: 0.3985 - val_accuracy: 0.8500 - lr: 2.5000e-05
# Epoch 26/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2543 - accuracy: 0.9318 - val_loss: 0.4415 - val_accuracy: 0.8562 - lr: 2.5000e-05
# Epoch 27/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2434 - accuracy: 0.9391 - val_loss: 0.4544 - val_accuracy: 0.8250 - lr: 2.5000e-05
# Epoch 28/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2308 - accuracy: 0.9401 - val_loss: 0.4294 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 29/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2301 - accuracy: 0.9440 - val_loss: 0.4985 - val_accuracy: 0.8500 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 24ms/step - loss: 0.8840 - accuracy: 0.5150 - val_loss: 0.7440 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7975 - accuracy: 0.5477 - val_loss: 0.6832 - val_accuracy: 0.6062 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7431 - accuracy: 0.5879 - val_loss: 0.6520 - val_accuracy: 0.6750 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7186 - accuracy: 0.6061 - val_loss: 0.6132 - val_accuracy: 0.7688 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6883 - accuracy: 0.6486 - val_loss: 0.5880 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6633 - accuracy: 0.6763 - val_loss: 0.5709 - val_accuracy: 0.7688 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6425 - accuracy: 0.7062 - val_loss: 0.5102 - val_accuracy: 0.8188 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6241 - accuracy: 0.7088 - val_loss: 0.4853 - val_accuracy: 0.8625 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5965 - accuracy: 0.7305 - val_loss: 0.4522 - val_accuracy: 0.8687 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5773 - accuracy: 0.7516 - val_loss: 0.3881 - val_accuracy: 0.8875 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5565 - accuracy: 0.7619 - val_loss: 0.4158 - val_accuracy: 0.8438 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5300 - accuracy: 0.7853 - val_loss: 0.3924 - val_accuracy: 0.8000 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5031 - accuracy: 0.7972 - val_loss: 0.3958 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4847 - accuracy: 0.8081 - val_loss: 0.3367 - val_accuracy: 0.8313 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4606 - accuracy: 0.8275 - val_loss: 0.3628 - val_accuracy: 0.8625 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4270 - accuracy: 0.8452 - val_loss: 0.3928 - val_accuracy: 0.8625 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3944 - accuracy: 0.8550 - val_loss: 0.4260 - val_accuracy: 0.8250 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3793 - accuracy: 0.8703 - val_loss: 0.3466 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3551 - accuracy: 0.8773 - val_loss: 0.4092 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3391 - accuracy: 0.8887 - val_loss: 0.3945 - val_accuracy: 0.8813 - lr: 5.0000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3192 - accuracy: 0.8968 - val_loss: 0.4262 - val_accuracy: 0.8750 - lr: 2.5000e-05
# Epoch 22/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3102 - accuracy: 0.8996 - val_loss: 0.3993 - val_accuracy: 0.8813 - lr: 2.5000e-05
# Epoch 23/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2943 - accuracy: 0.9048 - val_loss: 0.3910 - val_accuracy: 0.8875 - lr: 2.5000e-05
# Epoch 24/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2876 - accuracy: 0.9131 - val_loss: 0.4045 - val_accuracy: 0.8875 - lr: 2.5000e-05
# Epoch 25/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2812 - accuracy: 0.9212 - val_loss: 0.3904 - val_accuracy: 0.8938 - lr: 2.5000e-05
# Epoch 26/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2723 - accuracy: 0.9199 - val_loss: 0.3733 - val_accuracy: 0.8938 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 22ms/step - loss: 0.8866 - accuracy: 0.5103 - val_loss: 0.7296 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.8155 - accuracy: 0.5382 - val_loss: 0.6864 - val_accuracy: 0.6944 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7605 - accuracy: 0.5814 - val_loss: 0.6698 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7279 - accuracy: 0.6095 - val_loss: 0.6646 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6987 - accuracy: 0.6444 - val_loss: 0.6706 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6713 - accuracy: 0.6627 - val_loss: 0.6857 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6478 - accuracy: 0.6940 - val_loss: 0.7007 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.6223 - accuracy: 0.7283 - val_loss: 0.7014 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5777 - accuracy: 0.7546 - val_loss: 0.7652 - val_accuracy: 0.6389 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5396 - accuracy: 0.7769 - val_loss: 0.7119 - val_accuracy: 0.6667 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5143 - accuracy: 0.7986 - val_loss: 0.7086 - val_accuracy: 0.6736 - lr: 2.5000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4873 - accuracy: 0.8174 - val_loss: 0.6897 - val_accuracy: 0.6944 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4715 - accuracy: 0.8280 - val_loss: 0.6926 - val_accuracy: 0.7014 - lr: 2.5000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4575 - accuracy: 0.8383 - val_loss: 0.7038 - val_accuracy: 0.7014 - lr: 2.5000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4442 - accuracy: 0.8401 - val_loss: 0.6924 - val_accuracy: 0.7153 - lr: 2.5000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4213 - accuracy: 0.8543 - val_loss: 0.7010 - val_accuracy: 0.7153 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 22ms/step - loss: 0.9061 - accuracy: 0.4954 - val_loss: 0.7658 - val_accuracy: 0.4844 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.8091 - accuracy: 0.5370 - val_loss: 0.6781 - val_accuracy: 0.5859 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7698 - accuracy: 0.5761 - val_loss: 0.6488 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7316 - accuracy: 0.5990 - val_loss: 0.6140 - val_accuracy: 0.6641 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7020 - accuracy: 0.6294 - val_loss: 0.5945 - val_accuracy: 0.6953 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.6719 - accuracy: 0.6623 - val_loss: 0.5653 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6581 - accuracy: 0.6762 - val_loss: 0.5559 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6391 - accuracy: 0.6926 - val_loss: 0.5594 - val_accuracy: 0.6797 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6180 - accuracy: 0.7099 - val_loss: 0.5382 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6033 - accuracy: 0.7155 - val_loss: 0.5339 - val_accuracy: 0.6406 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5739 - accuracy: 0.7477 - val_loss: 0.5105 - val_accuracy: 0.6953 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5594 - accuracy: 0.7611 - val_loss: 0.4940 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5410 - accuracy: 0.7639 - val_loss: 0.5042 - val_accuracy: 0.7500 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5104 - accuracy: 0.7942 - val_loss: 0.4937 - val_accuracy: 0.7422 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4744 - accuracy: 0.8151 - val_loss: 0.5150 - val_accuracy: 0.7578 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4548 - accuracy: 0.8274 - val_loss: 0.5232 - val_accuracy: 0.7578 - lr: 5.0000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4300 - accuracy: 0.8418 - val_loss: 0.5442 - val_accuracy: 0.7578 - lr: 5.0000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3904 - accuracy: 0.8634 - val_loss: 0.5402 - val_accuracy: 0.7656 - lr: 5.0000e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3654 - accuracy: 0.8794 - val_loss: 0.5425 - val_accuracy: 0.7656 - lr: 5.0000e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3448 - accuracy: 0.8894 - val_loss: 0.5458 - val_accuracy: 0.7734 - lr: 5.0000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3183 - accuracy: 0.8974 - val_loss: 0.5497 - val_accuracy: 0.7734 - lr: 2.5000e-05
# Epoch 22/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3090 - accuracy: 0.9066 - val_loss: 0.5434 - val_accuracy: 0.7734 - lr: 2.5000e-05
# Epoch 23/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2935 - accuracy: 0.9105 - val_loss: 0.5407 - val_accuracy: 0.7812 - lr: 2.5000e-05
# Epoch 24/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2805 - accuracy: 0.9167 - val_loss: 0.5362 - val_accuracy: 0.7969 - lr: 2.5000e-05
# Epoch 25/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2736 - accuracy: 0.9213 - val_loss: 0.5310 - val_accuracy: 0.8047 - lr: 2.5000e-05
# Epoch 26/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2594 - accuracy: 0.9249 - val_loss: 0.5025 - val_accuracy: 0.8047 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 24ms/step - loss: 0.8564 - accuracy: 0.5150 - val_loss: 0.7153 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7772 - accuracy: 0.5483 - val_loss: 0.7215 - val_accuracy: 0.6111 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7250 - accuracy: 0.6015 - val_loss: 0.7031 - val_accuracy: 0.6181 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6967 - accuracy: 0.6364 - val_loss: 0.6929 - val_accuracy: 0.5903 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6674 - accuracy: 0.6617 - val_loss: 0.6636 - val_accuracy: 0.6736 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6430 - accuracy: 0.6885 - val_loss: 0.6453 - val_accuracy: 0.6736 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6223 - accuracy: 0.7084 - val_loss: 0.6165 - val_accuracy: 0.6944 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5897 - accuracy: 0.7355 - val_loss: 0.5662 - val_accuracy: 0.7708 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5642 - accuracy: 0.7500 - val_loss: 0.4919 - val_accuracy: 0.8056 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5319 - accuracy: 0.7784 - val_loss: 0.4738 - val_accuracy: 0.8056 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4986 - accuracy: 0.8022 - val_loss: 0.4291 - val_accuracy: 0.8333 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4696 - accuracy: 0.8187 - val_loss: 0.3697 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4445 - accuracy: 0.8355 - val_loss: 0.3449 - val_accuracy: 0.8750 - lr: 5.0000e-05
# Epoch 14/80
# ...
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3688 - accuracy: 0.8766 - val_loss: 0.5697 - val_accuracy: 0.8250 - lr: 2.5000e-05
# Epoch 28/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3523 - accuracy: 0.8841 - val_loss: 0.5908 - val_accuracy: 0.8062 - lr: 2.5000e-05
# Epoch 29/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3438 - accuracy: 0.8843 - val_loss: 0.5925 - val_accuracy: 0.8062 - lr: 1.2500e-05
# Epoch 30/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3356 - accuracy: 0.8893 - val_loss: 0.5879 - val_accuracy: 0.8125 - lr: 1.2500e-05
# Epoch 31/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3319 - accuracy: 0.8911 - val_loss: 0.6008 - val_accuracy: 0.8062 - lr: 1.2500e-05
# Epoch 32/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3157 - accuracy: 0.9038 - val_loss: 0.5971 - val_accuracy: 0.8000 - lr: 1.2500e-05
# Epoch 33/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3273 - accuracy: 0.8950 - val_loss: 0.6087 - val_accuracy: 0.8062 - lr: 1.2500e-05
# Epoch 34/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3227 - accuracy: 0.8965 - val_loss: 0.6232 - val_accuracy: 0.8062 - lr: 1.2500e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 24ms/step - loss: 0.8665 - accuracy: 0.5176 - val_loss: 0.7389 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.8139 - accuracy: 0.5459 - val_loss: 0.7204 - val_accuracy: 0.6562 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7723 - accuracy: 0.5638 - val_loss: 0.7115 - val_accuracy: 0.6375 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7486 - accuracy: 0.5827 - val_loss: 0.7146 - val_accuracy: 0.6750 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7277 - accuracy: 0.6068 - val_loss: 0.7100 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6980 - accuracy: 0.6447 - val_loss: 0.7168 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6701 - accuracy: 0.6662 - val_loss: 0.7260 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6541 - accuracy: 0.6909 - val_loss: 0.7211 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6380 - accuracy: 0.7005 - val_loss: 0.7248 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 15ms/step - loss: 0.6086 - accuracy: 0.7295 - val_loss: 0.7469 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5986 - accuracy: 0.7391 - val_loss: 0.7394 - val_accuracy: 0.6125 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5749 - accuracy: 0.7578 - val_loss: 0.7600 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5695 - accuracy: 0.7653 - val_loss: 0.7554 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5540 - accuracy: 0.7697 - val_loss: 0.7737 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5295 - accuracy: 0.7884 - val_loss: 0.8150 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5133 - accuracy: 0.8021 - val_loss: 0.8235 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5001 - accuracy: 0.8086 - val_loss: 0.8308 - val_accuracy: 0.6000 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 24ms/step - loss: 0.9178 - accuracy: 0.5026 - val_loss: 0.7303 - val_accuracy: 0.5750 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.8030 - accuracy: 0.5552 - val_loss: 0.6564 - val_accuracy: 0.6812 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7610 - accuracy: 0.5921 - val_loss: 0.6264 - val_accuracy: 0.7750 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7252 - accuracy: 0.6247 - val_loss: 0.6175 - val_accuracy: 0.8062 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7013 - accuracy: 0.6468 - val_loss: 0.6040 - val_accuracy: 0.8313 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6699 - accuracy: 0.6647 - val_loss: 0.6076 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6499 - accuracy: 0.6831 - val_loss: 0.6244 - val_accuracy: 0.6313 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6292 - accuracy: 0.7116 - val_loss: 0.6124 - val_accuracy: 0.6875 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6033 - accuracy: 0.7282 - val_loss: 0.6103 - val_accuracy: 0.6938 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5685 - accuracy: 0.7567 - val_loss: 0.6165 - val_accuracy: 0.7063 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5346 - accuracy: 0.7829 - val_loss: 0.6039 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5056 - accuracy: 0.8021 - val_loss: 0.6213 - val_accuracy: 0.7312 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4906 - accuracy: 0.8130 - val_loss: 0.6289 - val_accuracy: 0.7250 - lr: 2.5000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4770 - accuracy: 0.8234 - val_loss: 0.6208 - val_accuracy: 0.7188 - lr: 2.5000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4601 - accuracy: 0.8312 - val_loss: 0.6233 - val_accuracy: 0.7250 - lr: 2.5000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4443 - accuracy: 0.8338 - val_loss: 0.6347 - val_accuracy: 0.7250 - lr: 2.5000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4366 - accuracy: 0.8434 - val_loss: 0.6331 - val_accuracy: 0.7250 - lr: 2.5000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4255 - accuracy: 0.8568 - val_loss: 0.6469 - val_accuracy: 0.7125 - lr: 1.2500e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4153 - accuracy: 0.8626 - val_loss: 0.6522 - val_accuracy: 0.7125 - lr: 1.2500e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4169 - accuracy: 0.8613 - val_loss: 0.6599 - val_accuracy: 0.7125 - lr: 1.2500e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4086 - accuracy: 0.8597 - val_loss: 0.6628 - val_accuracy: 0.7125 - lr: 1.2500e-05
# Epoch 22/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3951 - accuracy: 0.8727 - val_loss: 0.6611 - val_accuracy: 0.7125 - lr: 1.2500e-05
# Epoch 23/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.3989 - accuracy: 0.8696 - val_loss: 0.6725 - val_accuracy: 0.7125 - lr: 1.2500e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 24ms/step - loss: 0.9161 - accuracy: 0.5083 - val_loss: 0.7462 - val_accuracy: 0.5188 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.8341 - accuracy: 0.5397 - val_loss: 0.6738 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7930 - accuracy: 0.5628 - val_loss: 0.6486 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7326 - accuracy: 0.6110 - val_loss: 0.6325 - val_accuracy: 0.7437 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7186 - accuracy: 0.6286 - val_loss: 0.6094 - val_accuracy: 0.7125 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6939 - accuracy: 0.6494 - val_loss: 0.5953 - val_accuracy: 0.7125 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6682 - accuracy: 0.6706 - val_loss: 0.5792 - val_accuracy: 0.7063 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6455 - accuracy: 0.6961 - val_loss: 0.5535 - val_accuracy: 0.7937 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6175 - accuracy: 0.7264 - val_loss: 0.5424 - val_accuracy: 0.7812 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5777 - accuracy: 0.7539 - val_loss: 0.5494 - val_accuracy: 0.7937 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.5338 - accuracy: 0.7863 - val_loss: 0.5505 - val_accuracy: 0.7750 - lr: 5.0000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4984 - accuracy: 0.8047 - val_loss: 0.6418 - val_accuracy: 0.7688 - lr: 5.0000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4721 - accuracy: 0.8288 - val_loss: 0.6683 - val_accuracy: 0.7188 - lr: 5.0000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4430 - accuracy: 0.8439 - val_loss: 0.6655 - val_accuracy: 0.7563 - lr: 5.0000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4064 - accuracy: 0.8636 - val_loss: 0.7700 - val_accuracy: 0.6938 - lr: 5.0000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3800 - accuracy: 0.8732 - val_loss: 0.7743 - val_accuracy: 0.7063 - lr: 2.5000e-05
# Epoch 17/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3646 - accuracy: 0.8872 - val_loss: 0.8095 - val_accuracy: 0.6938 - lr: 2.5000e-05
# Epoch 18/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3541 - accuracy: 0.8864 - val_loss: 0.8689 - val_accuracy: 0.6875 - lr: 2.5000e-05
# Epoch 19/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3401 - accuracy: 0.8955 - val_loss: 0.9178 - val_accuracy: 0.6812 - lr: 2.5000e-05
# Epoch 20/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3306 - accuracy: 0.9020 - val_loss: 0.9237 - val_accuracy: 0.6750 - lr: 2.5000e-05
# Epoch 21/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.3210 - accuracy: 0.9015 - val_loss: 0.9946 - val_accuracy: 0.6812 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 25ms/step - loss: 1.0524 - accuracy: 0.5101 - val_loss: 0.7782 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.8357 - accuracy: 0.5661 - val_loss: 0.7243 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7650 - accuracy: 0.5970 - val_loss: 0.6894 - val_accuracy: 0.6000 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7321 - accuracy: 0.6159 - val_loss: 0.6486 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.6978 - accuracy: 0.6572 - val_loss: 0.6694 - val_accuracy: 0.6250 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.6627 - accuracy: 0.6719 - val_loss: 0.6757 - val_accuracy: 0.6687 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.6347 - accuracy: 0.7116 - val_loss: 0.6537 - val_accuracy: 0.6938 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.6174 - accuracy: 0.7285 - val_loss: 0.6797 - val_accuracy: 0.7000 - lr: 5.0000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.5920 - accuracy: 0.7453 - val_loss: 0.7046 - val_accuracy: 0.7000 - lr: 5.0000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 12ms/step - loss: 0.5583 - accuracy: 0.7689 - val_loss: 0.7522 - val_accuracy: 0.7000 - lr: 5.0000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5330 - accuracy: 0.7840 - val_loss: 0.7578 - val_accuracy: 0.7000 - lr: 2.5000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5288 - accuracy: 0.7936 - val_loss: 0.7783 - val_accuracy: 0.6938 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5103 - accuracy: 0.8047 - val_loss: 0.7829 - val_accuracy: 0.6812 - lr: 2.5000e-05
# Epoch 14/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4982 - accuracy: 0.8089 - val_loss: 0.7945 - val_accuracy: 0.6250 - lr: 2.5000e-05
# Epoch 15/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.4872 - accuracy: 0.8174 - val_loss: 0.7795 - val_accuracy: 0.5813 - lr: 2.5000e-05
# Epoch 16/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.4630 - accuracy: 0.8278 - val_loss: 0.8557 - val_accuracy: 0.6125 - lr: 2.5000e-05
# Epoch 1/80
# 61/61 [==============================] - 4s 22ms/step - loss: 0.8752 - accuracy: 0.5285 - val_loss: 0.7935 - val_accuracy: 0.4125 - lr: 5.0000e-05
# Epoch 2/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.7869 - accuracy: 0.5711 - val_loss: 0.8684 - val_accuracy: 0.3375 - lr: 5.0000e-05
# Epoch 3/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7590 - accuracy: 0.5998 - val_loss: 0.8998 - val_accuracy: 0.3688 - lr: 5.0000e-05
# Epoch 4/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.7251 - accuracy: 0.6273 - val_loss: 0.9279 - val_accuracy: 0.3938 - lr: 5.0000e-05
# Epoch 5/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6892 - accuracy: 0.6551 - val_loss: 0.9305 - val_accuracy: 0.4125 - lr: 5.0000e-05
# Epoch 6/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6658 - accuracy: 0.6828 - val_loss: 0.9583 - val_accuracy: 0.4375 - lr: 5.0000e-05
# Epoch 7/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6446 - accuracy: 0.7025 - val_loss: 0.9460 - val_accuracy: 0.4688 - lr: 5.0000e-05
# Epoch 8/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.6284 - accuracy: 0.7147 - val_loss: 0.9354 - val_accuracy: 0.4875 - lr: 2.5000e-05
# Epoch 9/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6161 - accuracy: 0.7280 - val_loss: 0.9193 - val_accuracy: 0.4938 - lr: 2.5000e-05
# Epoch 10/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.6082 - accuracy: 0.7355 - val_loss: 0.9231 - val_accuracy: 0.5000 - lr: 2.5000e-05
# Epoch 11/80
# 61/61 [==============================] - 1s 13ms/step - loss: 0.5849 - accuracy: 0.7443 - val_loss: 0.8993 - val_accuracy: 0.5000 - lr: 2.5000e-05
# Epoch 12/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5670 - accuracy: 0.7663 - val_loss: 0.8821 - val_accuracy: 0.5375 - lr: 2.5000e-05
# Epoch 13/80
# 61/61 [==============================] - 1s 14ms/step - loss: 0.5502 - accuracy: 0.7695 - val_loss: 0.8795 - val_accuracy: 0.5312 - lr: 2.5000e-05
#
# ==== LOSO Summary (Up/Down) ====
# Mean Window Acc: 0.738 ± 0.135
# Mean Clip   Acc: 0.739 ± 0.153
#
# ==== OVERALL (클립) ====
# Overall 클립 Acc: 0.753
#               precision    recall  f1-score   support
#
#            위      0.754     0.748     0.751       250
#           아래      0.752     0.758     0.755       252
#
#     accuracy                          0.753       502
#    macro avg      0.753     0.753     0.753       502
# weighted avg      0.753     0.753     0.753       502

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

def build_crnn_with_delta(input_shape, n_classes=2,
                          k=5,        # Conv1D 커널(시간)
                          l2=1e-4,
                          ch1=64, ch2=128,
                          gru1=128, gru2=64,
                          p_drop_conv=0.30,
                          p_drop_dense=0.50,
                          lr=3e-4):
    """
    입력: (L, F)  -> 내부에서 Δ(1차) 생성 후 concat([x, Δ], axis=-1)
    블록: [Conv(64)->BN->ReLU->Drop] -> [Conv(128)->BN->ReLU->Drop]
          -> GRU(128, rs=True) -> GRU(64)
          -> Dense(64)->BN->ReLU->Drop -> Softmax
    """
    inp = layers.Input(shape=input_shape)      # (L, F)

    # --- Δ(1차) 생성 (레이어 안) ---
    def make_delta(x):
        x_prev = tf.pad(x[:, :-1, :], [[0,0],[1,0],[0,0]])
        dx = x - x_prev
        dx = tf.concat([tf.zeros_like(dx[:, :1, :]), dx[:, 1:, :]], axis=1)
        return tf.concat([x, dx], axis=-1)     # (L, 2F)
    x = layers.Lambda(make_delta, name="cat_x_delta")(inp)

    # --- Conv 블록 1 ---
    x = layers.Conv1D(ch1, k, padding='same',
                      kernel_regularizer=regularizers.l2(l2),
                      use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(p_drop_conv)(x)

    # --- Conv 블록 2 ---
    x = layers.Conv1D(ch2, k, padding='same',
                      kernel_regularizer=regularizers.l2(l2),
                      use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(p_drop_conv)(x)

    # --- GRU 블록 ---
    x = layers.GRU(gru1, return_sequences=True,
                   dropout=0.30, recurrent_dropout=0.0,
                   kernel_regularizer=regularizers.l2(l2),
                   recurrent_regularizer=regularizers.l2(l2))(x)
    x = layers.GRU(gru2,
                   dropout=0.30, recurrent_dropout=0.0,
                   kernel_regularizer=regularizers.l2(l2),
                   recurrent_regularizer=regularizers.l2(l2))(x)

    # --- Dense 헤드 ---
    x = layers.Dense(64, use_bias=False,
                     kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(p_drop_dense)(x)

    out = layers.Dense(n_classes, activation='softmax')(x)
    model = tf.keras.Model(inp, out)

    opt = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=1.0)
    model.compile(optimizer=opt,
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                  metrics=['accuracy'])
    return model

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager
import os

# ===== 옵션 =====
EPOCHS = 80
BATCH_SIZE = 64
ES_PATIENCE = 12
RLR_PATIENCE = 6

PLOT_LAST_FOLD_CURVES = True  # 폴드 개별 곡선(마지막 폴드만)
EVAL_LEVEL = "clip"          # "clip" 또는 "window"

# ===== 한글 폰트 =====
def setup_korean_font():
    candidates = ["Malgun Gothic", "AppleGothic", "NanumGothic", "Noto Sans CJK KR", "Noto Sans KR"]
    installed = {f.name for f in font_manager.fontManager.ttflist}
    for name in candidates:
        if name in installed:
            plt.rcParams["font.family"] = name
            break
    plt.rcParams["axes.unicode_minus"] = False
setup_korean_font()

# ===== 데이터 증강 기법: Time Stretching 함수 =====
def time_stretch(data, factor=1.2):
    L, C = data.shape
    # 원본 → 늘어난 축의 인덱스
    src_x = np.arange(L)
    dst_L = max(1, int(round(L * factor)))
    dst_x = np.linspace(0, L-1, dst_L)
    stretched = np.stack([np.interp(dst_x, src_x, data[:, c]) for c in range(C)], axis=1)
    # 다시 정확히 L로 리샘플
    back_x = np.linspace(0, dst_L-1, L)
    src_x2 = np.arange(dst_L)
    data_L = np.stack([np.interp(back_x, src_x2, stretched[:, c]) for c in range(C)], axis=1)
    return data_L.astype(np.float32)


# ===== 시각화 헬퍼 =====
def plot_training_curves(history, fold_no):
    H = history.history
    plt.figure()
    plt.plot(H.get('loss', []),     label='loss')
    plt.plot(H.get('val_loss', []), label='val_loss')
    plt.title(f'Fold {fold_no} - Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss')
    plt.legend(); plt.tight_layout(); plt.show()

    if 'accuracy' in H and 'val_accuracy' in H:
        plt.figure()
        plt.plot(H['accuracy'],     label='accuracy')
        plt.plot(H['val_accuracy'], label='val_accuracy')
        plt.title(f'Fold {fold_no} - Accuracy')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

def norm_cm(cm):
    with np.errstate(invalid='ignore', divide='ignore'):
        cmn = cm.astype(float) / cm.sum(axis=1, keepdims=True)
        cmn = np.nan_to_num(cmn)
    return cmn

def plot_confmat_ratio(cm, classes, title):
    M = norm_cm(cm)
    plt.figure()
    im = plt.imshow(M, interpolation='nearest', cmap='Blues', vmin=0.0, vmax=1.0)
    plt.title(title); plt.colorbar(im)
    ticks = np.arange(len(classes))
    plt.xticks(ticks, classes); plt.yticks(ticks, classes)
    for i in range(M.shape[0]):
        for j in range(M.shape[1]):
            val = M[i, j]
            txt_color = 'black' if val < 0.6 else 'white'
            plt.text(j, i, f"{val:.2f}", ha="center", va="center", color=txt_color, fontsize=10)
    plt.ylabel('실제 레이블'); plt.xlabel('예측 레이블')
    plt.tight_layout(); plt.show()

def _nanmean_along_epochs(list_of_lists):
    if not list_of_lists:
        return None, None
    maxlen = max(len(s) for s in list_of_lists)
    M = np.full((len(list_of_lists), maxlen), np.nan, dtype=np.float32)
    for i, s in enumerate(list_of_lists):
        arr = np.asarray(s, dtype=np.float32)
        M[i, :len(arr)] = arr
    return np.nanmean(M, axis=0), np.nanstd(M, axis=0)

def plot_mean_training_curves(histories):
    mean_loss, std_loss          = _nanmean_along_epochs([h.get('loss', []) for h in histories])
    mean_val_loss, std_val_loss = _nanmean_along_epochs([h.get('val_loss', []) for h in histories])

    if mean_loss is not None:
        x = np.arange(len(mean_loss))
        plt.figure()
        plt.plot(x, mean_loss,     label='loss (mean)')
        plt.plot(x, mean_val_loss, label='val_loss (mean)')
        plt.fill_between(x, mean_loss - std_loss,     mean_loss + std_loss,     alpha=0.15)
        plt.fill_between(x, mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.15)
        plt.title('LOSO 평균 Loss (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Loss')
        plt.legend(); plt.tight_layout(); plt.show()

    has_acc = all(('accuracy' in h and 'val_accuracy' in h) for h in histories)
    if has_acc:
        mean_acc, std_acc         = _nanmean_along_epochs([h['accuracy']     for h in histories])
        mean_val_acc, std_val_acc = _nanmean_along_epochs([h['val_accuracy'] for h in histories])
        x = np.arange(len(mean_acc))
        plt.figure()
        plt.plot(x, mean_acc,     label='accuracy (mean)')
        plt.plot(x, mean_val_acc, label='val_accuracy (mean)')
        plt.fill_between(x, mean_acc - std_acc,     mean_acc + std_acc,     alpha=0.15)
        plt.fill_between(x, mean_val_acc - std_val_acc, mean_val_acc + std_val_acc, alpha=0.15)
        plt.title('LOSO 평균 Accuracy (에포크 기준)')
        plt.xlabel('Epoch'); plt.ylabel('Accuracy')
        plt.legend(); plt.tight_layout(); plt.show()

# ===== 13 → 2 (위/아래) 매핑 및 데이터 필터 (가정) =====
#   - 이 부분은 외부 데이터와 변수 (X, y, meta, persons)가 정의되었다고 가정합니다.
#   - 실제 데이터셋으로 아래 변수들을 대체해야 합니다.
# KOREAN_LABELS = ['위-구개측', '아래-설측', '협측', ...]
# X = np.random.rand(100, 45, 48) # (샘플 수, 시퀀스 길이, 특징 차원)
# y = np.random.randint(0, 13, 100)
# meta = [{'person': p, 'src': f'file_{p}_{i}'} for i, p in enumerate(np.random.randint(0, 10, 100))]
# KOREAN_LABELS, X, y, meta 등 실제 데이터셋으로 대체해야 합니다.

# ... (위의 데이터 준비 코드가 여기에 위치)

# ===== 13 → 2 (위/아래) 매핑 및 데이터 필터 =====
labels_np = np.array(KOREAN_LABELS, dtype=object)

def _ud_from_label(lab: str):
    if ('구개측' in lab) or ('위-씹는면' in lab):
        return 0  # 위
    if ('설측' in lab) or ('아래-씹는면' in lab):
        return 1  # 아래
    return None   # 제외(협측 등)

keep_indices = []
y_ud_list = []
for i, yi in enumerate(y):
    lab = labels_np[yi]
    m = _ud_from_label(lab)
    if m is not None:
        keep_indices.append(i)
        y_ud_list.append(m)

keep_indices = np.array(keep_indices, dtype=int)
X_ud = X[keep_indices]
y_ud = np.array(y_ud_list, dtype=int)
meta_ud = [meta[i] for i in keep_indices]
persons_ud = np.array([m["person"] for m in meta_ud])

print(f"[Filter] 총 {len(X)}개 중 {len(X_ud)}개를 사용 (협측 제외).  위/아래 분포:", np.bincount(y_ud))

# ===== LOSO 학습/평가 루프 =====
F = X_ud.shape[-1]
HAND_DIMS = 42 if F >= 42 else F
EPS = 1e-7
logo = LeaveOneGroupOut()

CLASS_NAMES = ['위','아래']

histories = []
all_win_true, all_win_pred = [], []
all_clip_true, all_clip_pred = [], []
all_win_acc, all_clip_acc = [], []

fold_no = 0
total_folds = len(np.unique(persons_ud))

for train_idx, val_idx in logo.split(X_ud, y_ud, groups=persons_ud):
    fold_no += 1
    print(f"\n===== FOLD {fold_no}/{total_folds} - Person: {persons_ud[val_idx][0]} =====")

    # Split
    X_train, y_train = X_ud[train_idx], y_ud[train_idx]
    X_val,   y_val  = X_ud[val_idx],   y_ud[val_idx]

    # 스케일러: train으로만 fit
    scaler = StandardScaler(with_mean=True, with_std=True)
    Xtr_flat = X_train.reshape(-1, F)
    mask = (np.abs(Xtr_flat[:, :HAND_DIMS]).sum(axis=1) > EPS)
    scaler.fit(Xtr_flat[mask] if mask.any() else Xtr_flat)
    X_train_s = scaler.transform(Xtr_flat).reshape(X_train.shape)
    X_val_s   = scaler.transform(X_val.reshape(-1, F)).reshape(X_val.shape)

    # <<<<<<<<< Time Stretching 데이터 증강 적용 >>>>>>>>>
    X_train_augmented = []
    y_train_augmented = []
    original_length = X_train_s.shape[1]

    for i in range(X_train_s.shape[0]):
        X_train_augmented.append(X_train_s[i])
        y_train_augmented.append(y_train[i])

        if np.random.rand() > 0.5:
            factor = np.random.uniform(0.85, 1.15)
            augmented_data = time_stretch(X_train_s[i], factor=factor)
            
            # 길이 통일 (중요!)
            if augmented_data.shape[0] > original_length:
                augmented_data = augmented_data[:original_length]
            else:
                padding = np.zeros((original_length - augmented_data.shape[0], augmented_data.shape[1]), dtype=np.float32)
                augmented_data = np.vstack([augmented_data, padding])

            X_train_augmented.append(augmented_data)
            y_train_augmented.append(y_train[i])

    X_train_s_aug = np.array(X_train_augmented, dtype=np.float32)
    y_train_aug = np.array(y_train_augmented, dtype=np.int32)
    
    p = np.random.permutation(len(X_train_s_aug))
    X_train_s_aug = X_train_s_aug[p]
    y_train_aug = y_train_aug[p]
    # <<<<<<<<< 데이터 증강 적용 끝 >>>>>>>>>

    # 모델
    model = build_crnn_with_delta(input_shape=(X_train_s.shape[1], X_train_s.shape[2]), n_classes=2)

    cls_counts = np.bincount(y_train_aug, minlength=2)
    class_weights = {i: float(np.median(cls_counts)/c) for i, c in enumerate(cls_counts)}

    cb = [
        tf.keras.callbacks.EarlyStopping(patience=ES_PATIENCE, restore_best_weights=True, monitor='val_loss'),
        tf.keras.callbacks.ReduceLROnPlateau(patience=RLR_PATIENCE, factor=0.5, min_lr=1e-5),
    ]

    history = model.fit(
        X_train_s_aug, y_train_aug,
        validation_data=(X_val_s, y_val),
        epochs=EPOCHS, batch_size=BATCH_SIZE,
        class_weight=class_weights,
        callbacks=cb, verbose=1
    )
    histories.append(history.history)

    if PLOT_LAST_FOLD_CURVES and fold_no == total_folds:
        plot_training_curves(history, fold_no)

    # 윈도우 단위 예측
    p = model.predict(X_val_s, verbose=0)
    y_pred = p.argmax(1)
    win_acc = accuracy_score(y_val, y_pred)
    all_win_acc.append(win_acc)
    all_win_true.append(y_val); all_win_pred.append(y_pred)

    # 클립 단위 예측
    bucket_p, bucket_y = defaultdict(list), {}
    val_meta = [meta_ud[i] for i in val_idx]
    for i, m in enumerate(val_meta):
        bucket_p[m["src"]].append(p[i])
        bucket_y[m["src"]] = y_val[i]
    P_clip, Y_clip = [], []
    for src, ps in bucket_p.items():
        P_clip.append(np.mean(ps, axis=0))
        Y_clip.append(bucket_y[src])
    clip_pred = np.argmax(np.vstack(P_clip), axis=1)
    clip_acc = accuracy_score(Y_clip, clip_pred)
    all_clip_acc.append(clip_acc)
    all_clip_true.append(np.array(Y_clip))
    all_clip_pred.append(clip_pred)

# ===== 폴드 전체 집계 =====
all_win_true  = np.concatenate(all_win_true, axis=0)
all_win_pred  = np.concatenate(all_win_pred, axis=0)
all_clip_true = np.concatenate(all_clip_true, axis=0)
all_clip_pred = np.concatenate(all_clip_pred, axis=0)

print("\n==== LOSO Summary (Up/Down) ====")
print(f"Mean Window Acc: {np.mean(all_win_acc):.3f} ± {np.std(all_win_acc):.3f}")
print(f"Mean Clip   Acc: {np.mean(all_clip_acc):.3f} ± {np.std(all_clip_acc):.3f}")

# ===== 최종(전체 사람) 혼동행렬/지표 =====
if EVAL_LEVEL == "clip":
    y_true_overall = all_clip_true; y_pred_overall = all_clip_pred; level_name = "클립"
else:
    y_true_overall = all_win_true;  y_pred_overall = all_win_pred;  level_name = "윈도우"

overall_acc = accuracy_score(y_true_overall, y_pred_overall)
print(f"\n==== OVERALL ({level_name}) ====")
print(f"Overall {level_name} Acc: {overall_acc:.3f}")
print(classification_report(y_true_overall, y_pred_overall, target_names=CLASS_NAMES, digits=3))

cm_overall = confusion_matrix(y_true_overall, y_pred_overall, labels=[0,1])
plot_confmat_ratio(cm_overall, CLASS_NAMES, f'전체 {level_name} 혼동행렬 (행 정규화, 비율)')

# ===== LOSO 평균 곡선 =====
plot_mean_training_curves(histories)
# Out:
# [Filter] 총 5248개 중 4016개를 사용 (협측 제외).  위/아래 분포: [2000 2016]
#
# ===== FOLD 1/22 - Person: P01 =====
# Epoch 1/80
# 85/85 [==============================] - 5s 17ms/step - loss: 0.7409 - accuracy: 0.6830 - val_loss: 0.6253 - val_accuracy: 0.7150 - lr: 3.0000e-04
# Epoch 2/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.5192 - accuracy: 0.8014 - val_loss: 0.8561 - val_accuracy: 0.6575 - lr: 3.0000e-04
# Epoch 3/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.4201 - accuracy: 0.8498 - val_loss: 1.1584 - val_accuracy: 0.6750 - lr: 3.0000e-04
# Epoch 4/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.3517 - accuracy: 0.8818 - val_loss: 1.7570 - val_accuracy: 0.6825 - lr: 3.0000e-04
# Epoch 5/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.2592 - accuracy: 0.9262 - val_loss: 2.2548 - val_accuracy: 0.6625 - lr: 3.0000e-04
# Epoch 6/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.2228 - accuracy: 0.9439 - val_loss: 1.7081 - val_accuracy: 0.6900 - lr: 3.0000e-04
# Epoch 7/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1968 - accuracy: 0.9556 - val_loss: 2.2759 - val_accuracy: 0.6500 - lr: 3.0000e-04
# Epoch 8/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1742 - accuracy: 0.9643 - val_loss: 2.0919 - val_accuracy: 0.6450 - lr: 1.5000e-04
# Epoch 9/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1458 - accuracy: 0.9748 - val_loss: 1.8869 - val_accuracy: 0.6800 - lr: 1.5000e-04
# Epoch 10/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1351 - accuracy: 0.9801 - val_loss: 2.2458 - val_accuracy: 0.6725 - lr: 1.5000e-04
# Epoch 11/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1434 - accuracy: 0.9755 - val_loss: 2.0686 - val_accuracy: 0.6575 - lr: 1.5000e-04
# Epoch 12/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1286 - accuracy: 0.9827 - val_loss: 2.0011 - val_accuracy: 0.6825 - lr: 1.5000e-04
# Epoch 13/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1306 - accuracy: 0.9796 - val_loss: 1.9620 - val_accuracy: 0.6900 - lr: 1.5000e-04
#
# ===== FOLD 2/22 - Person: P02 =====
# Epoch 1/80
# 85/85 [==============================] - 3s 16ms/step - loss: 0.8030 - accuracy: 0.6578 - val_loss: 0.5375 - val_accuracy: 0.8100 - lr: 3.0000e-04
# Epoch 2/80
# 85/85 [==============================] - 1s 12ms/step - loss: 0.5177 - accuracy: 0.7912 - val_loss: 0.3765 - val_accuracy: 0.8475 - lr: 3.0000e-04
# Epoch 3/80
# 85/85 [==============================] - 1s 12ms/step - loss: 0.3952 - accuracy: 0.8623 - val_loss: 0.4687 - val_accuracy: 0.8725 - lr: 3.0000e-04
# Epoch 4/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.3180 - accuracy: 0.9033 - val_loss: 0.5486 - val_accuracy: 0.8875 - lr: 3.0000e-04
# Epoch 5/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2520 - accuracy: 0.9351 - val_loss: 0.9412 - val_accuracy: 0.8175 - lr: 3.0000e-04
# Epoch 6/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.2090 - accuracy: 0.9485 - val_loss: 0.6491 - val_accuracy: 0.8775 - lr: 3.0000e-04
# Epoch 7/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1785 - accuracy: 0.9616 - val_loss: 0.7028 - val_accuracy: 0.8700 - lr: 3.0000e-04
# Epoch 8/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1536 - accuracy: 0.9726 - val_loss: 0.7542 - val_accuracy: 0.8625 - lr: 3.0000e-04
# Epoch 9/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1391 - accuracy: 0.9780 - val_loss: 0.8220 - val_accuracy: 0.8450 - lr: 1.5000e-04
# Epoch 10/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1365 - accuracy: 0.9800 - val_loss: 0.9991 - val_accuracy: 0.8250 - lr: 1.5000e-04
# Epoch 11/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1395 - accuracy: 0.9770 - val_loss: 0.7871 - val_accuracy: 0.8625 - lr: 1.5000e-04
# Epoch 12/80
# 85/85 [==============================] - 1s 11ms/step - loss: 0.1112 - accuracy: 0.9887 - val_loss: 0.7248 - val_accuracy: 0.8700 - lr: 1.5000e-04
# Epoch 13/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1061 - accuracy: 0.9891 - val_loss: 0.8369 - val_accuracy: 0.8625 - lr: 1.5000e-04
# Epoch 14/80
# 85/85 [==============================] - 1s 10ms/step - loss: 0.1067 - accuracy: 0.9878 - val_loss: 0.6985 - val_accuracy: 0.8750 - lr: 1.5000e-04
#
# ===== FOLD 3/22 - Person: P03 =====
# Epoch 1/80
# 89/89 [==============================] - 3s 16ms/step - loss: 0.7186 - accuracy: 0.6829 - val_loss: 0.6575 - val_accuracy: 0.7583 - lr: 3.0000e-04
# Epoch 2/80
# 89/89 [==============================] - 1s 11ms/step - loss: 0.5018 - accuracy: 0.8054 - val_loss: 0.9478 - val_accuracy: 0.7125 - lr: 3.0000e-04
# Epoch 3/80
# 89/89 [==============================] - 1s 11ms/step - loss: 0.3898 - accuracy: 0.8662 - val_loss: 1.1707 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 4/80
# 89/89 [==============================] - 1s 11ms/step - loss: 0.3024 - accuracy: 0.9108 - val_loss: 1.4825 - val_accuracy: 0.7542 - lr: 3.0000e-04
# Epoch 5/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.2602 - accuracy: 0.9277 - val_loss: 1.9825 - val_accuracy: 0.6833 - lr: 3.0000e-04
# Epoch 6/80
# 89/89 [==============================] - 1s 11ms/step - loss: 0.1965 - accuracy: 0.9555 - val_loss: 1.6538 - val_accuracy: 0.7000 - lr: 3.0000e-04
# Epoch 7/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1909 - accuracy: 0.9576 - val_loss: 1.6883 - val_accuracy: 0.7375 - lr: 3.0000e-04
# Epoch 8/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1412 - accuracy: 0.9777 - val_loss: 1.5892 - val_accuracy: 0.7500 - lr: 1.5000e-04
# Epoch 9/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1480 - accuracy: 0.9739 - val_loss: 1.7154 - val_accuracy: 0.7208 - lr: 1.5000e-04
# Epoch 10/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1260 - accuracy: 0.9835 - val_loss: 1.7351 - val_accuracy: 0.7167 - lr: 1.5000e-04
# Epoch 11/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1326 - accuracy: 0.9778 - val_loss: 1.6502 - val_accuracy: 0.7292 - lr: 1.5000e-04
# Epoch 12/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1136 - accuracy: 0.9865 - val_loss: 1.7882 - val_accuracy: 0.7250 - lr: 1.5000e-04
# Epoch 13/80
# 89/89 [==============================] - 1s 10ms/step - loss: 0.1065 - accuracy: 0.9892 - val_loss: 1.7102 - val_accuracy: 0.7542 - lr: 1.5000e-04
#
# ===== FOLD 4/22 - Person: P04 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 16ms/step - loss: 0.7915 - accuracy: 0.6752 - val_loss: 0.7472 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.5206 - accuracy: 0.8053 - val_loss: 1.4138 - val_accuracy: 0.5000 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.3992 - accuracy: 0.8662 - val_loss: 2.2831 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.3133 - accuracy: 0.9021 - val_loss: 2.9962 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.2411 - accuracy: 0.9355 - val_loss: 3.7472 - val_accuracy: 0.5000 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1874 - accuracy: 0.9577 - val_loss: 3.7924 - val_accuracy: 0.5125 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1638 - accuracy: 0.9687 - val_loss: 3.5292 - val_accuracy: 0.5688 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1404 - accuracy: 0.9763 - val_loss: 3.6020 - val_accuracy: 0.5625 - lr: 1.5000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1268 - accuracy: 0.9833 - val_loss: 4.1447 - val_accuracy: 0.4625 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1196 - accuracy: 0.9840 - val_loss: 4.0510 - val_accuracy: 0.4750 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1265 - accuracy: 0.9821 - val_loss: 4.0219 - val_accuracy: 0.5000 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1191 - accuracy: 0.9837 - val_loss: 4.0444 - val_accuracy: 0.5125 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1143 - accuracy: 0.9830 - val_loss: 3.9230 - val_accuracy: 0.5125 - lr: 1.5000e-04
#
# ===== FOLD 5/22 - Person: P05 =====
# Epoch 1/80
# 90/90 [==============================] - 3s 16ms/step - loss: 0.7533 - accuracy: 0.6648 - val_loss: 0.6999 - val_accuracy: 0.5750 - lr: 3.0000e-04
# Epoch 2/80
# 90/90 [==============================] - 1s 11ms/step - loss: 0.5384 - accuracy: 0.7779 - val_loss: 0.6846 - val_accuracy: 0.6938 - lr: 3.0000e-04
# Epoch 3/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.4213 - accuracy: 0.8556 - val_loss: 0.9092 - val_accuracy: 0.7250 - lr: 3.0000e-04
# Epoch 4/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.3236 - accuracy: 0.8963 - val_loss: 0.7086 - val_accuracy: 0.7750 - lr: 3.0000e-04
# Epoch 5/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.2606 - accuracy: 0.9265 - val_loss: 0.7109 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 6/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.2080 - accuracy: 0.9505 - val_loss: 0.5498 - val_accuracy: 0.8562 - lr: 3.0000e-04
# Epoch 7/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1910 - accuracy: 0.9571 - val_loss: 0.5344 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 8/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1808 - accuracy: 0.9599 - val_loss: 0.4311 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 9/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1685 - accuracy: 0.9649 - val_loss: 0.7075 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 10/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1412 - accuracy: 0.9739 - val_loss: 0.7247 - val_accuracy: 0.8125 - lr: 3.0000e-04
# Epoch 11/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1373 - accuracy: 0.9776 - val_loss: 0.8657 - val_accuracy: 0.7937 - lr: 3.0000e-04
# Epoch 12/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1390 - accuracy: 0.9752 - val_loss: 0.3620 - val_accuracy: 0.8687 - lr: 3.0000e-04
# Epoch 13/80
# 90/90 [==============================] - 1s 11ms/step - loss: 0.1278 - accuracy: 0.9812 - val_loss: 0.5497 - val_accuracy: 0.8062 - lr: 3.0000e-04
# Epoch 14/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1178 - accuracy: 0.9811 - val_loss: 0.5161 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 15/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1047 - accuracy: 0.9878 - val_loss: 0.7921 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 16/80
# 90/90 [==============================] - 1s 11ms/step - loss: 0.0996 - accuracy: 0.9901 - val_loss: 0.8633 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 17/80
# 90/90 [==============================] - 1s 11ms/step - loss: 0.1008 - accuracy: 0.9877 - val_loss: 0.5833 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 18/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1032 - accuracy: 0.9870 - val_loss: 0.6112 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 19/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.0860 - accuracy: 0.9929 - val_loss: 0.4289 - val_accuracy: 0.8750 - lr: 1.5000e-04
# Epoch 20/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.0782 - accuracy: 0.9950 - val_loss: 0.5436 - val_accuracy: 0.8687 - lr: 1.5000e-04
# Epoch 21/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.0851 - accuracy: 0.9927 - val_loss: 0.7549 - val_accuracy: 0.8250 - lr: 1.5000e-04
# Epoch 22/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.0730 - accuracy: 0.9965 - val_loss: 0.6131 - val_accuracy: 0.8625 - lr: 1.5000e-04
# Epoch 23/80
# 90/90 [==============================] - 1s 11ms/step - loss: 0.0809 - accuracy: 0.9934 - val_loss: 0.4860 - val_accuracy: 0.8687 - lr: 1.5000e-04
# Epoch 24/80
# 90/90 [==============================] - 1s 10ms/step - loss: 0.0796 - accuracy: 0.9930 - val_loss: 0.6104 - val_accuracy: 0.8562 - lr: 1.5000e-04
#
# ===== FOLD 6/22 - Person: P06 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 15ms/step - loss: 0.7581 - accuracy: 0.6750 - val_loss: 0.5437 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.5291 - accuracy: 0.7942 - val_loss: 0.4137 - val_accuracy: 0.8562 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.4065 - accuracy: 0.8538 - val_loss: 0.6772 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.3242 - accuracy: 0.8986 - val_loss: 1.0206 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.2602 - accuracy: 0.9257 - val_loss: 1.2887 - val_accuracy: 0.7312 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.2104 - accuracy: 0.9478 - val_loss: 1.9357 - val_accuracy: 0.6875 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1855 - accuracy: 0.9589 - val_loss: 0.8150 - val_accuracy: 0.8125 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1618 - accuracy: 0.9668 - val_loss: 0.5715 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1377 - accuracy: 0.9789 - val_loss: 0.7948 - val_accuracy: 0.8625 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1353 - accuracy: 0.9800 - val_loss: 1.1889 - val_accuracy: 0.7937 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1201 - accuracy: 0.9855 - val_loss: 0.8260 - val_accuracy: 0.8687 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1193 - accuracy: 0.9855 - val_loss: 0.8967 - val_accuracy: 0.8562 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1087 - accuracy: 0.9877 - val_loss: 0.9072 - val_accuracy: 0.8625 - lr: 1.5000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1127 - accuracy: 0.9876 - val_loss: 1.3102 - val_accuracy: 0.8000 - lr: 1.5000e-04
#
# ===== FOLD 7/22 - Person: P07 =====
# Epoch 1/80
# 91/91 [==============================] - 4s 19ms/step - loss: 0.7562 - accuracy: 0.6857 - val_loss: 0.9472 - val_accuracy: 0.4250 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.4839 - accuracy: 0.8217 - val_loss: 1.7002 - val_accuracy: 0.4500 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.3751 - accuracy: 0.8735 - val_loss: 2.0021 - val_accuracy: 0.5000 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.2947 - accuracy: 0.9114 - val_loss: 2.8876 - val_accuracy: 0.4625 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.2473 - accuracy: 0.9317 - val_loss: 3.0008 - val_accuracy: 0.4938 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2145 - accuracy: 0.9468 - val_loss: 2.7195 - val_accuracy: 0.6250 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1945 - accuracy: 0.9527 - val_loss: 2.5462 - val_accuracy: 0.5562 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1535 - accuracy: 0.9711 - val_loss: 3.1670 - val_accuracy: 0.4875 - lr: 1.5000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1543 - accuracy: 0.9694 - val_loss: 2.6170 - val_accuracy: 0.6000 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1314 - accuracy: 0.9820 - val_loss: 2.3923 - val_accuracy: 0.6062 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1242 - accuracy: 0.9838 - val_loss: 2.8241 - val_accuracy: 0.5875 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1243 - accuracy: 0.9825 - val_loss: 2.4897 - val_accuracy: 0.6313 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1230 - accuracy: 0.9822 - val_loss: 2.2500 - val_accuracy: 0.6313 - lr: 1.5000e-04
#
# ===== FOLD 8/22 - Person: P08 =====
# Epoch 1/80
# 91/91 [==============================] - 4s 17ms/step - loss: 0.7546 - accuracy: 0.6741 - val_loss: 0.7095 - val_accuracy: 0.5875 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.5247 - accuracy: 0.7899 - val_loss: 0.7560 - val_accuracy: 0.5125 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.4175 - accuracy: 0.8420 - val_loss: 0.7057 - val_accuracy: 0.6938 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.3428 - accuracy: 0.8866 - val_loss: 0.4677 - val_accuracy: 0.8313 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2738 - accuracy: 0.9217 - val_loss: 0.8056 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2235 - accuracy: 0.9400 - val_loss: 1.1655 - val_accuracy: 0.7625 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.2048 - accuracy: 0.9476 - val_loss: 0.8400 - val_accuracy: 0.8375 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1561 - accuracy: 0.9694 - val_loss: 1.1210 - val_accuracy: 0.7875 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1532 - accuracy: 0.9711 - val_loss: 0.8080 - val_accuracy: 0.8188 - lr: 3.0000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1439 - accuracy: 0.9741 - val_loss: 0.3604 - val_accuracy: 0.9375 - lr: 3.0000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1516 - accuracy: 0.9711 - val_loss: 0.5962 - val_accuracy: 0.8625 - lr: 3.0000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1414 - accuracy: 0.9735 - val_loss: 0.8528 - val_accuracy: 0.8062 - lr: 3.0000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1129 - accuracy: 0.9846 - val_loss: 0.8868 - val_accuracy: 0.8562 - lr: 3.0000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1064 - accuracy: 0.9869 - val_loss: 0.8718 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 15/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1059 - accuracy: 0.9872 - val_loss: 0.3452 - val_accuracy: 0.9312 - lr: 3.0000e-04
# Epoch 16/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1117 - accuracy: 0.9855 - val_loss: 1.3603 - val_accuracy: 0.7000 - lr: 3.0000e-04
# Epoch 17/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0995 - accuracy: 0.9877 - val_loss: 0.6896 - val_accuracy: 0.8562 - lr: 3.0000e-04
# Epoch 18/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0945 - accuracy: 0.9898 - val_loss: 0.7398 - val_accuracy: 0.8188 - lr: 3.0000e-04
# Epoch 19/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0934 - accuracy: 0.9891 - val_loss: 0.9133 - val_accuracy: 0.7750 - lr: 3.0000e-04
# Epoch 20/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0913 - accuracy: 0.9917 - val_loss: 0.7572 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 21/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0899 - accuracy: 0.9900 - val_loss: 0.6098 - val_accuracy: 0.8625 - lr: 3.0000e-04
# Epoch 22/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0763 - accuracy: 0.9945 - val_loss: 0.4112 - val_accuracy: 0.9250 - lr: 1.5000e-04
# Epoch 23/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0723 - accuracy: 0.9964 - val_loss: 0.4959 - val_accuracy: 0.9125 - lr: 1.5000e-04
# Epoch 24/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0714 - accuracy: 0.9955 - val_loss: 0.6687 - val_accuracy: 0.8375 - lr: 1.5000e-04
# Epoch 25/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0705 - accuracy: 0.9967 - val_loss: 1.0358 - val_accuracy: 0.7688 - lr: 1.5000e-04
# Epoch 26/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0691 - accuracy: 0.9971 - val_loss: 0.4013 - val_accuracy: 0.9187 - lr: 1.5000e-04
# Epoch 27/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0670 - accuracy: 0.9964 - val_loss: 1.3239 - val_accuracy: 0.7563 - lr: 1.5000e-04
#
# ===== FOLD 9/22 - Person: P09 =====
# Epoch 1/80
# 91/91 [==============================] - 4s 18ms/step - loss: 0.8069 - accuracy: 0.6675 - val_loss: 0.4900 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.5682 - accuracy: 0.7747 - val_loss: 0.5108 - val_accuracy: 0.8625 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.4289 - accuracy: 0.8449 - val_loss: 0.6424 - val_accuracy: 0.8562 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.3317 - accuracy: 0.8907 - val_loss: 0.5906 - val_accuracy: 0.8625 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.2556 - accuracy: 0.9281 - val_loss: 0.7556 - val_accuracy: 0.8938 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2339 - accuracy: 0.9428 - val_loss: 0.6257 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1943 - accuracy: 0.9562 - val_loss: 0.6249 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1582 - accuracy: 0.9698 - val_loss: 0.8182 - val_accuracy: 0.8813 - lr: 1.5000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1449 - accuracy: 0.9747 - val_loss: 0.7406 - val_accuracy: 0.8813 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1357 - accuracy: 0.9798 - val_loss: 0.7734 - val_accuracy: 0.8562 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1412 - accuracy: 0.9767 - val_loss: 0.7396 - val_accuracy: 0.8813 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1312 - accuracy: 0.9779 - val_loss: 0.8649 - val_accuracy: 0.8687 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1200 - accuracy: 0.9835 - val_loss: 0.8642 - val_accuracy: 0.8875 - lr: 1.5000e-04
#
# ===== FOLD 10/22 - Person: P10 =====
# Epoch 1/80
# 91/91 [==============================] - 4s 19ms/step - loss: 0.7648 - accuracy: 0.6716 - val_loss: 0.5167 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.5506 - accuracy: 0.7813 - val_loss: 0.5119 - val_accuracy: 0.8188 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.4543 - accuracy: 0.8366 - val_loss: 0.4021 - val_accuracy: 0.8938 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.3619 - accuracy: 0.8776 - val_loss: 0.9113 - val_accuracy: 0.7312 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2791 - accuracy: 0.9205 - val_loss: 0.8677 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2337 - accuracy: 0.9386 - val_loss: 0.8015 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1858 - accuracy: 0.9622 - val_loss: 0.8507 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1715 - accuracy: 0.9650 - val_loss: 1.2426 - val_accuracy: 0.7937 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1537 - accuracy: 0.9730 - val_loss: 0.8995 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1328 - accuracy: 0.9818 - val_loss: 1.0598 - val_accuracy: 0.8625 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1202 - accuracy: 0.9851 - val_loss: 1.1961 - val_accuracy: 0.8125 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1159 - accuracy: 0.9867 - val_loss: 1.3052 - val_accuracy: 0.8125 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1144 - accuracy: 0.9860 - val_loss: 1.1663 - val_accuracy: 0.8313 - lr: 1.5000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1041 - accuracy: 0.9894 - val_loss: 1.3659 - val_accuracy: 0.8062 - lr: 1.5000e-04
# Epoch 15/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1029 - accuracy: 0.9896 - val_loss: 1.1245 - val_accuracy: 0.8562 - lr: 1.5000e-04
#
# ===== FOLD 11/22 - Person: P11 =====
# Epoch 1/80
# 92/92 [==============================] - 4s 19ms/step - loss: 0.7383 - accuracy: 0.6789 - val_loss: 0.5720 - val_accuracy: 0.6687 - lr: 3.0000e-04
# Epoch 2/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.4976 - accuracy: 0.8072 - val_loss: 0.4430 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 3/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.3865 - accuracy: 0.8675 - val_loss: 0.6109 - val_accuracy: 0.7937 - lr: 3.0000e-04
# Epoch 4/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.3079 - accuracy: 0.9003 - val_loss: 0.2530 - val_accuracy: 0.9625 - lr: 3.0000e-04
# Epoch 5/80
# 92/92 [==============================] - 1s 14ms/step - loss: 0.2511 - accuracy: 0.9327 - val_loss: 0.6125 - val_accuracy: 0.8687 - lr: 3.0000e-04
# Epoch 6/80
# 92/92 [==============================] - 1s 12ms/step - loss: 0.2154 - accuracy: 0.9485 - val_loss: 0.6924 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 7/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.2073 - accuracy: 0.9483 - val_loss: 0.4134 - val_accuracy: 0.9062 - lr: 3.0000e-04
# Epoch 8/80
# 92/92 [==============================] - 1s 14ms/step - loss: 0.1785 - accuracy: 0.9621 - val_loss: 0.7081 - val_accuracy: 0.8188 - lr: 3.0000e-04
# Epoch 9/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1538 - accuracy: 0.9701 - val_loss: 0.6217 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 10/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1459 - accuracy: 0.9755 - val_loss: 0.8794 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 11/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1179 - accuracy: 0.9839 - val_loss: 0.9266 - val_accuracy: 0.8438 - lr: 1.5000e-04
# Epoch 12/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1144 - accuracy: 0.9861 - val_loss: 1.2465 - val_accuracy: 0.8000 - lr: 1.5000e-04
# Epoch 13/80
# 92/92 [==============================] - 1s 13ms/step - loss: 0.1073 - accuracy: 0.9873 - val_loss: 0.8592 - val_accuracy: 0.8000 - lr: 1.5000e-04
# Epoch 14/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1091 - accuracy: 0.9883 - val_loss: 1.1678 - val_accuracy: 0.8062 - lr: 1.5000e-04
# Epoch 15/80
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1050 - accuracy: 0.9873 - val_loss: 1.1200 - val_accuracy: 0.8188 - lr: 1.5000e-04
# Epoch 16/80
# 92/92 [==============================] - 1s 10ms/step - loss: 0.1068 - accuracy: 0.9870 - val_loss: 1.1981 - val_accuracy: 0.8062 - lr: 1.5000e-04
#
# ===== FOLD 12/22 - Person: P12 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 15ms/step - loss: 0.7345 - accuracy: 0.6766 - val_loss: 0.5120 - val_accuracy: 0.7431 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.4903 - accuracy: 0.8125 - val_loss: 0.6184 - val_accuracy: 0.7431 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.3687 - accuracy: 0.8694 - val_loss: 0.1667 - val_accuracy: 0.9792 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.2920 - accuracy: 0.9110 - val_loss: 1.0389 - val_accuracy: 0.8056 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.2323 - accuracy: 0.9354 - val_loss: 0.7371 - val_accuracy: 0.8056 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1949 - accuracy: 0.9550 - val_loss: 0.9721 - val_accuracy: 0.7986 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1741 - accuracy: 0.9610 - val_loss: 0.2818 - val_accuracy: 0.9444 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1663 - accuracy: 0.9665 - val_loss: 0.6270 - val_accuracy: 0.8125 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1494 - accuracy: 0.9713 - val_loss: 0.2013 - val_accuracy: 0.9514 - lr: 3.0000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1289 - accuracy: 0.9802 - val_loss: 0.6575 - val_accuracy: 0.8333 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1156 - accuracy: 0.9850 - val_loss: 1.1517 - val_accuracy: 0.7986 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1194 - accuracy: 0.9837 - val_loss: 0.3302 - val_accuracy: 0.9097 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1048 - accuracy: 0.9893 - val_loss: 0.5407 - val_accuracy: 0.8681 - lr: 1.5000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1074 - accuracy: 0.9869 - val_loss: 0.3738 - val_accuracy: 0.9097 - lr: 1.5000e-04
# Epoch 15/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1023 - accuracy: 0.9899 - val_loss: 0.3646 - val_accuracy: 0.9028 - lr: 1.5000e-04
#
# ===== FOLD 13/22 - Person: P13 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 15ms/step - loss: 0.7564 - accuracy: 0.6705 - val_loss: 0.6063 - val_accuracy: 0.6797 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 10ms/step - loss: 0.5496 - accuracy: 0.7714 - val_loss: 0.5278 - val_accuracy: 0.7422 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.4325 - accuracy: 0.8376 - val_loss: 0.9923 - val_accuracy: 0.7656 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.3533 - accuracy: 0.8785 - val_loss: 0.4337 - val_accuracy: 0.8516 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.2857 - accuracy: 0.9136 - val_loss: 0.6660 - val_accuracy: 0.7812 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.2427 - accuracy: 0.9300 - val_loss: 0.3022 - val_accuracy: 0.9062 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.2044 - accuracy: 0.9480 - val_loss: 0.2640 - val_accuracy: 0.9141 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1780 - accuracy: 0.9616 - val_loss: 0.3737 - val_accuracy: 0.8906 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1617 - accuracy: 0.9679 - val_loss: 0.9766 - val_accuracy: 0.7578 - lr: 3.0000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1605 - accuracy: 0.9684 - val_loss: 0.7154 - val_accuracy: 0.8359 - lr: 3.0000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1420 - accuracy: 0.9762 - val_loss: 0.5385 - val_accuracy: 0.8516 - lr: 3.0000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1223 - accuracy: 0.9819 - val_loss: 0.8653 - val_accuracy: 0.8359 - lr: 3.0000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1242 - accuracy: 0.9801 - val_loss: 0.8317 - val_accuracy: 0.7734 - lr: 3.0000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0966 - accuracy: 0.9915 - val_loss: 0.8971 - val_accuracy: 0.8359 - lr: 1.5000e-04
# Epoch 15/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0958 - accuracy: 0.9912 - val_loss: 0.5233 - val_accuracy: 0.8672 - lr: 1.5000e-04
# Epoch 16/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0978 - accuracy: 0.9902 - val_loss: 0.2406 - val_accuracy: 0.9375 - lr: 1.5000e-04
# Epoch 17/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0917 - accuracy: 0.9907 - val_loss: 0.1901 - val_accuracy: 0.9453 - lr: 1.5000e-04
# Epoch 18/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0952 - accuracy: 0.9910 - val_loss: 0.3636 - val_accuracy: 0.8750 - lr: 1.5000e-04
# Epoch 19/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0913 - accuracy: 0.9912 - val_loss: 0.7414 - val_accuracy: 0.8438 - lr: 1.5000e-04
# Epoch 20/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0927 - accuracy: 0.9914 - val_loss: 0.1921 - val_accuracy: 0.9453 - lr: 1.5000e-04
# Epoch 21/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0857 - accuracy: 0.9927 - val_loss: 0.5487 - val_accuracy: 0.8438 - lr: 1.5000e-04
# Epoch 22/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0861 - accuracy: 0.9929 - val_loss: 0.8082 - val_accuracy: 0.8750 - lr: 1.5000e-04
# Epoch 23/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0885 - accuracy: 0.9915 - val_loss: 0.6881 - val_accuracy: 0.8516 - lr: 1.5000e-04
# Epoch 24/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0755 - accuracy: 0.9964 - val_loss: 0.5533 - val_accuracy: 0.8594 - lr: 7.5000e-05
# Epoch 25/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0792 - accuracy: 0.9950 - val_loss: 0.3121 - val_accuracy: 0.8984 - lr: 7.5000e-05
# Epoch 26/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0748 - accuracy: 0.9959 - val_loss: 0.1707 - val_accuracy: 0.9531 - lr: 7.5000e-05
# Epoch 27/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0708 - accuracy: 0.9976 - val_loss: 0.2645 - val_accuracy: 0.9453 - lr: 7.5000e-05
# Epoch 28/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0729 - accuracy: 0.9962 - val_loss: 0.3939 - val_accuracy: 0.8906 - lr: 7.5000e-05
# Epoch 29/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0743 - accuracy: 0.9955 - val_loss: 0.2394 - val_accuracy: 0.9453 - lr: 7.5000e-05
# Epoch 30/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0787 - accuracy: 0.9952 - val_loss: 0.8251 - val_accuracy: 0.8672 - lr: 7.5000e-05
# Epoch 31/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0703 - accuracy: 0.9974 - val_loss: 0.2633 - val_accuracy: 0.9141 - lr: 7.5000e-05
# Epoch 32/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0731 - accuracy: 0.9962 - val_loss: 0.4826 - val_accuracy: 0.8672 - lr: 7.5000e-05
# Epoch 33/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0663 - accuracy: 0.9972 - val_loss: 0.2939 - val_accuracy: 0.9375 - lr: 3.7500e-05
# Epoch 34/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0692 - accuracy: 0.9969 - val_loss: 0.3042 - val_accuracy: 0.9297 - lr: 3.7500e-05
# Epoch 35/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0679 - accuracy: 0.9979 - val_loss: 0.2318 - val_accuracy: 0.9375 - lr: 3.7500e-05
# Epoch 36/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0721 - accuracy: 0.9962 - val_loss: 0.2553 - val_accuracy: 0.9453 - lr: 3.7500e-05
# Epoch 37/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0684 - accuracy: 0.9978 - val_loss: 0.1465 - val_accuracy: 0.9609 - lr: 3.7500e-05
# Epoch 38/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0647 - accuracy: 0.9976 - val_loss: 0.2476 - val_accuracy: 0.9453 - lr: 3.7500e-05
# Epoch 39/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0693 - accuracy: 0.9971 - val_loss: 0.5668 - val_accuracy: 0.8750 - lr: 3.7500e-05
# Epoch 40/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0668 - accuracy: 0.9969 - val_loss: 0.4664 - val_accuracy: 0.8828 - lr: 3.7500e-05
# Epoch 41/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0668 - accuracy: 0.9974 - val_loss: 0.6256 - val_accuracy: 0.8672 - lr: 3.7500e-05
# Epoch 42/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0664 - accuracy: 0.9976 - val_loss: 0.3696 - val_accuracy: 0.9219 - lr: 3.7500e-05
# Epoch 43/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0652 - accuracy: 0.9979 - val_loss: 0.4876 - val_accuracy: 0.8750 - lr: 3.7500e-05
# Epoch 44/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0680 - accuracy: 0.9965 - val_loss: 0.6804 - val_accuracy: 0.8594 - lr: 1.8750e-05
# Epoch 45/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0630 - accuracy: 0.9984 - val_loss: 0.4664 - val_accuracy: 0.8906 - lr: 1.8750e-05
# Epoch 46/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0642 - accuracy: 0.9974 - val_loss: 0.3700 - val_accuracy: 0.9297 - lr: 1.8750e-05
# Epoch 47/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0634 - accuracy: 0.9978 - val_loss: 0.3870 - val_accuracy: 0.9297 - lr: 1.8750e-05
# Epoch 48/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0638 - accuracy: 0.9971 - val_loss: 0.4730 - val_accuracy: 0.8828 - lr: 1.8750e-05
# Epoch 49/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.0601 - accuracy: 0.9988 - val_loss: 0.4866 - val_accuracy: 0.8828 - lr: 1.8750e-05
#
# ===== FOLD 14/22 - Person: P14 =====
# Epoch 1/80
# 92/92 [==============================] - 3s 17ms/step - loss: 0.7754 - accuracy: 0.6756 - val_loss: 0.6649 - val_accuracy: 0.6111 - lr: 3.0000e-04
# Epoch 2/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.5281 - accuracy: 0.7971 - val_loss: 0.6175 - val_accuracy: 0.7222 - lr: 3.0000e-04
# Epoch 3/80
# 92/92 [==============================] - 1s 12ms/step - loss: 0.3819 - accuracy: 0.8654 - val_loss: 0.8697 - val_accuracy: 0.7639 - lr: 3.0000e-04
# Epoch 4/80
# 92/92 [==============================] - 1s 12ms/step - loss: 0.3052 - accuracy: 0.9054 - val_loss: 1.3730 - val_accuracy: 0.7292 - lr: 3.0000e-04
# Epoch 5/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.2420 - accuracy: 0.9338 - val_loss: 2.3090 - val_accuracy: 0.6250 - lr: 3.0000e-04
# Epoch 6/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1996 - accuracy: 0.9536 - val_loss: 2.0917 - val_accuracy: 0.6667 - lr: 3.0000e-04
# Epoch 7/80
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1860 - accuracy: 0.9565 - val_loss: 2.1026 - val_accuracy: 0.6667 - lr: 3.0000e-04
# Epoch 8/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1645 - accuracy: 0.9695 - val_loss: 2.3184 - val_accuracy: 0.6667 - lr: 3.0000e-04
# Epoch 9/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1349 - accuracy: 0.9788 - val_loss: 2.5668 - val_accuracy: 0.6667 - lr: 1.5000e-04
# Epoch 10/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1253 - accuracy: 0.9820 - val_loss: 1.9471 - val_accuracy: 0.7292 - lr: 1.5000e-04
# Epoch 11/80
# 92/92 [==============================] - 1s 11ms/step - loss: 0.1209 - accuracy: 0.9836 - val_loss: 2.5657 - val_accuracy: 0.6528 - lr: 1.5000e-04
# Epoch 12/80
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1173 - accuracy: 0.9841 - val_loss: 2.1665 - val_accuracy: 0.6806 - lr: 1.5000e-04
# Epoch 13/80
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1148 - accuracy: 0.9855 - val_loss: 2.1169 - val_accuracy: 0.6806 - lr: 1.5000e-04
# Epoch 14/80
# 92/92 [==============================] - 1s 12ms/step - loss: 0.1066 - accuracy: 0.9882 - val_loss: 2.1697 - val_accuracy: 0.6875 - lr: 1.5000e-04
#
# ===== FOLD 15/22 - Person: P15 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 17ms/step - loss: 0.7689 - accuracy: 0.6676 - val_loss: 0.6708 - val_accuracy: 0.6375 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.5555 - accuracy: 0.7764 - val_loss: 0.6392 - val_accuracy: 0.7125 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.4199 - accuracy: 0.8451 - val_loss: 0.7062 - val_accuracy: 0.7125 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.3292 - accuracy: 0.8932 - val_loss: 1.8519 - val_accuracy: 0.6687 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.2205 - accuracy: 0.9420 - val_loss: 2.7259 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1991 - accuracy: 0.9560 - val_loss: 2.2184 - val_accuracy: 0.6562 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1745 - accuracy: 0.9649 - val_loss: 2.1852 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1668 - accuracy: 0.9672 - val_loss: 2.1377 - val_accuracy: 0.6187 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1301 - accuracy: 0.9821 - val_loss: 2.1831 - val_accuracy: 0.7063 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1220 - accuracy: 0.9844 - val_loss: 2.1626 - val_accuracy: 0.7063 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1261 - accuracy: 0.9819 - val_loss: 2.2135 - val_accuracy: 0.6875 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1184 - accuracy: 0.9837 - val_loss: 2.2066 - val_accuracy: 0.6938 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1053 - accuracy: 0.9905 - val_loss: 2.1996 - val_accuracy: 0.6938 - lr: 1.5000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1101 - accuracy: 0.9881 - val_loss: 2.4051 - val_accuracy: 0.6562 - lr: 1.5000e-04
#
# ===== FOLD 16/22 - Person: P16 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 17ms/step - loss: 0.7460 - accuracy: 0.6803 - val_loss: 0.6520 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.4945 - accuracy: 0.8109 - val_loss: 0.6094 - val_accuracy: 0.7750 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.3767 - accuracy: 0.8731 - val_loss: 0.9397 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.3040 - accuracy: 0.9089 - val_loss: 0.8481 - val_accuracy: 0.6875 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.2272 - accuracy: 0.9390 - val_loss: 1.3043 - val_accuracy: 0.6625 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1964 - accuracy: 0.9564 - val_loss: 1.3930 - val_accuracy: 0.7188 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1862 - accuracy: 0.9616 - val_loss: 1.5244 - val_accuracy: 0.6438 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1755 - accuracy: 0.9628 - val_loss: 1.3395 - val_accuracy: 0.6750 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1297 - accuracy: 0.9812 - val_loss: 1.7883 - val_accuracy: 0.6250 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1145 - accuracy: 0.9860 - val_loss: 1.6197 - val_accuracy: 0.6562 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1287 - accuracy: 0.9794 - val_loss: 1.3992 - val_accuracy: 0.7250 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 15ms/step - loss: 0.1239 - accuracy: 0.9800 - val_loss: 1.8598 - val_accuracy: 0.6562 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1073 - accuracy: 0.9867 - val_loss: 2.4425 - val_accuracy: 0.5750 - lr: 1.5000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1098 - accuracy: 0.9867 - val_loss: 2.1920 - val_accuracy: 0.5750 - lr: 1.5000e-04
#
# ===== FOLD 17/22 - Person: P17 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 19ms/step - loss: 0.7794 - accuracy: 0.6588 - val_loss: 0.7114 - val_accuracy: 0.6125 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.5530 - accuracy: 0.7810 - val_loss: 0.6205 - val_accuracy: 0.7312 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.4227 - accuracy: 0.8458 - val_loss: 0.9009 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.3292 - accuracy: 0.8946 - val_loss: 0.6887 - val_accuracy: 0.7375 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2721 - accuracy: 0.9226 - val_loss: 0.4333 - val_accuracy: 0.8375 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2121 - accuracy: 0.9488 - val_loss: 1.1300 - val_accuracy: 0.7500 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1814 - accuracy: 0.9608 - val_loss: 1.0253 - val_accuracy: 0.8125 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1691 - accuracy: 0.9649 - val_loss: 0.9954 - val_accuracy: 0.7312 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1428 - accuracy: 0.9753 - val_loss: 1.6097 - val_accuracy: 0.7312 - lr: 3.0000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1436 - accuracy: 0.9732 - val_loss: 1.6205 - val_accuracy: 0.7125 - lr: 3.0000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1384 - accuracy: 0.9751 - val_loss: 1.5887 - val_accuracy: 0.7188 - lr: 3.0000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1124 - accuracy: 0.9860 - val_loss: 1.4180 - val_accuracy: 0.7937 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1012 - accuracy: 0.9900 - val_loss: 1.5282 - val_accuracy: 0.7125 - lr: 1.5000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1082 - accuracy: 0.9870 - val_loss: 1.6192 - val_accuracy: 0.7312 - lr: 1.5000e-04
# Epoch 15/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0987 - accuracy: 0.9917 - val_loss: 1.5528 - val_accuracy: 0.7688 - lr: 1.5000e-04
# Epoch 16/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0919 - accuracy: 0.9929 - val_loss: 1.5478 - val_accuracy: 0.7812 - lr: 1.5000e-04
# Epoch 17/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0974 - accuracy: 0.9915 - val_loss: 1.5055 - val_accuracy: 0.7625 - lr: 1.5000e-04
#
# ===== FOLD 18/22 - Person: P18 =====
# Epoch 1/80
# 91/91 [==============================] - 4s 20ms/step - loss: 0.7687 - accuracy: 0.6511 - val_loss: 0.6699 - val_accuracy: 0.6938 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.5299 - accuracy: 0.7916 - val_loss: 0.7645 - val_accuracy: 0.6625 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.4197 - accuracy: 0.8506 - val_loss: 0.8668 - val_accuracy: 0.7250 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.3323 - accuracy: 0.8892 - val_loss: 0.8145 - val_accuracy: 0.8687 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.2600 - accuracy: 0.9256 - val_loss: 1.1244 - val_accuracy: 0.7437 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.2150 - accuracy: 0.9469 - val_loss: 1.6474 - val_accuracy: 0.6938 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2135 - accuracy: 0.9458 - val_loss: 0.5376 - val_accuracy: 0.8438 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1813 - accuracy: 0.9589 - val_loss: 1.5261 - val_accuracy: 0.7000 - lr: 3.0000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1674 - accuracy: 0.9645 - val_loss: 0.8560 - val_accuracy: 0.8313 - lr: 3.0000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1288 - accuracy: 0.9796 - val_loss: 1.2281 - val_accuracy: 0.8188 - lr: 3.0000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1337 - accuracy: 0.9779 - val_loss: 1.1880 - val_accuracy: 0.8250 - lr: 3.0000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1217 - accuracy: 0.9817 - val_loss: 0.8961 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1184 - accuracy: 0.9831 - val_loss: 0.7821 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 14/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1085 - accuracy: 0.9867 - val_loss: 1.1791 - val_accuracy: 0.8188 - lr: 1.5000e-04
# Epoch 15/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0906 - accuracy: 0.9931 - val_loss: 0.7969 - val_accuracy: 0.8938 - lr: 1.5000e-04
# Epoch 16/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.0896 - accuracy: 0.9931 - val_loss: 0.8286 - val_accuracy: 0.9000 - lr: 1.5000e-04
# Epoch 17/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0842 - accuracy: 0.9948 - val_loss: 1.1518 - val_accuracy: 0.8250 - lr: 1.5000e-04
# Epoch 18/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.0960 - accuracy: 0.9893 - val_loss: 0.9118 - val_accuracy: 0.8562 - lr: 1.5000e-04
# Epoch 19/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.0912 - accuracy: 0.9909 - val_loss: 1.0431 - val_accuracy: 0.8375 - lr: 1.5000e-04
#
# ===== FOLD 19/22 - Person: P19 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 17ms/step - loss: 0.7883 - accuracy: 0.6768 - val_loss: 0.6530 - val_accuracy: 0.6375 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.5494 - accuracy: 0.7902 - val_loss: 0.7293 - val_accuracy: 0.6750 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.4020 - accuracy: 0.8604 - val_loss: 1.8784 - val_accuracy: 0.5938 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.2947 - accuracy: 0.9113 - val_loss: 3.3274 - val_accuracy: 0.5813 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2412 - accuracy: 0.9400 - val_loss: 3.0097 - val_accuracy: 0.5688 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.2087 - accuracy: 0.9520 - val_loss: 2.4179 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1848 - accuracy: 0.9601 - val_loss: 2.3445 - val_accuracy: 0.6562 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1568 - accuracy: 0.9722 - val_loss: 3.0042 - val_accuracy: 0.5750 - lr: 1.5000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1422 - accuracy: 0.9800 - val_loss: 2.3543 - val_accuracy: 0.6250 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1322 - accuracy: 0.9813 - val_loss: 2.4375 - val_accuracy: 0.6062 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 14ms/step - loss: 0.1267 - accuracy: 0.9822 - val_loss: 2.9340 - val_accuracy: 0.5250 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1359 - accuracy: 0.9793 - val_loss: 2.6486 - val_accuracy: 0.5875 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.1176 - accuracy: 0.9844 - val_loss: 3.1693 - val_accuracy: 0.5375 - lr: 1.5000e-04
#
# ===== FOLD 20/22 - Person: P20 =====
# Epoch 1/80
# 90/90 [==============================] - 3s 18ms/step - loss: 0.7684 - accuracy: 0.6533 - val_loss: 0.5965 - val_accuracy: 0.8500 - lr: 3.0000e-04
# Epoch 2/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.5472 - accuracy: 0.7883 - val_loss: 0.6772 - val_accuracy: 0.5875 - lr: 3.0000e-04
# Epoch 3/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.4136 - accuracy: 0.8485 - val_loss: 0.4033 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 4/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3316 - accuracy: 0.8961 - val_loss: 1.1561 - val_accuracy: 0.5500 - lr: 3.0000e-04
# Epoch 5/80
# 90/90 [==============================] - 1s 15ms/step - loss: 0.2527 - accuracy: 0.9302 - val_loss: 1.7828 - val_accuracy: 0.5813 - lr: 3.0000e-04
# Epoch 6/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.2093 - accuracy: 0.9486 - val_loss: 1.8735 - val_accuracy: 0.5312 - lr: 3.0000e-04
# Epoch 7/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1811 - accuracy: 0.9604 - val_loss: 2.3958 - val_accuracy: 0.5437 - lr: 3.0000e-04
# Epoch 8/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1632 - accuracy: 0.9679 - val_loss: 3.3089 - val_accuracy: 0.4000 - lr: 3.0000e-04
# Epoch 9/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1671 - accuracy: 0.9666 - val_loss: 2.6642 - val_accuracy: 0.4375 - lr: 3.0000e-04
# Epoch 10/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.1267 - accuracy: 0.9819 - val_loss: 3.0828 - val_accuracy: 0.4250 - lr: 1.5000e-04
# Epoch 11/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1219 - accuracy: 0.9840 - val_loss: 3.0528 - val_accuracy: 0.4437 - lr: 1.5000e-04
# Epoch 12/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1085 - accuracy: 0.9880 - val_loss: 2.4533 - val_accuracy: 0.5500 - lr: 1.5000e-04
# Epoch 13/80
# 90/90 [==============================] - 1s 15ms/step - loss: 0.1076 - accuracy: 0.9880 - val_loss: 3.4970 - val_accuracy: 0.4187 - lr: 1.5000e-04
# Epoch 14/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.1110 - accuracy: 0.9871 - val_loss: 3.6010 - val_accuracy: 0.4250 - lr: 1.5000e-04
# Epoch 15/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1057 - accuracy: 0.9889 - val_loss: 3.2489 - val_accuracy: 0.4563 - lr: 1.5000e-04
#
# ===== FOLD 21/22 - Person: P21 =====
# Epoch 1/80
# 90/90 [==============================] - 3s 18ms/step - loss: 0.7733 - accuracy: 0.6558 - val_loss: 0.6836 - val_accuracy: 0.6625 - lr: 3.0000e-04
# Epoch 2/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.5311 - accuracy: 0.7842 - val_loss: 0.6760 - val_accuracy: 0.6938 - lr: 3.0000e-04
# Epoch 3/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.4107 - accuracy: 0.8493 - val_loss: 0.6817 - val_accuracy: 0.8000 - lr: 3.0000e-04
# Epoch 4/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.3234 - accuracy: 0.8964 - val_loss: 0.9887 - val_accuracy: 0.7312 - lr: 3.0000e-04
# Epoch 5/80
# 90/90 [==============================] - 1s 12ms/step - loss: 0.2434 - accuracy: 0.9352 - val_loss: 1.0069 - val_accuracy: 0.6500 - lr: 3.0000e-04
# Epoch 6/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.2171 - accuracy: 0.9459 - val_loss: 1.5381 - val_accuracy: 0.6812 - lr: 3.0000e-04
# Epoch 7/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.1727 - accuracy: 0.9668 - val_loss: 0.8459 - val_accuracy: 0.7125 - lr: 3.0000e-04
# Epoch 8/80
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1505 - accuracy: 0.9729 - val_loss: 1.3787 - val_accuracy: 0.6562 - lr: 3.0000e-04
# Epoch 9/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1331 - accuracy: 0.9793 - val_loss: 1.6177 - val_accuracy: 0.6625 - lr: 1.5000e-04
# Epoch 10/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.1147 - accuracy: 0.9871 - val_loss: 1.8722 - val_accuracy: 0.7000 - lr: 1.5000e-04
# Epoch 11/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.1152 - accuracy: 0.9856 - val_loss: 1.6342 - val_accuracy: 0.6500 - lr: 1.5000e-04
# Epoch 12/80
# 90/90 [==============================] - 1s 12ms/step - loss: 0.1105 - accuracy: 0.9878 - val_loss: 1.7749 - val_accuracy: 0.6250 - lr: 1.5000e-04
# Epoch 13/80
# 90/90 [==============================] - 1s 13ms/step - loss: 0.1108 - accuracy: 0.9863 - val_loss: 1.1913 - val_accuracy: 0.7750 - lr: 1.5000e-04
# Epoch 14/80
# 90/90 [==============================] - 1s 14ms/step - loss: 0.1019 - accuracy: 0.9904 - val_loss: 1.9315 - val_accuracy: 0.6375 - lr: 1.5000e-04
#
# ===== FOLD 22/22 - Person: P22 =====
# Epoch 1/80
# 91/91 [==============================] - 3s 17ms/step - loss: 0.7492 - accuracy: 0.6760 - val_loss: 0.8251 - val_accuracy: 0.6000 - lr: 3.0000e-04
# Epoch 2/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.5261 - accuracy: 0.7851 - val_loss: 1.0567 - val_accuracy: 0.5750 - lr: 3.0000e-04
# Epoch 3/80
# 91/91 [==============================] - 1s 13ms/step - loss: 0.4144 - accuracy: 0.8468 - val_loss: 1.4255 - val_accuracy: 0.4750 - lr: 3.0000e-04
# Epoch 4/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.3301 - accuracy: 0.8931 - val_loss: 1.9150 - val_accuracy: 0.4563 - lr: 3.0000e-04
# Epoch 5/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.2493 - accuracy: 0.9318 - val_loss: 2.7415 - val_accuracy: 0.4250 - lr: 3.0000e-04
# Epoch 6/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.2057 - accuracy: 0.9503 - val_loss: 2.8029 - val_accuracy: 0.4062 - lr: 3.0000e-04
# Epoch 7/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1825 - accuracy: 0.9611 - val_loss: 3.1880 - val_accuracy: 0.3938 - lr: 3.0000e-04
# Epoch 8/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1658 - accuracy: 0.9682 - val_loss: 2.8338 - val_accuracy: 0.4313 - lr: 1.5000e-04
# Epoch 9/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1434 - accuracy: 0.9762 - val_loss: 3.2994 - val_accuracy: 0.4250 - lr: 1.5000e-04
# Epoch 10/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1224 - accuracy: 0.9857 - val_loss: 3.5767 - val_accuracy: 0.3625 - lr: 1.5000e-04
# Epoch 11/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1213 - accuracy: 0.9848 - val_loss: 3.4865 - val_accuracy: 0.4250 - lr: 1.5000e-04
# Epoch 12/80
# 91/91 [==============================] - 1s 11ms/step - loss: 0.1284 - accuracy: 0.9805 - val_loss: 3.6926 - val_accuracy: 0.4500 - lr: 1.5000e-04
# Epoch 13/80
# 91/91 [==============================] - 1s 12ms/step - loss: 0.1107 - accuracy: 0.9865 - val_loss: 3.8231 - val_accuracy: 0.4625 - lr: 1.5000e-04
# ==== LOSO Summary (Up/Down) ====
# Mean Window Acc: 0.787 ± 0.136
# Mean Clip   Acc: 0.804 ± 0.146
#
# ==== OVERALL (클립) ====
# Overall 클립 Acc: 0.799
#               precision    recall  f1-score   support
#
#            위      0.825     0.756     0.789       250
#           아래      0.777     0.841     0.808       252
#
#     accuracy                          0.799       502
#    macro avg      0.801     0.799     0.798       502
# weighted avg      0.801     0.799     0.798       502
